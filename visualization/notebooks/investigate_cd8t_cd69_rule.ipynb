# %% [markdown]
# # Investigation: CD8T_CD69+ -> Epithelial rule (Multi-Stage Evaluation)
#
# This notebook investigates the functional subtype association rule **CD8T_CD69+ -> Epithelial** across different disease stages (Control, Mild, Severe). It calculates per-FOV metrics to directly compare standard FP-Growth (binary) vs Weighted FP-Growth (distance-decay) pass rates.

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.filterwarnings('ignore')

# Add root to path for constants and utils
sys.path.append(os.path.abspath('../../'))
import constants
from utils.rules import build_cell_item_token, passes_rule_support_policy, _extract_base_lineage

RADIUS = constants.CONFIG['RADIUS']
BANDWIDTH = constants.CONFIG.get('BANDWIDTH', RADIUS)
MIN_SUPPORT = constants.CONFIG['MIN_SUPPORT']
MIN_ABS_SUPPORT = constants.CONFIG.get('MIN_ABS_SUPPORT', 5)
MIN_CONFIDENCE = constants.CONFIG['MIN_CONFIDENCE']
MIN_LIFT = constants.CONFIG['MIN_LIFT']

ANTECEDENT_BASE = 'CD8T'
ANTECEDENT_REQUIRED_MARKERS = ('CD69+',)
CONSEQUENT_BASE = 'Epithelial'
CONSEQUENT_REQUIRED_MARKERS = ()

# %% [markdown]
# ## Step 1: Data Loading & Functional Subtypes
#
# Load the cell and metadata tables, identify disease stages, and append the `functional_subtypes` array to every cell.

# %%
def _add_functional_subtypes(df):
    if not constants.USE_FUNCTIONAL_MARKERS:
        df["functional_subtypes"] = [[] for _ in range(len(df))]
        return df
    functional_subtypes_list = [[] for _ in range(len(df))]
    idx_to_pos = {idx: i for i, idx in enumerate(df.index)}
    for base_type, markers in constants.CELLTYPE_MARKER_THRESHOLDS.items():
        type_mask = df["cell type"] == base_type
        for marker, threshold in markers.items():
            if marker in df.columns:
                mask = type_mask & (df[marker] > threshold)
                subtype_label = f"{base_type}_{marker}+"
                matching_indices = df.index[mask]
                for idx in matching_indices:
                    functional_subtypes_list[idx_to_pos[idx]].append(subtype_label)
    df["functional_subtypes"] = functional_subtypes_list
    return df

cell_table_path = '../../data/MIBIGutCsv/cell_table.csv'
fov_meta_path = '../../data/MIBIGutCsv/fovs_metadata.csv'
biopsy_meta_path = '../../data/MIBIGutCsv/biopsy_metadata.csv'

df_cells = pd.read_csv(cell_table_path)
df_fovs = pd.read_csv(fov_meta_path)
df_biopsy = pd.read_csv(biopsy_meta_path)

# Merge FOV with Biopsy to get Pathological score
df_fovs = pd.merge(df_fovs, df_biopsy[['Biopsy_ID', 'Pathological score']], left_on='Patient', right_on='Biopsy_ID', how='left')

# Define FOV lists for each cohort
control_cohorts = ['Duodenum_Cohort_Control_1', 'Duodenum_Cohort_Control_2', 'Colon_Cohort_Control']
control_fovs = df_fovs[df_fovs['Cohort'].isin(control_cohorts)]['FOV'].tolist()
mild_fovs = df_fovs[df_fovs['Pathological score'] == 'Mild']['FOV'].tolist()
severe_fovs = df_fovs[df_fovs['Pathological score'] == 'Severe']['FOV'].tolist()

# Normalize Coordinates
fov_to_size = df_fovs.set_index('FOV')['Size [um]'].to_dict()
def normalize_coords(row):
    size = fov_to_size.get(row['fov'], 800)
    res = 1024 if size == 400 else 2048
    return row['centroid_x'] * (size / res), row['centroid_y'] * (size / res)

df_cells[['x_um', 'y_um']] = df_cells.apply(lambda row: pd.Series(normalize_coords(row)), axis=1)

# Add Functional Subtypes
df_cells = _add_functional_subtypes(df_cells)

print(f"Total Cells: {len(df_cells)}")
print(f"Control FOVs: {len(control_fovs)}")
print(f"Mild FOVs: {len(mild_fovs)}")
print(f"Severe FOVs: {len(severe_fovs)}")
# Out:
# Total Cells: 713372
# Control FOVs: 77
# Mild FOVs: 143
# Severe FOVs: 68

# %% [markdown]
# ## Step 2: Evaluation Framework
#
# Define a reusable function that iterates over a given list of FOVs, computes both binary and weighted metrics *per FOV*, and verifies how many FOVs pass the algorithm thresholds. Finally, it visualizes the FOV with the highest target cell density.

# %%
def evaluate_cohort(cohort_name, fov_list, df_cells_all):
    print(f"==============================================")
    print(f"Evaluating Cohort: {cohort_name}")
    print(f"==============================================\n")

    binary_pass_count = 0
    weighted_pass_count = 0
    valid_fovs = 0

    global_binary_transactions = []
    global_weighted_transactions = []
    passing_binary_transactions = []
    passing_weighted_transactions = []

    max_target_count = -1
    max_target_fov = None

    def _parse_token(token, suffix):
        token = str(token)
        tail = f"_{suffix}"
        if not token.endswith(tail):
            return None, set()
        core = token[:-len(tail)]
        base = _extract_base_lineage(core)
        markers = {part for part in core.split('_') if part.endswith('+')}
        return base, markers

    def _matches_rule_item(token, base, suffix, required_markers=()):
        token_base, token_markers = _parse_token(token, suffix)
        if token_base != base:
            return False
        return set(required_markers).issubset(token_markers)

    def _has_item(binary_trans, base, suffix, required_markers=()):
        return any(_matches_rule_item(item, base, suffix, required_markers) for item in binary_trans)

    def _weight_for_item(weighted_trans, base, suffix, required_markers=()):
        return min(
            sum(float(v) for k, v in weighted_trans.items() if _matches_rule_item(k, base, suffix, required_markers)),
            1.0,
        )

    def _rule_item_label(base, required_markers):
        if not required_markers:
            return base
        return f"{base}_{'_'.join(required_markers)}"

    for fov in fov_list:
        fov_data = df_cells_all[df_cells_all['fov'] == fov]
        if fov_data.empty:
            continue
        valid_fovs += 1

        coords = fov_data[['x_um', 'y_um']].values
        types = fov_data['cell type'].values
        subtypes = fov_data['functional_subtypes'].values

        target_count = sum(
            1
            for t, st in zip(types, subtypes)
            if _matches_rule_item(
                build_cell_item_token(t, st, suffix='CENTER'),
                ANTECEDENT_BASE,
                'CENTER',
                ANTECEDENT_REQUIRED_MARKERS,
            )
        )
        if target_count > max_target_count:
            max_target_count = target_count
            max_target_fov = fov

        nn = NearestNeighbors(radius=RADIUS).fit(coords)
        distances, neighbors_idx = nn.radius_neighbors(coords, return_distance=True)

        fov_binary_trans = []
        fov_weighted_trans = []

        for i, (idxs, dists) in enumerate(zip(neighbors_idx, distances)):
            if len(idxs) < constants.CONFIG.get("MIN_CELLS_PER_PATCH", 2):
                continue

            center_token = build_cell_item_token(types[i], subtypes[i], suffix='CENTER')

            b_trans = {center_token}
            w_trans = {center_token: 1.0}

            for n_idx, d in zip(idxs, dists):
                if n_idx == i:
                    continue

                neighbor_token = build_cell_item_token(types[n_idx], subtypes[n_idx], suffix='NEIGHBOR')
                b_trans.add(neighbor_token)

                w = np.exp(-0.5 * (d / BANDWIDTH) ** 2)
                w_trans[neighbor_token] = w_trans.get(neighbor_token, 0.0) + w

            w_trans = {k: min(v, 1.0) for k, v in w_trans.items()}

            fov_binary_trans.append(b_trans)
            fov_weighted_trans.append(w_trans)
            global_binary_transactions.append(b_trans)
            global_weighted_transactions.append(w_trans)

        n_trans = len(fov_binary_trans)
        if n_trans == 0:
            print(f"FOV: {fov} | 0 Transactions")
            continue

        b_sup_ant = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_con = sum(
            1 for t in fov_binary_trans
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_joint = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_conf = b_sup_joint / b_sup_ant if b_sup_ant > 0 else 0
        b_lift = b_conf / b_sup_con if b_sup_con > 0 else 0

        b_pass = False
        if b_sup_joint >= MIN_SUPPORT and b_conf >= MIN_CONFIDENCE and b_lift >= MIN_LIFT:
            binary_pass_count += 1
            b_pass = True

        w_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in fov_weighted_trans
        ) / n_trans
        w_conf = w_sup_joint / w_sup_ant if w_sup_ant > 0 else 0
        w_lift = w_conf / w_sup_con if w_sup_con > 0 else 0

        w_pass = False
        if (
            passes_rule_support_policy(constants.CONFIG, w_sup_joint, w_conf, w_lift, num_transactions=n_trans)
            and w_conf >= MIN_CONFIDENCE
            and w_lift >= MIN_LIFT
        ):
            weighted_pass_count += 1
            w_pass = True

        if b_pass:
            passing_binary_transactions.extend(fov_binary_trans)
        if w_pass:
            passing_weighted_transactions.extend(fov_weighted_trans)

        print(f"FOV: {fov} | Transactions: {n_trans}")
        print(f"  [Binary]   Sup: {b_sup_joint:.4f} | Conf: {b_conf:.4f} | Lift: {b_lift:.4f} | PASS: {b_pass}")
        print(f"  [Weighted] Sup: {w_sup_joint:.4f} | Conf: {w_conf:.4f} | Lift: {w_lift:.4f} | PASS: {w_pass}\n")

    ant_label = _rule_item_label(ANTECEDENT_BASE, ANTECEDENT_REQUIRED_MARKERS)
    con_label = _rule_item_label(CONSEQUENT_BASE, CONSEQUENT_REQUIRED_MARKERS)
    print(f"\n[Algorithm Comparison: {ant_label}_CENTER -> {con_label}_NEIGHBOR (rule-aware)]")
    print(f"FOVs passing standard FP-Growth (Binary): {binary_pass_count} / {valid_fovs}")
    print(f"FOVs passing Weighted FP-Growth (Distance-decay): {weighted_pass_count} / {valid_fovs}")

    if not global_binary_transactions:
        return

    g_n_trans = len(global_binary_transactions)
    gb_sup_ant = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_con = sum(
        1 for t in global_binary_transactions
        if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_joint = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_conf = gb_sup_joint / gb_sup_ant if gb_sup_ant > 0 else 0
    gb_lift = gb_conf / gb_sup_con if gb_sup_con > 0 else 0

    gw_sup_ant = sum(
        _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_con = sum(
        _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_joint = sum(
        min(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
        )
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_conf = gw_sup_joint / gw_sup_ant if gw_sup_ant > 0 else 0
    gw_lift = gw_conf / gw_sup_con if gw_sup_con > 0 else 0

    if passing_binary_transactions:
        p_n_trans = len(passing_binary_transactions)
        pb_sup_ant = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_con = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_joint = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_conf = pb_sup_joint / pb_sup_ant if pb_sup_ant > 0 else 0
        pb_lift = pb_conf / pb_sup_con if pb_sup_con > 0 else 0

        pw_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_conf = pw_sup_joint / pw_sup_ant if pw_sup_ant > 0 else 0
        pw_lift = pw_conf / pw_sup_con if pw_sup_con > 0 else 0
    else:
        pb_sup_joint = pb_conf = pb_lift = 0
        pw_sup_joint = pw_conf = pw_lift = 0

    print(f"\n[Aggregate Metrics: ALL FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Approved: {binary_pass_count:>12} | {weighted_pass_count:>12}  (out of {valid_fovs} valid FOVs)")
    print(f"Support : {gb_sup_joint:>12.4f} | {gw_sup_joint:>12.4f}")
    print(f"Conf    : {gb_conf:>12.4f} | {gw_conf:>12.4f}")
    print(f"Lift    : {gb_lift:>12.4f} | {gw_lift:>12.4f}")

    print(f"\n[Aggregate Metrics: ONLY PASSING FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Support : {pb_sup_joint:>12.4f} | {pw_sup_joint:>12.4f}")
    print(f"Conf    : {pb_conf:>12.4f} | {pw_conf:>12.4f}")
    print(f"Lift    : {pb_lift:>12.4f} | {pw_lift:>12.4f}")

    if max_target_fov:
        print(f"\nVisualizing Representative FOV: {max_target_fov} ({max_target_count} matching antecedent cells)")
        _plot_fov(max_target_fov, df_cells_all)

def _plot_fov(fov, df_cells_all):
    fov_df = df_cells_all[df_cells_all['fov'] == fov].copy()
    
    def get_plot_class(row):
        if 'CD8T_CD69+' in row['functional_subtypes']:
            return 'CD8T_CD69+'
        elif row['cell type'] == 'CD8T':
            return 'CD8T_Other'
        elif row['cell type'] == 'Epithelial':
            return 'Epithelial'
        return 'Other'
        
    fov_df['PlotClass'] = fov_df.apply(get_plot_class, axis=1)
    
    plt.figure(figsize=(10, 10))
    
    # Plot others
    others = fov_df[fov_df['PlotClass'] == 'Other']
    sns.scatterplot(data=others, x='x_um', y='y_um', color='lightgrey', alpha=0.3, s=20)
    
    # Plot CD8T_Other
    cd8t_other = fov_df[fov_df['PlotClass'] == 'CD8T_Other']
    sns.scatterplot(data=cd8t_other, x='x_um', y='y_um', color='pink', s=20, label='CD8T (No CD69)')
    
    # Plot Epithelial
    epi = fov_df[fov_df['PlotClass'] == 'Epithelial']
    sns.scatterplot(data=epi, x='x_um', y='y_um', color='blue', alpha=0.5, s=30, label='Epithelial')
    
    # Plot CD8T_CD69+
    cd8t_cd69 = fov_df[fov_df['PlotClass'] == 'CD8T_CD69+']
    sns.scatterplot(data=cd8t_cd69, x='x_um', y='y_um', color='red', s=70, edgecolor='black', zorder=10, label='CD8T_CD69+')
    
    plt.title(f"Spatial Distribution in FOV {fov}")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.show()

# %% [markdown]
# ## Step 3: Run Evaluation on Control Cohort

# %%
evaluate_cohort("Control", control_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Control
# ==============================================
#
# FOV: Control_01_FOV_1 | Transactions: 2618
#   [Binary]   Sup: 0.0267 | Conf: 0.6422 | Lift: 1.3636 | PASS: True
#   [Weighted] Sup: 0.0253 | Conf: 0.6083 | Lift: 1.4262 | PASS: True
#
# FOV: Control_01_FOV_2 | Transactions: 2354
#   [Binary]   Sup: 0.0425 | Conf: 0.9009 | Lift: 1.1775 | PASS: False
#   [Weighted] Sup: 0.0396 | Conf: 0.8395 | Lift: 1.1791 | PASS: False
#
# FOV: Control_01_FOV_3 | Transactions: 2157
#   [Binary]   Sup: 0.0352 | Conf: 0.7238 | Lift: 0.9844 | PASS: False
#   [Weighted] Sup: 0.0339 | Conf: 0.6970 | Lift: 0.9779 | PASS: False
#
# FOV: Control_01_FOV_4 | Transactions: 2140
#   [Binary]   Sup: 0.0248 | Conf: 0.9138 | Lift: 0.9817 | PASS: False
#   [Weighted] Sup: 0.0233 | Conf: 0.8613 | Lift: 0.9531 | PASS: False
#
# FOV: Control_02_FOV_1 | Transactions: 2305
#   [Binary]   Sup: 0.0148 | Conf: 0.7083 | Lift: 0.9748 | PASS: False
#   [Weighted] Sup: 0.0142 | Conf: 0.6820 | Lift: 0.9927 | PASS: False
#
# FOV: Control_02_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0103 | Conf: 0.7500 | Lift: 1.1549 | PASS: False
#   [Weighted] Sup: 0.0091 | Conf: 0.6624 | Lift: 1.0727 | PASS: False
#
# FOV: Control_02_FOV_3 | Transactions: 2040
#   [Binary]   Sup: 0.0157 | Conf: 0.9412 | Lift: 1.0000 | PASS: False
#   [Weighted] Sup: 0.0152 | Conf: 0.9123 | Lift: 1.0041 | PASS: False
#
# FOV: Control_02_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0092 | Conf: 0.7000 | Lift: 0.9436 | PASS: False
#   [Weighted] Sup: 0.0083 | Conf: 0.6323 | Lift: 0.9094 | PASS: False
#
# FOV: Control_03_FOV_1 | Transactions: 2074
#   [Binary]   Sup: 0.0174 | Conf: 0.9231 | Lift: 1.1157 | PASS: False
#   [Weighted] Sup: 0.0173 | Conf: 0.9188 | Lift: 1.1553 | PASS: False
#
# FOV: Control_03_FOV_2 | Transactions: 1916
#   [Binary]   Sup: 0.0177 | Conf: 0.6667 | Lift: 0.8803 | PASS: False
#   [Weighted] Sup: 0.0177 | Conf: 0.6667 | Lift: 0.9221 | PASS: False
#
# FOV: Control_03_FOV_3 | Transactions: 1884
#   [Binary]   Sup: 0.0175 | Conf: 0.7674 | Lift: 0.9965 | PASS: False
#   [Weighted] Sup: 0.0171 | Conf: 0.7504 | Lift: 1.0269 | PASS: False
#
# FOV: Control_04_FOV_1 | Transactions: 2290
#   [Binary]   Sup: 0.0402 | Conf: 0.8142 | Lift: 1.0533 | PASS: False
#   [Weighted] Sup: 0.0385 | Conf: 0.7804 | Lift: 1.0751 | PASS: False
#
# FOV: Control_04_FOV_2 | Transactions: 1911
#   [Binary]   Sup: 0.0424 | Conf: 0.7364 | Lift: 0.9096 | PASS: False
#   [Weighted] Sup: 0.0406 | Conf: 0.7062 | Lift: 0.9036 | PASS: False
#
# FOV: Control_05_FOV_1 | Transactions: 1924
#   [Binary]   Sup: 0.0291 | Conf: 0.9032 | Lift: 1.1562 | PASS: False
#   [Weighted] Sup: 0.0266 | Conf: 0.8252 | Lift: 1.1257 | PASS: False
#
# FOV: Control_05_FOV_2 | Transactions: 1753
#   [Binary]   Sup: 0.0422 | Conf: 0.7708 | Lift: 1.0880 | PASS: False
#   [Weighted] Sup: 0.0380 | Conf: 0.6945 | Lift: 1.0650 | PASS: False
#
# FOV: Control_06_FOV_1 | Transactions: 1723
#   [Binary]   Sup: 0.0081 | Conf: 0.8235 | Lift: 0.9813 | PASS: False
#   [Weighted] Sup: 0.0077 | Conf: 0.7837 | Lift: 0.9853 | PASS: False
#
# FOV: Control_06_FOV_2 | Transactions: 1651
#   [Binary]   Sup: 0.0103 | Conf: 0.9444 | Lift: 0.9549 | PASS: False
#   [Weighted] Sup: 0.0102 | Conf: 0.9348 | Lift: 0.9480 | PASS: False
#
# FOV: Control_06_FOV_3 | Transactions: 1308
#   [Binary]   Sup: 0.0061 | Conf: 0.6667 | Lift: 1.0595 | PASS: False
#   [Weighted] Sup: 0.0061 | Conf: 0.6638 | Lift: 1.2262 | PASS: False
#
# FOV: Control_07_FOV_1 | Transactions: 2317
#   [Binary]   Sup: 0.0246 | Conf: 0.7308 | Lift: 1.0375 | PASS: False
#   [Weighted] Sup: 0.0234 | Conf: 0.6941 | Lift: 1.0183 | PASS: False
#
# FOV: Control_07_FOV_2 | Transactions: 1811
#   [Binary]   Sup: 0.0116 | Conf: 0.6364 | Lift: 0.9279 | PASS: False
#   [Weighted] Sup: 0.0098 | Conf: 0.5375 | Lift: 0.8773 | PASS: False
#
# FOV: Control_07_FOV_3 | Transactions: 1913
#   [Binary]   Sup: 0.0131 | Conf: 0.6410 | Lift: 0.8280 | PASS: False
#   [Weighted] Sup: 0.0127 | Conf: 0.6233 | Lift: 0.8333 | PASS: False
#
# FOV: Control_08_FOV_1 | Transactions: 1954
#   [Binary]   Sup: 0.0143 | Conf: 0.3684 | Lift: 0.4989 | PASS: False
#   [Weighted] Sup: 0.0137 | Conf: 0.3526 | Lift: 0.4901 | PASS: False
#
# FOV: Control_08_FOV_2 | Transactions: 1657
#   [Binary]   Sup: 0.0260 | Conf: 1.0000 | Lift: 1.0061 | PASS: False
#   [Weighted] Sup: 0.0260 | Conf: 1.0000 | Lift: 1.0156 | PASS: False
#
# FOV: Control_08_FOV_3 | Transactions: 2070
#   [Binary]   Sup: 0.0155 | Conf: 0.6809 | Lift: 0.9794 | PASS: False
#   [Weighted] Sup: 0.0155 | Conf: 0.6809 | Lift: 1.0178 | PASS: False
#
# FOV: Control_09_FOV_1 | Transactions: 2375
#   [Binary]   Sup: 0.0156 | Conf: 0.5286 | Lift: 1.0059 | PASS: False
#   [Weighted] Sup: 0.0140 | Conf: 0.4763 | Lift: 1.0197 | PASS: False
#
# FOV: Control_09_FOV_2 | Transactions: 2644
#   [Binary]   Sup: 0.0110 | Conf: 0.1706 | Lift: 1.2357 | PASS: False
#   [Weighted] Sup: 0.0106 | Conf: 0.1653 | Lift: 1.3852 | PASS: False
#
# FOV: Control_09_FOV_3 | Transactions: 2064
#   [Binary]   Sup: 0.0194 | Conf: 0.8000 | Lift: 1.1015 | PASS: False
#   [Weighted] Sup: 0.0180 | Conf: 0.7446 | Lift: 1.0859 | PASS: False
#
# FOV: Control_09_FOV_4 | Transactions: 1977
#   [Binary]   Sup: 0.0258 | Conf: 0.9444 | Lift: 1.0983 | PASS: False
#   [Weighted] Sup: 0.0236 | Conf: 0.8646 | Lift: 1.0864 | PASS: False
#
# FOV: Control_10_FOV_2 | Transactions: 1966
#   [Binary]   Sup: 0.0127 | Conf: 0.9259 | Lift: 0.9516 | PASS: False
#   [Weighted] Sup: 0.0127 | Conf: 0.9259 | Lift: 0.9665 | PASS: False
#
# FOV: Control_10_FOV_3 | Transactions: 1797
#   [Binary]   Sup: 0.0139 | Conf: 0.8929 | Lift: 0.9216 | PASS: False
#   [Weighted] Sup: 0.0131 | Conf: 0.8386 | Lift: 0.8889 | PASS: False
#
# FOV: Control_10_FOV_4 | Transactions: 2073
#   [Binary]   Sup: 0.0043 | Conf: 1.0000 | Lift: 1.0534 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.9524 | Lift: 1.0241 | PASS: False
#
# FOV: S_01_FOV_1 | Transactions: 5113
#   [Binary]   Sup: 0.0143 | Conf: 0.9733 | Lift: 1.0996 | PASS: False
#   [Weighted] Sup: 0.0141 | Conf: 0.9584 | Lift: 1.1205 | PASS: False
#
# FOV: S_01_FOV_2 | Transactions: 6563
#   [Binary]   Sup: 0.0378 | Conf: 0.6739 | Lift: 0.9785 | PASS: False
#   [Weighted] Sup: 0.0349 | Conf: 0.6232 | Lift: 0.9708 | PASS: False
#
# FOV: S_01_FOV_3 | Transactions: 6849
#   [Binary]   Sup: 0.0253 | Conf: 0.9153 | Lift: 1.0073 | PASS: False
#   [Weighted] Sup: 0.0245 | Conf: 0.8884 | Lift: 1.0083 | PASS: False
#
# FOV: S_01_FOV_4 | Transactions: 6070
#   [Binary]   Sup: 0.0269 | Conf: 0.8232 | Lift: 1.0858 | PASS: False
#   [Weighted] Sup: 0.0246 | Conf: 0.7546 | Lift: 1.0542 | PASS: False
#
# FOV: S_02_FOV_1 | Transactions: 6163
#   [Binary]   Sup: 0.0592 | Conf: 0.9481 | Lift: 1.1427 | PASS: False
#   [Weighted] Sup: 0.0572 | Conf: 0.9153 | Lift: 1.1639 | PASS: False
#
# FOV: S_02_FOV_2 | Transactions: 5802
#   [Binary]   Sup: 0.0527 | Conf: 0.9080 | Lift: 1.1063 | PASS: False
#   [Weighted] Sup: 0.0507 | Conf: 0.8737 | Lift: 1.1277 | PASS: False
#
# FOV: S_02_FOV_3 | Transactions: 6259
#   [Binary]   Sup: 0.0521 | Conf: 0.8468 | Lift: 1.2031 | PASS: True
#   [Weighted] Sup: 0.0491 | Conf: 0.7990 | Lift: 1.2099 | PASS: True
#
# FOV: S_02_FOV_4 | Transactions: 5914
#   [Binary]   Sup: 0.0561 | Conf: 0.8623 | Lift: 1.1125 | PASS: False
#   [Weighted] Sup: 0.0541 | Conf: 0.8314 | Lift: 1.1267 | PASS: False
#
# FOV: S_02_FOV_5 | Transactions: 5174
#   [Binary]   Sup: 0.0296 | Conf: 0.9053 | Lift: 1.1001 | PASS: False
#   [Weighted] Sup: 0.0293 | Conf: 0.8971 | Lift: 1.1581 | PASS: False
#
# FOV: S_03_FOV_1 | Transactions: 5245
#   [Binary]   Sup: 0.0334 | Conf: 0.8883 | Lift: 1.0775 | PASS: False
#   [Weighted] Sup: 0.0308 | Conf: 0.8188 | Lift: 1.0486 | PASS: False
#
# FOV: S_03_FOV_10 | Transactions: 5116
#   [Binary]   Sup: 0.0199 | Conf: 0.8226 | Lift: 1.1252 | PASS: False
#   [Weighted] Sup: 0.0179 | Conf: 0.7379 | Lift: 1.0910 | PASS: False
#
# FOV: S_03_FOV_2 | Transactions: 5494
#   [Binary]   Sup: 0.0173 | Conf: 0.8120 | Lift: 0.9579 | PASS: False
#   [Weighted] Sup: 0.0160 | Conf: 0.7498 | Lift: 0.9453 | PASS: False
#
# FOV: S_03_FOV_3 | Transactions: 6689
#   [Binary]   Sup: 0.0295 | Conf: 0.6417 | Lift: 0.9323 | PASS: False
#   [Weighted] Sup: 0.0273 | Conf: 0.5956 | Lift: 0.9294 | PASS: False
#
# FOV: S_03_FOV_4 | Transactions: 5343
#   [Binary]   Sup: 0.0146 | Conf: 0.7156 | Lift: 1.0204 | PASS: False
#   [Weighted] Sup: 0.0133 | Conf: 0.6543 | Lift: 1.0065 | PASS: False
#
# FOV: S_03_FOV_5 | Transactions: 5158
#   [Binary]   Sup: 0.0118 | Conf: 0.7922 | Lift: 0.9724 | PASS: False
#   [Weighted] Sup: 0.0116 | Conf: 0.7783 | Lift: 1.0083 | PASS: False
#
# FOV: S_03_FOV_6 | Transactions: 4794
#   [Binary]   Sup: 0.0292 | Conf: 0.8383 | Lift: 1.0098 | PASS: False
#   [Weighted] Sup: 0.0271 | Conf: 0.7775 | Lift: 0.9893 | PASS: False
#
# FOV: S_03_FOV_7 | Transactions: 5981
#   [Binary]   Sup: 0.0226 | Conf: 0.7418 | Lift: 1.1700 | PASS: False
#   [Weighted] Sup: 0.0209 | Conf: 0.6861 | Lift: 1.1842 | PASS: False
#
# FOV: S_03_FOV_8 | Transactions: 5875
#   [Binary]   Sup: 0.0208 | Conf: 0.8841 | Lift: 1.0134 | PASS: False
#   [Weighted] Sup: 0.0196 | Conf: 0.8357 | Lift: 0.9977 | PASS: False
#
# FOV: S_03_FOV_9 | Transactions: 4546
#   [Binary]   Sup: 0.0255 | Conf: 0.8345 | Lift: 0.9585 | PASS: False
#   [Weighted] Sup: 0.0241 | Conf: 0.7866 | Lift: 0.9311 | PASS: False
#
# FOV: S_04_FOV_1 | Transactions: 3501
#   [Binary]   Sup: 0.0328 | Conf: 0.8779 | Lift: 1.3450 | PASS: True
#   [Weighted] Sup: 0.0295 | Conf: 0.7887 | Lift: 1.3095 | PASS: True
#
# FOV: S_04_FOV_2 | Transactions: 3544
#   [Binary]   Sup: 0.0344 | Conf: 0.8472 | Lift: 1.0685 | PASS: False
#   [Weighted] Sup: 0.0334 | Conf: 0.8212 | Lift: 1.1061 | PASS: False
#
# FOV: Control_Colon_01_FOV_1 | Transactions: 1401
#   [Binary]   Sup: 0.0021 | Conf: 0.3750 | Lift: 0.4479 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.3071 | Lift: 0.4178 | PASS: False
#
# FOV: Control_Colon_01_FOV_2 | Transactions: 1778
#   [Binary]   Sup: 0.0247 | Conf: 0.9778 | Lift: 1.1202 | PASS: False
#   [Weighted] Sup: 0.0233 | Conf: 0.9198 | Lift: 1.1070 | PASS: False
#
# FOV: Control_Colon_01_FOV_3 | Transactions: 1624
#   [Binary]   Sup: 0.0105 | Conf: 0.9444 | Lift: 1.1646 | PASS: False
#   [Weighted] Sup: 0.0093 | Conf: 0.8371 | Lift: 1.1575 | PASS: False
#
# FOV: Control_Colon_01_FOV_4 | Transactions: 2046
#   [Binary]   Sup: 0.0166 | Conf: 0.5312 | Lift: 1.0869 | PASS: False
#   [Weighted] Sup: 0.0157 | Conf: 0.5020 | Lift: 1.0976 | PASS: False
#
# FOV: Control_Colon_01_FOV_5 | Transactions: 1877
#   [Binary]   Sup: 0.0186 | Conf: 0.9722 | Lift: 1.0585 | PASS: False
#   [Weighted] Sup: 0.0173 | Conf: 0.9046 | Lift: 1.0857 | PASS: False
#
# FOV: Control_Colon_01_FOV_6 | Transactions: 5270
#   [Binary]   Sup: 0.0139 | Conf: 0.8488 | Lift: 1.0258 | PASS: False
#   [Weighted] Sup: 0.0133 | Conf: 0.8128 | Lift: 1.0842 | PASS: False
#
# FOV: Control_Colon_01_FOV_7 | Transactions: 5502
#   [Binary]   Sup: 0.0115 | Conf: 0.5294 | Lift: 1.0950 | PASS: False
#   [Weighted] Sup: 0.0091 | Conf: 0.4206 | Lift: 0.9946 | PASS: False
#
# FOV: Control_Colon_02_FOV_1 | Transactions: 1743
#   [Binary]   Sup: 0.0264 | Conf: 0.6765 | Lift: 1.0398 | PASS: False
#   [Weighted] Sup: 0.0241 | Conf: 0.6170 | Lift: 1.0814 | PASS: False
#
# FOV: Control_Colon_02_FOV_2 | Transactions: 1901
#   [Binary]   Sup: 0.0494 | Conf: 0.8468 | Lift: 1.2931 | PASS: True
#   [Weighted] Sup: 0.0431 | Conf: 0.7377 | Lift: 1.3099 | PASS: True
#
# FOV: Control_Colon_02_FOV_3 | Transactions: 1706
#   [Binary]   Sup: 0.0756 | Conf: 0.7963 | Lift: 1.0276 | PASS: False
#   [Weighted] Sup: 0.0652 | Conf: 0.6870 | Lift: 1.0077 | PASS: False
#
# FOV: Control_Colon_02_FOV_4 | Transactions: 1882
#   [Binary]   Sup: 0.0537 | Conf: 0.8417 | Lift: 1.1503 | PASS: False
#   [Weighted] Sup: 0.0499 | Conf: 0.7821 | Lift: 1.1702 | PASS: False
#
# FOV: Control_Colon_02_FOV_5 | Transactions: 5686
#   [Binary]   Sup: 0.0301 | Conf: 0.5552 | Lift: 1.0401 | PASS: False
#   [Weighted] Sup: 0.0255 | Conf: 0.4700 | Lift: 1.0061 | PASS: False
#
# FOV: Control_Colon_02_FOV_6 | Transactions: 5706
#   [Binary]   Sup: 0.0338 | Conf: 0.6328 | Lift: 1.1719 | PASS: False
#   [Weighted] Sup: 0.0298 | Conf: 0.5576 | Lift: 1.1585 | PASS: False
#
# FOV: Control_Colon_03_FOV_1 | Transactions: 1672
#   [Binary]   Sup: 0.0179 | Conf: 0.6122 | Lift: 0.9694 | PASS: False
#   [Weighted] Sup: 0.0141 | Conf: 0.4810 | Lift: 0.9181 | PASS: False
#
# FOV: Control_Colon_03_FOV_2 | Transactions: 1846
#   [Binary]   Sup: 0.0108 | Conf: 0.4545 | Lift: 0.9612 | PASS: False
#   [Weighted] Sup: 0.0096 | Conf: 0.4022 | Lift: 1.0213 | PASS: False
#
# FOV: Control_Colon_03_FOV_3 | Transactions: 1850
#   [Binary]   Sup: 0.0178 | Conf: 0.4714 | Lift: 1.1660 | PASS: False
#   [Weighted] Sup: 0.0129 | Conf: 0.3417 | Lift: 1.0820 | PASS: False
#
# FOV: Control_Colon_03_FOV_4 | Transactions: 1834
#   [Binary]   Sup: 0.0065 | Conf: 0.6000 | Lift: 1.8714 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.3775 | Lift: 1.5521 | PASS: False
#
# FOV: Control_Colon_03_FOV_5 | Transactions: 5717
#   [Binary]   Sup: 0.0072 | Conf: 0.3130 | Lift: 0.7858 | PASS: False
#   [Weighted] Sup: 0.0053 | Conf: 0.2291 | Lift: 0.7191 | PASS: False
#
# FOV: Control_Colon_03_FOV_6 | Transactions: 6034
#   [Binary]   Sup: 0.0154 | Conf: 0.6118 | Lift: 1.0512 | PASS: False
#   [Weighted] Sup: 0.0125 | Conf: 0.4973 | Lift: 0.9973 | PASS: False
#
# FOV: Control_Colon_04_FOV_1 | Transactions: 2273
#   [Binary]   Sup: 0.0220 | Conf: 0.5747 | Lift: 1.2732 | PASS: True
#   [Weighted] Sup: 0.0219 | Conf: 0.5710 | Lift: 1.3756 | PASS: True
#
# FOV: Control_Colon_04_FOV_2 | Transactions: 2379
#   [Binary]   Sup: 0.0063 | Conf: 0.7500 | Lift: 1.6265 | PASS: False
#   [Weighted] Sup: 0.0059 | Conf: 0.6983 | Lift: 1.5851 | PASS: False
#
# FOV: Control_Colon_04_FOV_3 | Transactions: 2357
#   [Binary]   Sup: 0.0127 | Conf: 1.0000 | Lift: 1.5692 | PASS: True
#   [Weighted] Sup: 0.0113 | Conf: 0.8860 | Lift: 1.4782 | PASS: True
#
# FOV: Control_Colon_04_FOV_4 | Transactions: 2294
#   [Binary]   Sup: 0.0122 | Conf: 0.6667 | Lift: 1.1179 | PASS: False
#   [Weighted] Sup: 0.0112 | Conf: 0.6100 | Lift: 1.0624 | PASS: False
#
# FOV: Control_Colon_04_FOV_5 | Transactions: 7392
#   [Binary]   Sup: 0.0080 | Conf: 0.4155 | Lift: 0.8748 | PASS: False
#   [Weighted] Sup: 0.0073 | Conf: 0.3816 | Lift: 0.8645 | PASS: False
#
# FOV: Control_Colon_04_FOV_6 | Transactions: 7983
#   [Binary]   Sup: 0.0084 | Conf: 0.3545 | Lift: 0.6896 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.3159 | Lift: 0.6696 | PASS: False
#
#
# [Algorithm Comparison: CD8T_CD69+_CENTER -> Epithelial_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 6 / 77
# FOVs passing Weighted FP-Growth (Distance-decay): 6 / 77
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            6 |            6  (out of 77 valid FOVs)
# Support :       0.0244 |       0.0227
# Conf    :       0.7423 |       0.6899
# Lift    :       1.0487 |       1.0451
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0362 |       0.0336
# Conf    :       0.8030 |       0.7449
# Lift    :       1.2983 |       1.3059
#
# Visualizing Representative FOV: S_02_FOV_1 (385 matching antecedent cells)

# %% [markdown]
# ## Step 4: Run Evaluation on Mild Cohort (Stage 1)

# %%
evaluate_cohort("Mild", mild_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Mild
# ==============================================
#
# FOV: GVHD_03_FOV_1_R | Transactions: 2879
#   [Binary]   Sup: 0.0427 | Conf: 0.5748 | Lift: 0.9122 | PASS: False
#   [Weighted] Sup: 0.0401 | Conf: 0.5394 | Lift: 0.9120 | PASS: False
#
# FOV: GVHD_03_FOV_2 | Transactions: 2524
#   [Binary]   Sup: 0.0404 | Conf: 0.5025 | Lift: 0.8575 | PASS: False
#   [Weighted] Sup: 0.0359 | Conf: 0.4469 | Lift: 0.8089 | PASS: False
#
# FOV: GVHD_03_FOV_3_R | Transactions: 2615
#   [Binary]   Sup: 0.0249 | Conf: 0.7471 | Lift: 0.9983 | PASS: False
#   [Weighted] Sup: 0.0227 | Conf: 0.6822 | Lift: 0.9775 | PASS: False
#
# FOV: GVHD_03_FOV_4 | Transactions: 2443
#   [Binary]   Sup: 0.0348 | Conf: 0.6028 | Lift: 0.8057 | PASS: False
#   [Weighted] Sup: 0.0314 | Conf: 0.5432 | Lift: 0.7622 | PASS: False
#
# FOV: GVHD_04_FOV_1 | Transactions: 2177
#   [Binary]   Sup: 0.0073 | Conf: 0.8000 | Lift: 1.2787 | PASS: False
#   [Weighted] Sup: 0.0067 | Conf: 0.7246 | Lift: 1.1959 | PASS: False
#
# FOV: GVHD_04_FOV_2 | Transactions: 2031
#   [Binary]   Sup: 0.0034 | Conf: 0.7000 | Lift: 1.1230 | PASS: False
#   [Weighted] Sup: 0.0034 | Conf: 0.7000 | Lift: 1.2296 | PASS: False
#
# FOV: GVHD_04_FOV_3 | Transactions: 2340
#   [Binary]   Sup: 0.0043 | Conf: 0.5882 | Lift: 1.1338 | PASS: False
#   [Weighted] Sup: 0.0040 | Conf: 0.5458 | Lift: 1.1354 | PASS: False
#
# FOV: GVHD_05_FOV_1_R | Transactions: 1815
#   [Binary]   Sup: 0.0011 | Conf: 0.6667 | Lift: 0.8259 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.6667 | Lift: 0.8817 | PASS: False
#
# FOV: GVHD_05_FOV_2_R | Transactions: 2398
#   [Binary]   Sup: 0.0104 | Conf: 0.7143 | Lift: 0.9895 | PASS: False
#   [Weighted] Sup: 0.0085 | Conf: 0.5818 | Lift: 0.9198 | PASS: False
#
# FOV: GVHD_05_FOV_3_R | Transactions: 2244
#   [Binary]   Sup: 0.0205 | Conf: 0.7667 | Lift: 0.8611 | PASS: False
#   [Weighted] Sup: 0.0197 | Conf: 0.7372 | Lift: 0.8583 | PASS: False
#
# FOV: GVHD_07_FOV_1 | Transactions: 2137
#   [Binary]   Sup: 0.0014 | Conf: 1.0000 | Lift: 1.4469 | PASS: False
#   [Weighted] Sup: 0.0014 | Conf: 1.0000 | Lift: 1.4992 | PASS: False
#
# FOV: GVHD_07_FOV_3 | Transactions: 2411
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.4067 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 1.4443 | PASS: False
#
# FOV: GVHD_07_FOV_4 | Transactions: 2301
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_10_FOV_1 | Transactions: 1810
#   [Binary]   Sup: 0.0039 | Conf: 1.0000 | Lift: 1.1207 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 0.7878 | Lift: 0.9147 | PASS: False
#
# FOV: GVHD_10_FOV_2 | Transactions: 2395
#   [Binary]   Sup: 0.0029 | Conf: 0.8750 | Lift: 1.4665 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 0.8750 | Lift: 1.5370 | PASS: False
#
# FOV: GVHD_10_FOV_3 | Transactions: 1962
#   [Binary]   Sup: 0.0025 | Conf: 1.0000 | Lift: 1.1407 | PASS: False
#   [Weighted] Sup: 0.0022 | Conf: 0.8622 | Lift: 1.0362 | PASS: False
#
# FOV: GVHD_10_FOV_4 | Transactions: 2438
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 1.7340 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 1.9917 | PASS: False
#
# FOV: GVHD_12_FOV_1 | Transactions: 1769
#   [Binary]   Sup: 0.0006 | Conf: 0.5000 | Lift: 0.5773 | PASS: False
#   [Weighted] Sup: 0.0002 | Conf: 0.1560 | Lift: 0.1891 | PASS: False
#
# FOV: GVHD_12_FOV_2 | Transactions: 1703
#   [Binary]   Sup: 0.0029 | Conf: 1.0000 | Lift: 1.0670 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 1.0000 | Lift: 1.1013 | PASS: False
#
# FOV: GVHD_12_FOV_3 | Transactions: 1440
#   [Binary]   Sup: 0.0063 | Conf: 0.9000 | Lift: 0.9766 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 0.9000 | Lift: 1.0090 | PASS: False
#
# FOV: GVHD_12_FOV_4 | Transactions: 2318
#   [Binary]   Sup: 0.0043 | Conf: 1.0000 | Lift: 1.2194 | PASS: False
#   [Weighted] Sup: 0.0043 | Conf: 1.0000 | Lift: 1.3146 | PASS: False
#
# FOV: GVHD_12_FOV_5 | Transactions: 2492
#   [Binary]   Sup: 0.0020 | Conf: 1.0000 | Lift: 1.2127 | PASS: False
#   [Weighted] Sup: 0.0014 | Conf: 0.7109 | Lift: 0.8989 | PASS: False
#
# FOV: GVHD_13_FOV_1 | Transactions: 1462
#   [Binary]   Sup: 0.0062 | Conf: 0.8182 | Lift: 0.8960 | PASS: False
#   [Weighted] Sup: 0.0062 | Conf: 0.8182 | Lift: 0.9368 | PASS: False
#
# FOV: GVHD_13_FOV_2 | Transactions: 1661
#   [Binary]   Sup: 0.0006 | Conf: 1.0000 | Lift: 1.0682 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 1.0000 | Lift: 1.1092 | PASS: False
#
# FOV: GVHD_13_FOV_3 | Transactions: 1294
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 1.1041 | PASS: False
#   [Weighted] Sup: 0.0015 | Conf: 1.0000 | Lift: 1.1566 | PASS: False
#
# FOV: GVHD_15_FOV_1 | Transactions: 1493
#   [Binary]   Sup: 0.0033 | Conf: 0.8333 | Lift: 1.7979 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.5086 | Lift: 1.1854 | PASS: False
#
# FOV: GVHD_15_FOV_1_B | Transactions: 1816
#   [Binary]   Sup: 0.0028 | Conf: 0.5000 | Lift: 1.0145 | PASS: False
#   [Weighted] Sup: 0.0027 | Conf: 0.4944 | Lift: 1.1365 | PASS: False
#
# FOV: GVHD_15_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0029 | Conf: 1.0000 | Lift: 1.1650 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 1.0000 | Lift: 1.2113 | PASS: False
#
# FOV: GVHD_15_FOV_2_B | Transactions: 2040
#   [Binary]   Sup: 0.0020 | Conf: 0.8000 | Lift: 0.8860 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.8000 | Lift: 0.9143 | PASS: False
#
# FOV: GVHD_15_FOV_3 | Transactions: 2226
#   [Binary]   Sup: 0.0036 | Conf: 0.8889 | Lift: 1.3905 | PASS: False
#   [Weighted] Sup: 0.0034 | Conf: 0.8453 | Lift: 1.3879 | PASS: False
#
# FOV: GVHD_15_FOV_3_B | Transactions: 2470
#   [Binary]   Sup: 0.0024 | Conf: 1.0000 | Lift: 1.1602 | PASS: False
#   [Weighted] Sup: 0.0019 | Conf: 0.7932 | Lift: 0.9551 | PASS: False
#
# FOV: GVHD_16_FOV_1 | Transactions: 1912
#   [Binary]   Sup: 0.0052 | Conf: 0.9091 | Lift: 1.0249 | PASS: False
#   [Weighted] Sup: 0.0052 | Conf: 0.9091 | Lift: 1.0531 | PASS: False
#
# FOV: GVHD_16_FOV_2 | Transactions: 2166
#   [Binary]   Sup: 0.0037 | Conf: 0.8000 | Lift: 1.3774 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 0.7754 | Lift: 1.4275 | PASS: False
#
# FOV: GVHD_16_FOV_3 | Transactions: 2272
#   [Binary]   Sup: 0.0013 | Conf: 1.0000 | Lift: 4.7932 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 1.0000 | Lift: 5.0883 | PASS: False
#
# FOV: GVHD_17_FOV_1 | Transactions: 1503
#   [Binary]   Sup: 0.0013 | Conf: 1.0000 | Lift: 1.2609 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 1.0000 | Lift: 1.3489 | PASS: False
#
# FOV: GVHD_17_FOV_2 | Transactions: 1188
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_3 | Transactions: 1492
#   [Binary]   Sup: 0.0087 | Conf: 0.5200 | Lift: 0.6217 | PASS: False
#   [Weighted] Sup: 0.0071 | Conf: 0.4256 | Lift: 0.5492 | PASS: False
#
# FOV: GVHD_18_FOV_1 | Transactions: 2169
#   [Binary]   Sup: 0.0060 | Conf: 0.8667 | Lift: 1.1618 | PASS: False
#   [Weighted] Sup: 0.0051 | Conf: 0.7428 | Lift: 1.0333 | PASS: False
#
# FOV: GVHD_18_FOV_2 | Transactions: 2054
#   [Binary]   Sup: 0.0044 | Conf: 0.6923 | Lift: 1.0773 | PASS: False
#   [Weighted] Sup: 0.0044 | Conf: 0.6923 | Lift: 1.1231 | PASS: False
#
# FOV: GVHD_18_FOV_3 | Transactions: 2525
#   [Binary]   Sup: 0.0032 | Conf: 0.5333 | Lift: 0.9180 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 0.4925 | Lift: 0.8876 | PASS: False
#
# FOV: GVHD_18_FOV_4 | Transactions: 2344
#   [Binary]   Sup: 0.0141 | Conf: 0.8250 | Lift: 0.9347 | PASS: False
#   [Weighted] Sup: 0.0124 | Conf: 0.7258 | Lift: 0.8607 | PASS: False
#
# FOV: GVHD_19_FOV_1 | Transactions: 2205
#   [Binary]   Sup: 0.0195 | Conf: 0.7679 | Lift: 1.1132 | PASS: False
#   [Weighted] Sup: 0.0174 | Conf: 0.6847 | Lift: 1.0981 | PASS: False
#
# FOV: GVHD_19_FOV_2 | Transactions: 2173
#   [Binary]   Sup: 0.0129 | Conf: 0.8750 | Lift: 1.0516 | PASS: False
#   [Weighted] Sup: 0.0117 | Conf: 0.7977 | Lift: 1.0109 | PASS: False
#
# FOV: GVHD_19_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0147 | Conf: 0.4737 | Lift: 0.7652 | PASS: False
#   [Weighted] Sup: 0.0107 | Conf: 0.3464 | Lift: 0.6143 | PASS: False
#
# FOV: GVHD_19_FOV_4 | Transactions: 2250
#   [Binary]   Sup: 0.0160 | Conf: 0.5000 | Lift: 0.7093 | PASS: False
#   [Weighted] Sup: 0.0143 | Conf: 0.4461 | Lift: 0.6767 | PASS: False
#
# FOV: GVHD_20_FOV_1 | Transactions: 1526
#   [Binary]   Sup: 0.0118 | Conf: 0.7826 | Lift: 1.3081 | PASS: True
#   [Weighted] Sup: 0.0117 | Conf: 0.7744 | Lift: 1.4062 | PASS: True
#
# FOV: GVHD_20_FOV_2 | Transactions: 2003
#   [Binary]   Sup: 0.0035 | Conf: 0.5385 | Lift: 0.9314 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 0.5385 | Lift: 1.0085 | PASS: False
#
# FOV: GVHD_22_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0049 | Conf: 0.5882 | Lift: 1.0613 | PASS: False
#   [Weighted] Sup: 0.0047 | Conf: 0.5633 | Lift: 1.1433 | PASS: False
#
# FOV: GVHD_22_FOV_2 | Transactions: 1698
#   [Binary]   Sup: 0.0135 | Conf: 0.7419 | Lift: 1.1763 | PASS: False
#   [Weighted] Sup: 0.0114 | Conf: 0.6262 | Lift: 1.1507 | PASS: False
#
# FOV: GVHD_22_FOV_3 | Transactions: 1900
#   [Binary]   Sup: 0.0058 | Conf: 0.2075 | Lift: 0.4667 | PASS: False
#   [Weighted] Sup: 0.0044 | Conf: 0.1563 | Lift: 0.4343 | PASS: False
#
# FOV: GVHD_23_FOV_1 | Transactions: 2347
#   [Binary]   Sup: 0.0021 | Conf: 0.8333 | Lift: 0.9999 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.7144 | Lift: 0.8858 | PASS: False
#
# FOV: GVHD_23_FOV_2 | Transactions: 1039
#   [Binary]   Sup: 0.0010 | Conf: 1.0000 | Lift: 1.1834 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 1.0000 | Lift: 1.2660 | PASS: False
#
# FOV: GVHD_23_FOV_3 | Transactions: 1348
#   [Binary]   Sup: 0.0045 | Conf: 1.0000 | Lift: 1.1215 | PASS: False
#   [Weighted] Sup: 0.0034 | Conf: 0.7578 | Lift: 0.9015 | PASS: False
#
# FOV: GVHD_23_FOV_4 | Transactions: 1161
#   [Binary]   Sup: 0.0017 | Conf: 1.0000 | Lift: 1.2221 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 1.0000 | Lift: 1.3024 | PASS: False
#
# FOV: GVHD_27_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0266 | Conf: 0.4609 | Lift: 0.8478 | PASS: False
#   [Weighted] Sup: 0.0251 | Conf: 0.4348 | Lift: 0.8210 | PASS: False
#
# FOV: GVHD_27_FOV_2 | Transactions: 2738
#   [Binary]   Sup: 0.0047 | Conf: 0.3171 | Lift: 1.3607 | PASS: False
#   [Weighted] Sup: 0.0043 | Conf: 0.2868 | Lift: 1.4667 | PASS: False
#
# FOV: GVHD_27_FOV_3 | Transactions: 3061
#   [Binary]   Sup: 0.0114 | Conf: 0.2612 | Lift: 1.3460 | PASS: False
#   [Weighted] Sup: 0.0093 | Conf: 0.2123 | Lift: 1.2526 | PASS: False
#
# FOV: GVHD_27_FOV_4 | Transactions: 2161
#   [Binary]   Sup: 0.0241 | Conf: 0.8125 | Lift: 0.9733 | PASS: False
#   [Weighted] Sup: 0.0227 | Conf: 0.7654 | Lift: 0.9643 | PASS: False
#
# FOV: GVHD_27_FOV_5 | Transactions: 2416
#   [Binary]   Sup: 0.0877 | Conf: 0.6405 | Lift: 0.9623 | PASS: False
#   [Weighted] Sup: 0.0811 | Conf: 0.5923 | Lift: 0.9444 | PASS: False
#
# FOV: GVHD_28_FOV_1 | Transactions: 2142
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_28_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0009 | Conf: 0.5000 | Lift: 0.9417 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.5000 | Lift: 0.9780 | PASS: False
#
# FOV: GVHD_28_FOV_3 | Transactions: 2110
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4986 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.5599 | PASS: False
#
# FOV: GVHD_29_FOV_1 | Transactions: 2334
#   [Binary]   Sup: 0.0026 | Conf: 0.6000 | Lift: 0.9076 | PASS: False
#   [Weighted] Sup: 0.0023 | Conf: 0.5259 | Lift: 0.8497 | PASS: False
#
# FOV: GVHD_29_FOV_2 | Transactions: 2393
#   [Binary]   Sup: 0.0025 | Conf: 1.0000 | Lift: 1.1293 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.9974 | Lift: 1.1842 | PASS: False
#
# FOV: GVHD_29_FOV_3 | Transactions: 2233
#   [Binary]   Sup: 0.0013 | Conf: 1.0000 | Lift: 1.4662 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 1.0000 | Lift: 1.5201 | PASS: False
#
# FOV: GVHD_29_FOV_4 | Transactions: 2107
#   [Binary]   Sup: 0.0009 | Conf: 0.4000 | Lift: 0.7641 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.4000 | Lift: 0.8217 | PASS: False
#
# FOV: GVHD_30_FOV_1 | Transactions: 2235
#   [Binary]   Sup: 0.0067 | Conf: 0.7143 | Lift: 1.1502 | PASS: False
#   [Weighted] Sup: 0.0067 | Conf: 0.7143 | Lift: 1.2164 | PASS: False
#
# FOV: GVHD_30_FOV_2 | Transactions: 2267
#   [Binary]   Sup: 0.0040 | Conf: 0.6000 | Lift: 0.9878 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 0.5328 | Lift: 0.9070 | PASS: False
#
# FOV: GVHD_30_FOV_3 | Transactions: 2206
#   [Binary]   Sup: 0.0077 | Conf: 0.8947 | Lift: 1.4355 | PASS: False
#   [Weighted] Sup: 0.0074 | Conf: 0.8622 | Lift: 1.4467 | PASS: False
#
# FOV: GVHD_31_FOV_1 | Transactions: 2168
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.2283 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.2532 | PASS: False
#
# FOV: GVHD_31_FOV_2 | Transactions: 2315
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_31_FOV_3 | Transactions: 2372
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 2.1084 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 2.1971 | PASS: False
#
# FOV: GVHD_33_FOV_1 | Transactions: 1834
#   [Binary]   Sup: 0.0060 | Conf: 1.0000 | Lift: 1.0350 | PASS: False
#   [Weighted] Sup: 0.0060 | Conf: 1.0000 | Lift: 1.0514 | PASS: False
#
# FOV: GVHD_33_FOV_2 | Transactions: 1535
#   [Binary]   Sup: 0.0085 | Conf: 0.9286 | Lift: 1.0232 | PASS: False
#   [Weighted] Sup: 0.0077 | Conf: 0.8430 | Lift: 0.9580 | PASS: False
#
# FOV: GVHD_33_FOV_3 | Transactions: 1990
#   [Binary]   Sup: 0.0010 | Conf: 1.0000 | Lift: 1.0768 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 1.0000 | Lift: 1.0996 | PASS: False
#
# FOV: GVHD_34_FOV_1 | Transactions: 2224
#   [Binary]   Sup: 0.0076 | Conf: 1.0000 | Lift: 1.1656 | PASS: False
#   [Weighted] Sup: 0.0073 | Conf: 0.9566 | Lift: 1.1595 | PASS: False
#
# FOV: GVHD_34_FOV_2 | Transactions: 2254
#   [Binary]   Sup: 0.0275 | Conf: 0.8986 | Lift: 0.9865 | PASS: False
#   [Weighted] Sup: 0.0268 | Conf: 0.8759 | Lift: 0.9879 | PASS: False
#
# FOV: GVHD_35_FOV_1 | Transactions: 2240
#   [Binary]   Sup: 0.0312 | Conf: 0.3911 | Lift: 0.7711 | PASS: False
#   [Weighted] Sup: 0.0262 | Conf: 0.3279 | Lift: 0.7579 | PASS: False
#
# FOV: GVHD_35_FOV_2 | Transactions: 2120
#   [Binary]   Sup: 0.0208 | Conf: 0.6286 | Lift: 0.9864 | PASS: False
#   [Weighted] Sup: 0.0173 | Conf: 0.5241 | Lift: 0.9540 | PASS: False
#
# FOV: GVHD_36_FOV_1 | Transactions: 2179
#   [Binary]   Sup: 0.0138 | Conf: 0.9677 | Lift: 1.3649 | PASS: True
#   [Weighted] Sup: 0.0138 | Conf: 0.9677 | Lift: 1.4402 | PASS: True
#
# FOV: GVHD_36_FOV_2 | Transactions: 2409
#   [Binary]   Sup: 0.0112 | Conf: 0.6923 | Lift: 1.3257 | PASS: True
#   [Weighted] Sup: 0.0106 | Conf: 0.6542 | Lift: 1.2869 | PASS: True
#
# FOV: GVHD_36_FOV_3 | Transactions: 2318
#   [Binary]   Sup: 0.0211 | Conf: 0.7206 | Lift: 1.0311 | PASS: False
#   [Weighted] Sup: 0.0203 | Conf: 0.6920 | Lift: 1.0468 | PASS: False
#
# FOV: GVHD_38_FOV_1 | Transactions: 1760
#   [Binary]   Sup: 0.0017 | Conf: 1.0000 | Lift: 1.2239 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 1.0000 | Lift: 1.4760 | PASS: False
#
# FOV: GVHD_38_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0017 | Conf: 0.6667 | Lift: 1.1026 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 0.4842 | Lift: 0.8769 | PASS: False
#
# FOV: GVHD_39_FOV_1 | Transactions: 1942
#   [Binary]   Sup: 0.0077 | Conf: 0.7143 | Lift: 0.7922 | PASS: False
#   [Weighted] Sup: 0.0068 | Conf: 0.6282 | Lift: 0.7463 | PASS: False
#
# FOV: GVHD_39_FOV_2 | Transactions: 1508
#   [Binary]   Sup: 0.0166 | Conf: 0.8065 | Lift: 0.9110 | PASS: False
#   [Weighted] Sup: 0.0154 | Conf: 0.7502 | Lift: 0.8916 | PASS: False
#
# FOV: GVHD_39_FOV_3 | Transactions: 1957
#   [Binary]   Sup: 0.0066 | Conf: 0.8125 | Lift: 1.2119 | PASS: False
#   [Weighted] Sup: 0.0059 | Conf: 0.7168 | Lift: 1.1590 | PASS: False
#
# FOV: GVHD_40_FOV_1 | Transactions: 1386
#   [Binary]   Sup: 0.0152 | Conf: 0.7241 | Lift: 0.9191 | PASS: False
#   [Weighted] Sup: 0.0124 | Conf: 0.5945 | Lift: 0.8663 | PASS: False
#
# FOV: GVHD_40_FOV_2 | Transactions: 1447
#   [Binary]   Sup: 0.0104 | Conf: 0.9375 | Lift: 1.1766 | PASS: False
#   [Weighted] Sup: 0.0087 | Conf: 0.7900 | Lift: 1.0818 | PASS: False
#
# FOV: GVHD_40_FOV_3 | Transactions: 1147
#   [Binary]   Sup: 0.0122 | Conf: 0.7000 | Lift: 0.9293 | PASS: False
#   [Weighted] Sup: 0.0105 | Conf: 0.6038 | Lift: 0.9615 | PASS: False
#
# FOV: GVHD_40_FOV_4 | Transactions: 1437
#   [Binary]   Sup: 0.0021 | Conf: 1.0000 | Lift: 1.0748 | PASS: False
#   [Weighted] Sup: 0.0021 | Conf: 1.0000 | Lift: 1.1506 | PASS: False
#
# FOV: GVHD_42_FOV_1 | Transactions: 1768
#   [Binary]   Sup: 0.0085 | Conf: 0.7500 | Lift: 0.8308 | PASS: False
#   [Weighted] Sup: 0.0084 | Conf: 0.7432 | Lift: 0.8690 | PASS: False
#
# FOV: GVHD_42_FOV_2 | Transactions: 1913
#   [Binary]   Sup: 0.0047 | Conf: 0.8182 | Lift: 1.2829 | PASS: False
#   [Weighted] Sup: 0.0042 | Conf: 0.7297 | Lift: 1.2172 | PASS: False
#
# FOV: GVHD_42_FOV_3 | Transactions: 1989
#   [Binary]   Sup: 0.0090 | Conf: 0.8571 | Lift: 1.2239 | PASS: False
#   [Weighted] Sup: 0.0089 | Conf: 0.8414 | Lift: 1.2643 | PASS: False
#
# FOV: GVHD_42_FOV_4 | Transactions: 2275
#   [Binary]   Sup: 0.0018 | Conf: 0.6667 | Lift: 1.0911 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.6667 | Lift: 1.1496 | PASS: False
#
# FOV: GVHD_43_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.8423 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.9450 | Lift: 2.2176 | PASS: False
#
# FOV: GVHD_43_FOV_2 | Transactions: 2110
#   [Binary]   Sup: 0.0057 | Conf: 0.6316 | Lift: 0.8206 | PASS: False
#   [Weighted] Sup: 0.0042 | Conf: 0.4693 | Lift: 0.7161 | PASS: False
#
# FOV: GVHD_44_FOV_1 | Transactions: 1837
#   [Binary]   Sup: 0.0033 | Conf: 1.0000 | Lift: 1.3938 | PASS: False
#   [Weighted] Sup: 0.0033 | Conf: 1.0000 | Lift: 1.4466 | PASS: False
#
# FOV: GVHD_44_FOV_2 | Transactions: 1932
#   [Binary]   Sup: 0.0005 | Conf: 0.5000 | Lift: 6.0755 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 0.4562 | Lift: 9.3922 | PASS: False
#
# FOV: GVHD_45_FOV_1 | Transactions: 2357
#   [Binary]   Sup: 0.0102 | Conf: 0.6667 | Lift: 0.7551 | PASS: False
#   [Weighted] Sup: 0.0096 | Conf: 0.6254 | Lift: 0.7356 | PASS: False
#
# FOV: GVHD_45_FOV_2 | Transactions: 2096
#   [Binary]   Sup: 0.0086 | Conf: 0.6923 | Lift: 0.9994 | PASS: False
#   [Weighted] Sup: 0.0079 | Conf: 0.6395 | Lift: 1.0189 | PASS: False
#
# FOV: GVHD_47_FOV_1 | Transactions: 2145
#   [Binary]   Sup: 0.0117 | Conf: 0.8929 | Lift: 1.0101 | PASS: False
#   [Weighted] Sup: 0.0114 | Conf: 0.8724 | Lift: 1.0297 | PASS: False
#
# FOV: GVHD_47_FOV_2 | Transactions: 2091
#   [Binary]   Sup: 0.0057 | Conf: 1.0000 | Lift: 1.0382 | PASS: False
#   [Weighted] Sup: 0.0057 | Conf: 1.0000 | Lift: 1.0591 | PASS: False
#
# FOV: GVHD_49_FOV_1 | Transactions: 2531
#   [Binary]   Sup: 0.0122 | Conf: 0.8378 | Lift: 1.2021 | PASS: True
#   [Weighted] Sup: 0.0121 | Conf: 0.8306 | Lift: 1.2335 | PASS: True
#
# FOV: GVHD_49_FOV_2 | Transactions: 2426
#   [Binary]   Sup: 0.0194 | Conf: 0.7344 | Lift: 0.9436 | PASS: False
#   [Weighted] Sup: 0.0181 | Conf: 0.6866 | Lift: 0.9423 | PASS: False
#
# FOV: GVHD_49_FOV_3 | Transactions: 1967
#   [Binary]   Sup: 0.0081 | Conf: 0.8421 | Lift: 1.0200 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.7738 | Lift: 0.9564 | PASS: False
#
# FOV: GVHD_50_FOV_1 | Transactions: 2444
#   [Binary]   Sup: 0.0020 | Conf: 0.5000 | Lift: 0.8201 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.5000 | Lift: 0.8409 | PASS: False
#
# FOV: GVHD_50_FOV_2 | Transactions: 2514
#   [Binary]   Sup: 0.0004 | Conf: 0.1250 | Lift: 0.2436 | PASS: False
#   [Weighted] Sup: 0.0001 | Conf: 0.0369 | Lift: 0.0762 | PASS: False
#
# FOV: GVHD_50_FOV_3 | Transactions: 2088
#   [Binary]   Sup: 0.0010 | Conf: 0.4000 | Lift: 0.5587 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.4000 | Lift: 0.5693 | PASS: False
#
# FOV: GVHD_50_FOV_4 | Transactions: 2225
#   [Binary]   Sup: 0.0027 | Conf: 0.8571 | Lift: 1.2647 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 0.7504 | Lift: 1.1435 | PASS: False
#
# FOV: GVHD_51_FOV_1 | Transactions: 2527
#   [Binary]   Sup: 0.0202 | Conf: 0.8644 | Lift: 0.9535 | PASS: False
#   [Weighted] Sup: 0.0197 | Conf: 0.8455 | Lift: 0.9676 | PASS: False
#
# FOV: GVHD_51_FOV_2 | Transactions: 2273
#   [Binary]   Sup: 0.0590 | Conf: 1.0000 | Lift: 1.0049 | PASS: False
#   [Weighted] Sup: 0.0583 | Conf: 0.9886 | Lift: 0.9998 | PASS: False
#
# FOV: GVHD_51_FOV_3 | Transactions: 2210
#   [Binary]   Sup: 0.0081 | Conf: 1.0000 | Lift: 1.0005 | PASS: False
#   [Weighted] Sup: 0.0081 | Conf: 1.0000 | Lift: 1.0018 | PASS: False
#
# FOV: GVHD_51_FOV_4 | Transactions: 1873
#   [Binary]   Sup: 0.0037 | Conf: 0.8750 | Lift: 0.9344 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 0.8288 | Lift: 0.9215 | PASS: False
#
# FOV: GVHD_52_FOV_1 | Transactions: 2407
#   [Binary]   Sup: 0.0158 | Conf: 0.9744 | Lift: 0.9988 | PASS: False
#   [Weighted] Sup: 0.0158 | Conf: 0.9744 | Lift: 1.0155 | PASS: False
#
# FOV: GVHD_52_FOV_2 | Transactions: 2624
#   [Binary]   Sup: 0.0217 | Conf: 0.9194 | Lift: 1.0595 | PASS: False
#   [Weighted] Sup: 0.0216 | Conf: 0.9144 | Lift: 1.0802 | PASS: False
#
# FOV: GVHD_52_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0184 | Conf: 0.9574 | Lift: 1.0012 | PASS: False
#   [Weighted] Sup: 0.0176 | Conf: 0.9162 | Lift: 0.9753 | PASS: False
#
# FOV: GVHD_52_FOV_4 | Transactions: 2201
#   [Binary]   Sup: 0.0277 | Conf: 1.0000 | Lift: 1.0848 | PASS: False
#   [Weighted] Sup: 0.0277 | Conf: 0.9996 | Lift: 1.1101 | PASS: False
#
# FOV: GVHD_53_FOV_1 | Transactions: 2420
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_2 | Transactions: 2375
#   [Binary]   Sup: 0.0046 | Conf: 1.0000 | Lift: 1.3784 | PASS: False
#   [Weighted] Sup: 0.0040 | Conf: 0.8554 | Lift: 1.3057 | PASS: False
#
# FOV: GVHD_53_FOV_3 | Transactions: 2707
#   [Binary]   Sup: 0.0059 | Conf: 0.8889 | Lift: 1.0349 | PASS: False
#   [Weighted] Sup: 0.0053 | Conf: 0.7979 | Lift: 0.9997 | PASS: False
#
# FOV: GVHD_53_FOV_4 | Transactions: 2668
#   [Binary]   Sup: 0.0030 | Conf: 0.5333 | Lift: 0.7293 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.4377 | Lift: 0.6797 | PASS: False
#
# FOV: GVHD_54_FOV_1 | Transactions: 2263
#   [Binary]   Sup: 0.0027 | Conf: 0.5455 | Lift: 1.1493 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 0.4872 | Lift: 1.1405 | PASS: False
#
# FOV: GVHD_54_FOV_2 | Transactions: 2289
#   [Binary]   Sup: 0.0039 | Conf: 1.0000 | Lift: 1.1293 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 0.9196 | Lift: 1.0738 | PASS: False
#
# FOV: GVHD_54_FOV_3 | Transactions: 2688
#   [Binary]   Sup: 0.0060 | Conf: 0.3404 | Lift: 0.6150 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.2365 | Lift: 0.4841 | PASS: False
#
# FOV: GVHD_54_FOV_4 | Transactions: 2739
#   [Binary]   Sup: 0.0091 | Conf: 0.6250 | Lift: 1.2881 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.5118 | Lift: 1.1965 | PASS: False
#
# FOV: GVHD_55_FOV_1 | Transactions: 2553
#   [Binary]   Sup: 0.0576 | Conf: 0.5307 | Lift: 0.8113 | PASS: False
#   [Weighted] Sup: 0.0487 | Conf: 0.4492 | Lift: 0.7446 | PASS: False
#
# FOV: GVHD_55_FOV_2 | Transactions: 2216
#   [Binary]   Sup: 0.0090 | Conf: 0.9091 | Lift: 1.0553 | PASS: False
#   [Weighted] Sup: 0.0087 | Conf: 0.8734 | Lift: 1.0426 | PASS: False
#
# FOV: GVHD_55_FOV_3 | Transactions: 1786
#   [Binary]   Sup: 0.0084 | Conf: 0.9375 | Lift: 1.2514 | PASS: False
#   [Weighted] Sup: 0.0080 | Conf: 0.8958 | Lift: 1.2414 | PASS: False
#
# FOV: GVHD_56_FOV_1 | Transactions: 2237
#   [Binary]   Sup: 0.0036 | Conf: 0.8889 | Lift: 0.9648 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 0.8889 | Lift: 0.9914 | PASS: False
#
# FOV: GVHD_56_FOV_2 | Transactions: 2424
#   [Binary]   Sup: 0.0029 | Conf: 0.6364 | Lift: 0.7602 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 0.6357 | Lift: 0.8121 | PASS: False
#
# FOV: GVHD_56_FOV_3 | Transactions: 2278
#   [Binary]   Sup: 0.0026 | Conf: 1.0000 | Lift: 1.3039 | PASS: False
#   [Weighted] Sup: 0.0023 | Conf: 0.8788 | Lift: 1.1810 | PASS: False
#
# FOV: GVHD_56_FOV_4 | Transactions: 2406
#   [Binary]   Sup: 0.0025 | Conf: 0.7500 | Lift: 1.0728 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.7500 | Lift: 1.1218 | PASS: False
#
# FOV: GVHD_58_FOV_1 | Transactions: 2377
#   [Binary]   Sup: 0.0101 | Conf: 0.9231 | Lift: 0.9875 | PASS: False
#   [Weighted] Sup: 0.0101 | Conf: 0.9231 | Lift: 1.0105 | PASS: False
#
# FOV: GVHD_58_FOV_2 | Transactions: 2628
#   [Binary]   Sup: 0.0068 | Conf: 0.6000 | Lift: 0.8888 | PASS: False
#   [Weighted] Sup: 0.0068 | Conf: 0.6000 | Lift: 0.9243 | PASS: False
#
# FOV: GVHD_58_FOV_3 | Transactions: 2730
#   [Binary]   Sup: 0.0081 | Conf: 0.7333 | Lift: 1.2703 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.6836 | Lift: 1.2306 | PASS: False
#
# FOV: GVHD_58_FOV_4 | Transactions: 2447
#   [Binary]   Sup: 0.0143 | Conf: 0.7778 | Lift: 1.0091 | PASS: False
#   [Weighted] Sup: 0.0136 | Conf: 0.7401 | Lift: 1.0075 | PASS: False
#
# FOV: GVHD_59_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0029 | Conf: 0.8571 | Lift: 1.7286 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 0.8571 | Lift: 1.8178 | PASS: False
#
# FOV: GVHD_59_FOV_2 | Transactions: 1953
#   [Binary]   Sup: 0.0010 | Conf: 1.0000 | Lift: 1.6357 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 1.0000 | Lift: 1.7506 | PASS: False
#
# FOV: GVHD_59_FOV_3 | Transactions: 1993
#   [Binary]   Sup: 0.0035 | Conf: 0.6364 | Lift: 0.9164 | PASS: False
#   [Weighted] Sup: 0.0031 | Conf: 0.5689 | Lift: 0.8666 | PASS: False
#
# FOV: GVHD_60_FOV_1 | Transactions: 1962
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_60_FOV_2 | Transactions: 1949
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_60_FOV_3 | Transactions: 2138
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: CD8T_CD69+_CENTER -> Epithelial_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 4 / 143
# FOVs passing Weighted FP-Growth (Distance-decay): 4 / 143
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            4 |            4  (out of 143 valid FOVs)
# Support :       0.0094 |       0.0087
# Conf    :       0.6667 |       0.6144
# Lift    :       0.9386 |       0.9164
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0123 |       0.0120
# Conf    :       0.8154 |       0.8004
# Lift    :       1.2863 |       1.3222
#
# Visualizing Representative FOV: GVHD_27_FOV_5 (331 matching antecedent cells)

# %% [markdown]
# ## Step 5: Run Evaluation on Severe Cohort (Stage 3)

# %%
evaluate_cohort("Severe", severe_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Severe
# ==============================================
#
# FOV: GVHD_01_FOV_1 | Transactions: 1801
#   [Binary]   Sup: 0.0172 | Conf: 0.9394 | Lift: 1.0521 | PASS: False
#   [Weighted] Sup: 0.0165 | Conf: 0.9011 | Lift: 1.0481 | PASS: False
#
# FOV: GVHD_01_FOV_2_R | Transactions: 2040
#   [Binary]   Sup: 0.0328 | Conf: 0.5038 | Lift: 0.7997 | PASS: False
#   [Weighted] Sup: 0.0281 | Conf: 0.4314 | Lift: 0.7516 | PASS: False
#
# FOV: GVHD_01_FOV_3_R | Transactions: 1852
#   [Binary]   Sup: 0.0043 | Conf: 0.6154 | Lift: 0.8043 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.5850 | Lift: 0.8192 | PASS: False
#
# FOV: GVHD_01_FOV_4 | Transactions: 1937
#   [Binary]   Sup: 0.0093 | Conf: 1.0000 | Lift: 1.0358 | PASS: False
#   [Weighted] Sup: 0.0086 | Conf: 0.9247 | Lift: 0.9904 | PASS: False
#
# FOV: GVHD_01_FOV_5 | Transactions: 2103
#   [Binary]   Sup: 0.0162 | Conf: 0.7907 | Lift: 0.9886 | PASS: False
#   [Weighted] Sup: 0.0152 | Conf: 0.7452 | Lift: 0.9804 | PASS: False
#
# FOV: GVHD_01_FOV_6_R | Transactions: 2010
#   [Binary]   Sup: 0.0129 | Conf: 0.8966 | Lift: 1.1604 | PASS: False
#   [Weighted] Sup: 0.0127 | Conf: 0.8817 | Lift: 1.2240 | PASS: True
#
# FOV: GVHD_01_FOV_7 | Transactions: 2066
#   [Binary]   Sup: 0.0116 | Conf: 0.5106 | Lift: 0.9897 | PASS: False
#   [Weighted] Sup: 0.0104 | Conf: 0.4590 | Lift: 0.9636 | PASS: False
#
# FOV: GVHD_02_FOV_1_R | Transactions: 1977
#   [Binary]   Sup: 0.0010 | Conf: 0.2500 | Lift: 0.4628 | PASS: False
#   [Weighted] Sup: 0.0007 | Conf: 0.1848 | Lift: 0.3942 | PASS: False
#
# FOV: GVHD_02_FOV_2_R | Transactions: 1722
#   [Binary]   Sup: 0.0023 | Conf: 0.6667 | Lift: 1.6662 | PASS: False
#   [Weighted] Sup: 0.0023 | Conf: 0.6667 | Lift: 2.0729 | PASS: False
#
# FOV: GVHD_06_FOV_1 | Transactions: 2174
#   [Binary]   Sup: 0.0055 | Conf: 0.1875 | Lift: 0.8528 | PASS: False
#   [Weighted] Sup: 0.0028 | Conf: 0.0954 | Lift: 0.6713 | PASS: False
#
# FOV: GVHD_06_FOV_2 | Transactions: 2265
#   [Binary]   Sup: 0.0009 | Conf: 0.0952 | Lift: 3.9221 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 0.0650 | Lift: 4.4452 | PASS: False
#
# FOV: GVHD_06_FOV_3 | Transactions: 1998
#   [Binary]   Sup: 0.0080 | Conf: 0.3810 | Lift: 2.0683 | PASS: False
#   [Weighted] Sup: 0.0068 | Conf: 0.3212 | Lift: 2.3743 | PASS: False
#
# FOV: GVHD_06_FOV_4 | Transactions: 2040
#   [Binary]   Sup: 0.0093 | Conf: 0.2088 | Lift: 0.8434 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.1680 | Lift: 0.9040 | PASS: False
#
# FOV: GVHD_06_FOV_5 | Transactions: 2233
#   [Binary]   Sup: 0.0004 | Conf: 0.2000 | Lift: 7.5695 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 0.2000 | Lift: 9.6324 | PASS: False
#
# FOV: GVHD_08_FOV_1 | Transactions: 2672
#   [Binary]   Sup: 0.0022 | Conf: 0.0438 | Lift: 0.8015 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.0213 | Lift: 0.6347 | PASS: False
#
# FOV: GVHD_08_FOV_2 | Transactions: 2496
#   [Binary]   Sup: 0.0020 | Conf: 0.1064 | Lift: 0.9871 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.0600 | Lift: 0.8280 | PASS: False
#
# FOV: GVHD_08_FOV_3 | Transactions: 2107
#   [Binary]   Sup: 0.0014 | Conf: 0.1765 | Lift: 1.7056 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.1181 | Lift: 1.5002 | PASS: False
#
# FOV: GVHD_08_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0018 | Conf: 0.0851 | Lift: 0.7089 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.0520 | Lift: 0.5701 | PASS: False
#
# FOV: GVHD_09_FOV_1 | Transactions: 2477
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_09_FOV_2 | Transactions: 2121
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0271 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0400 | PASS: False
#
# FOV: GVHD_09_FOV_3 | Transactions: 2765
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_09_FOV_4 | Transactions: 2233
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.3143 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.3666 | PASS: False
#
# FOV: GVHD_11_FOV_1 | Transactions: 2608
#   [Binary]   Sup: 0.0023 | Conf: 0.1538 | Lift: 0.9810 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.1207 | Lift: 1.1276 | PASS: False
#
# FOV: GVHD_11_FOV_2 | Transactions: 2600
#   [Binary]   Sup: 0.0038 | Conf: 0.2083 | Lift: 0.7310 | PASS: False
#   [Weighted] Sup: 0.0031 | Conf: 0.1678 | Lift: 0.7076 | PASS: False
#
# FOV: GVHD_11_FOV_3 | Transactions: 2441
#   [Binary]   Sup: 0.0037 | Conf: 0.4737 | Lift: 0.9668 | PASS: False
#   [Weighted] Sup: 0.0031 | Conf: 0.3979 | Lift: 1.0023 | PASS: False
#
# FOV: GVHD_11_FOV_4 | Transactions: 1796
#   [Binary]   Sup: 0.0028 | Conf: 0.5556 | Lift: 1.6119 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.3665 | Lift: 1.3229 | PASS: False
#
# FOV: GVHD_14_FOV_1 | Transactions: 2206
#   [Binary]   Sup: 0.0036 | Conf: 0.3077 | Lift: 0.5714 | PASS: False
#   [Weighted] Sup: 0.0033 | Conf: 0.2830 | Lift: 0.5582 | PASS: False
#
# FOV: GVHD_14_FOV_2 | Transactions: 2210
#   [Binary]   Sup: 0.0439 | Conf: 0.6736 | Lift: 1.0930 | PASS: False
#   [Weighted] Sup: 0.0402 | Conf: 0.6169 | Lift: 1.0403 | PASS: False
#
# FOV: GVHD_14_FOV_3 | Transactions: 2000
#   [Binary]   Sup: 0.0625 | Conf: 0.7911 | Lift: 0.8443 | PASS: False
#   [Weighted] Sup: 0.0595 | Conf: 0.7536 | Lift: 0.8200 | PASS: False
#
# FOV: GVHD_14_FOV_4 | Transactions: 2703
#   [Binary]   Sup: 0.0174 | Conf: 0.5402 | Lift: 1.1408 | PASS: False
#   [Weighted] Sup: 0.0164 | Conf: 0.5088 | Lift: 1.1260 | PASS: False
#
# FOV: GVHD_14_FOV_5 | Transactions: 2412
#   [Binary]   Sup: 0.0091 | Conf: 0.4074 | Lift: 0.7049 | PASS: False
#   [Weighted] Sup: 0.0084 | Conf: 0.3771 | Lift: 0.6969 | PASS: False
#
# FOV: GVHD_21_FOV_1 | Transactions: 1340
#   [Binary]   Sup: 0.0149 | Conf: 0.6897 | Lift: 1.0733 | PASS: False
#   [Weighted] Sup: 0.0134 | Conf: 0.6203 | Lift: 1.0453 | PASS: False
#
# FOV: GVHD_21_FOV_2 | Transactions: 1840
#   [Binary]   Sup: 0.0141 | Conf: 0.8387 | Lift: 1.1853 | PASS: False
#   [Weighted] Sup: 0.0141 | Conf: 0.8387 | Lift: 1.2323 | PASS: True
#
# FOV: GVHD_21_FOV_3 | Transactions: 2570
#   [Binary]   Sup: 0.0140 | Conf: 0.8182 | Lift: 2.0514 | PASS: True
#   [Weighted] Sup: 0.0125 | Conf: 0.7315 | Lift: 2.0374 | PASS: True
#
# FOV: GVHD_21_FOV_4 | Transactions: 1956
#   [Binary]   Sup: 0.0368 | Conf: 0.7500 | Lift: 0.9879 | PASS: False
#   [Weighted] Sup: 0.0312 | Conf: 0.6364 | Lift: 0.9655 | PASS: False
#
# FOV: GVHD_24_FOV_1 | Transactions: 2262
#   [Binary]   Sup: 0.0004 | Conf: 0.0278 | Lift: 0.1945 | PASS: False
#   [Weighted] Sup: 0.0001 | Conf: 0.0087 | Lift: 0.1001 | PASS: False
#
# FOV: GVHD_24_FOV_2 | Transactions: 2001
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_24_FOV_3 | Transactions: 1589
#   [Binary]   Sup: 0.0019 | Conf: 0.6000 | Lift: 1.4578 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 0.5326 | Lift: 1.7799 | PASS: False
#
# FOV: GVHD_24_FOV_4 | Transactions: 1483
#   [Binary]   Sup: 0.0034 | Conf: 0.3846 | Lift: 1.4049 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.2817 | Lift: 1.3107 | PASS: False
#
# FOV: GVHD_25_FOV_1 | Transactions: 2667
#   [Binary]   Sup: 0.0094 | Conf: 0.7143 | Lift: 1.2362 | PASS: False
#   [Weighted] Sup: 0.0088 | Conf: 0.6678 | Lift: 1.2386 | PASS: False
#
# FOV: GVHD_25_FOV_2 | Transactions: 2589
#   [Binary]   Sup: 0.0042 | Conf: 0.1930 | Lift: 0.6349 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.1844 | Lift: 0.6923 | PASS: False
#
# FOV: GVHD_25_FOV_3 | Transactions: 2320
#   [Binary]   Sup: 0.0237 | Conf: 0.6790 | Lift: 1.0105 | PASS: False
#   [Weighted] Sup: 0.0219 | Conf: 0.6273 | Lift: 0.9995 | PASS: False
#
# FOV: GVHD_25_FOV_4 | Transactions: 2276
#   [Binary]   Sup: 0.0127 | Conf: 0.7436 | Lift: 1.4115 | PASS: True
#   [Weighted] Sup: 0.0119 | Conf: 0.6924 | Lift: 1.4157 | PASS: True
#
# FOV: GVHD_26_FOV_1 | Transactions: 2686
#   [Binary]   Sup: 0.0015 | Conf: 0.4444 | Lift: 9.5502 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.2803 | Lift: 9.3891 | PASS: False
#
# FOV: GVHD_26_FOV_2 | Transactions: 2425
#   [Binary]   Sup: 0.0004 | Conf: 0.0435 | Lift: 3.1010 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 0.0373 | Lift: 5.3021 | PASS: False
#
# FOV: GVHD_26_FOV_3 | Transactions: 2362
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_4 | Transactions: 2534
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_1 | Transactions: 2579
#   [Binary]   Sup: 0.0004 | Conf: 0.0588 | Lift: 0.9787 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 0.0488 | Lift: 1.4774 | PASS: False
#
# FOV: GVHD_32_FOV_2 | Transactions: 1867
#   [Binary]   Sup: 0.0305 | Conf: 0.7125 | Lift: 0.9724 | PASS: False
#   [Weighted] Sup: 0.0278 | Conf: 0.6489 | Lift: 0.9422 | PASS: False
#
# FOV: GVHD_32_FOV_3 | Transactions: 2197
#   [Binary]   Sup: 0.0055 | Conf: 0.1379 | Lift: 0.4298 | PASS: False
#   [Weighted] Sup: 0.0052 | Conf: 0.1323 | Lift: 0.4657 | PASS: False
#
# FOV: GVHD_32_FOV_4 | Transactions: 1765
#   [Binary]   Sup: 0.0164 | Conf: 0.2788 | Lift: 0.6687 | PASS: False
#   [Weighted] Sup: 0.0142 | Conf: 0.2409 | Lift: 0.6455 | PASS: False
#
# FOV: GVHD_37_FOV_1 | Transactions: 1821
#   [Binary]   Sup: 0.0077 | Conf: 1.0000 | Lift: 1.1786 | PASS: False
#   [Weighted] Sup: 0.0073 | Conf: 0.9490 | Lift: 1.1773 | PASS: False
#
# FOV: GVHD_37_FOV_2 | Transactions: 2118
#   [Binary]   Sup: 0.0047 | Conf: 0.7143 | Lift: 0.8581 | PASS: False
#   [Weighted] Sup: 0.0044 | Conf: 0.6662 | Lift: 0.8208 | PASS: False
#
# FOV: GVHD_37_FOV_3 | Transactions: 1431
#   [Binary]   Sup: 0.0119 | Conf: 0.8947 | Lift: 1.1704 | PASS: False
#   [Weighted] Sup: 0.0104 | Conf: 0.7850 | Lift: 1.1285 | PASS: False
#
# FOV: GVHD_37_FOV_4 | Transactions: 1596
#   [Binary]   Sup: 0.0063 | Conf: 0.7692 | Lift: 1.1474 | PASS: False
#   [Weighted] Sup: 0.0052 | Conf: 0.6336 | Lift: 1.1469 | PASS: False
#
# FOV: GVHD_41_FOV_1 | Transactions: 1896
#   [Binary]   Sup: 0.0079 | Conf: 0.8824 | Lift: 0.9887 | PASS: False
#   [Weighted] Sup: 0.0079 | Conf: 0.8824 | Lift: 1.0312 | PASS: False
#
# FOV: GVHD_41_FOV_2 | Transactions: 2102
#   [Binary]   Sup: 0.0076 | Conf: 0.8889 | Lift: 1.0788 | PASS: False
#   [Weighted] Sup: 0.0066 | Conf: 0.7750 | Lift: 1.0008 | PASS: False
#
# FOV: GVHD_41_FOV_3 | Transactions: 2569
#   [Binary]   Sup: 0.0160 | Conf: 0.6406 | Lift: 1.1883 | PASS: False
#   [Weighted] Sup: 0.0139 | Conf: 0.5570 | Lift: 1.1837 | PASS: False
#
# FOV: GVHD_41_FOV_4 | Transactions: 2023
#   [Binary]   Sup: 0.0119 | Conf: 0.6154 | Lift: 0.7864 | PASS: False
#   [Weighted] Sup: 0.0107 | Conf: 0.5530 | Lift: 0.7592 | PASS: False
#
# FOV: GVHD_48_FOV_1 | Transactions: 2528
#   [Binary]   Sup: 0.0047 | Conf: 0.4138 | Lift: 0.8484 | PASS: False
#   [Weighted] Sup: 0.0045 | Conf: 0.3890 | Lift: 0.8454 | PASS: False
#
# FOV: GVHD_48_FOV_2 | Transactions: 2151
#   [Binary]   Sup: 0.0200 | Conf: 0.8113 | Lift: 0.9685 | PASS: False
#   [Weighted] Sup: 0.0186 | Conf: 0.7537 | Lift: 0.9442 | PASS: False
#
# FOV: GVHD_48_FOV_3 | Transactions: 2388
#   [Binary]   Sup: 0.0050 | Conf: 0.4615 | Lift: 0.6457 | PASS: False
#   [Weighted] Sup: 0.0047 | Conf: 0.4352 | Lift: 0.6597 | PASS: False
#
# FOV: GVHD_48_FOV_4 | Transactions: 2989
#   [Binary]   Sup: 0.0070 | Conf: 0.3333 | Lift: 1.3041 | PASS: False
#   [Weighted] Sup: 0.0052 | Conf: 0.2470 | Lift: 1.2142 | PASS: False
#
# FOV: GVHD_48_FOV_5 | Transactions: 2740
#   [Binary]   Sup: 0.0113 | Conf: 0.6889 | Lift: 0.9414 | PASS: False
#   [Weighted] Sup: 0.0103 | Conf: 0.6274 | Lift: 0.9224 | PASS: False
#
# FOV: GVHD_57_FOV_1 | Transactions: 2427
#   [Binary]   Sup: 0.0041 | Conf: 0.2222 | Lift: 0.4820 | PASS: False
#   [Weighted] Sup: 0.0039 | Conf: 0.2084 | Lift: 0.4978 | PASS: False
#
# FOV: GVHD_57_FOV_2 | Transactions: 2178
#   [Binary]   Sup: 0.0101 | Conf: 1.0000 | Lift: 1.0366 | PASS: False
#   [Weighted] Sup: 0.0100 | Conf: 0.9867 | Lift: 1.0391 | PASS: False
#
# FOV: GVHD_57_FOV_3 | Transactions: 2036
#   [Binary]   Sup: 0.0172 | Conf: 0.8974 | Lift: 0.9698 | PASS: False
#   [Weighted] Sup: 0.0163 | Conf: 0.8487 | Lift: 0.9437 | PASS: False
#
# FOV: GVHD_57_FOV_4 | Transactions: 2196
#   [Binary]   Sup: 0.0164 | Conf: 1.0000 | Lift: 1.0186 | PASS: False
#   [Weighted] Sup: 0.0164 | Conf: 0.9978 | Lift: 1.0316 | PASS: False
#
#
# [Algorithm Comparison: CD8T_CD69+_CENTER -> Epithelial_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 2 / 68
# FOVs passing Weighted FP-Growth (Distance-decay): 4 / 68
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            2 |            4  (out of 68 valid FOVs)
# Support :       0.0092 |       0.0083
# Conf    :       0.4975 |       0.4490
# Lift    :       1.0194 |       1.0028
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0134 |       0.0229
# Conf    :       0.7831 |       0.7745
# Lift    :       1.7064 |       0.7925
#
# Visualizing Representative FOV: GVHD_14_FOV_3 (158 matching antecedent cells)
