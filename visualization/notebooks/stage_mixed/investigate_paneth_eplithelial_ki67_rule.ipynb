# %% [markdown]
# # Investigation: Paneth -> Epithelial_Ki67+ rule (Multi-Stage Evaluation)
#
# This notebook investigates the association rule **Paneth -> Epithelial_Ki67+** across different disease stages.

# %% [markdown]
# **What it represents:** Paneth cells supporting Ki67+ epithelial stem/amplifying cells at crypt base (duodenum-specific).
# **Expected pattern:** High in controls, reduced in aHSCT (mild to severe); limited signal in colon.

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.filterwarnings('ignore')

# Add root to path for utils
sys.path.append(os.path.abspath('../../../'))
from utils.rules import build_cell_item_token, passes_rule_support_policy, _extract_base_lineage

# --- Notebook config (no constants.py) ---
USE_FUNCTIONAL_MARKERS = True
CELLTYPE_MARKER_THRESHOLDS = {
    'Epithelial': {'Ki67': 2.5, 'HLADRDPDQ': 1.75},
    'CD8T': {'Ki67': 2.5, 'CD103': 2.0, 'CD69': 2.0, 'GZMB': 2.5},
    'CD4T': {'Ki67': 1.0, 'CD103': 1.0, 'CD69': 2.0, 'GZMB': 0.5},
    'Neutrophil': {'CD103': 2.75},
    'Neutrophil_CD15': {'CD103': 2.75}
}
CONFIG = {
    'RADIUS': 25.0,
    'BANDWIDTH': 15.0,
    'MIN_SUPPORT': 0.01,
    'MIN_ABS_SUPPORT': 5,
    'MIN_CONFIDENCE': 0.3,
    'MIN_LIFT': 1.2,
    'MIN_CELLS_PER_PATCH': 2,
    'HIGH_CONFIDENCE_THRESHOLD': 0.9,
    'HIGH_CONF_MIN_SUPPORT': 0.005,
}

RADIUS = CONFIG['RADIUS']
BANDWIDTH = CONFIG.get('BANDWIDTH', RADIUS)
MIN_SUPPORT = CONFIG['MIN_SUPPORT']
MIN_ABS_SUPPORT = CONFIG.get('MIN_ABS_SUPPORT', 5)
MIN_CONFIDENCE = CONFIG['MIN_CONFIDENCE']
MIN_LIFT = CONFIG['MIN_LIFT']
STAGE_COLUMN = "Pathological score"
STAGE_FOV_METRICS = []
SCORE_COLUMN = 'Pathological score'  # change to 'Clinical score' if needed

ANTECEDENT_BASE = 'Paneth'
ANTECEDENT_REQUIRED_MARKERS = ()
CONSEQUENT_BASE = 'Epithelial'
CONSEQUENT_REQUIRED_MARKERS = ('Ki67+',)

# %% [markdown]
# ## Step 1: Data Loading & Functional Subtypes
#
# Load the cell and metadata tables, identify disease stages, and append the `functional_subtypes` array to every cell.

# %%
def _add_functional_subtypes(df):
    if not USE_FUNCTIONAL_MARKERS:
        df["functional_subtypes"] = [[] for _ in range(len(df))]
        return df
    functional_subtypes_list = [[] for _ in range(len(df))]
    idx_to_pos = {idx: i for i, idx in enumerate(df.index)}
    for base_type, markers in CELLTYPE_MARKER_THRESHOLDS.items():
        type_mask = df["cell type"] == base_type
        for marker, threshold in markers.items():
            if marker in df.columns:
                mask = type_mask & (df[marker] > threshold)
                subtype_label = f"{base_type}_{marker}+"
                matching_indices = df.index[mask]
                for idx in matching_indices:
                    functional_subtypes_list[idx_to_pos[idx]].append(subtype_label)
    df["functional_subtypes"] = functional_subtypes_list
    return df

cell_table_path = '../../../data/MIBIGutCsv/cell_table.csv'
fov_meta_path = '../../../data/MIBIGutCsv/fovs_metadata.csv'
biopsy_meta_path = '../../../data/MIBIGutCsv/biopsy_metadata.csv'

df_cells = pd.read_csv(cell_table_path)
df_fovs = pd.read_csv(fov_meta_path)
df_biopsy = pd.read_csv(biopsy_meta_path)

# Merge FOV with Biopsy to get score columns and Localization
df_fovs = pd.merge(
    df_fovs,
    df_biopsy[['Biopsy_ID', 'Pathological score', 'Clinical score', 'Localization']],
    left_on='Patient',
    right_on='Biopsy_ID',
    how='left'
)

# --- Standardized Organ Enrichment (from investigation_01_colon.ipynb) ---
def get_organ(row):
    if pd.notna(row.get("Localization")): return row["Localization"]
    cohort = str(row.get("Cohort", ""))
    if "Colon" in cohort: return "Colon"
    if "Duodenum" in cohort: return "Duodenum"
    return "Unknown"

df_fovs["Organ"] = df_fovs.apply(get_organ, axis=1)
# -------------------------------------------------------------------------

# Define FOV lists for each cohort, explicitly split by Stage and Organ
control_cohorts = ['Duodenum_Cohort_Control_1', 'Duodenum_Cohort_Control_2', 'Colon_Cohort_Control']

# Colon
colon_control_fovs = df_fovs[(df_fovs['Cohort'].isin(control_cohorts)) & (df_fovs['Organ'] == 'Colon')]['FOV'].tolist()
colon_mild_fovs = df_fovs[(df_fovs[SCORE_COLUMN] == 'Mild') & (df_fovs['Organ'] == 'Colon')]['FOV'].tolist()
colon_severe_fovs = df_fovs[(df_fovs[SCORE_COLUMN] == 'Severe') & (df_fovs['Organ'] == 'Colon')]['FOV'].tolist()

# Duodenum
duodenum_control_fovs = df_fovs[(df_fovs['Cohort'].isin(control_cohorts)) & (df_fovs['Organ'] == 'Duodenum')]['FOV'].tolist()
duodenum_mild_fovs = df_fovs[(df_fovs[SCORE_COLUMN] == 'Mild') & (df_fovs['Organ'] == 'Duodenum')]['FOV'].tolist()
duodenum_severe_fovs = df_fovs[(df_fovs[SCORE_COLUMN] == 'Severe') & (df_fovs['Organ'] == 'Duodenum')]['FOV'].tolist()

# Normalize Coordinates
fov_to_size = df_fovs.set_index('FOV')['Size [um]'].to_dict()
def normalize_coords(row):
    size = fov_to_size.get(row['fov'], 800)
    res = 1024 if size == 400 else 2048
    return row['centroid_x'] * (size / res), row['centroid_y'] * (size / res)

df_cells[['x_um', 'y_um']] = df_cells.apply(lambda row: pd.Series(normalize_coords(row)), axis=1)

# Add Functional Subtypes
df_cells = _add_functional_subtypes(df_cells)

print(f"Total Cells: {len(df_cells)}")
print(f"Colon Control FOVs: {len(colon_control_fovs)}")
print(f"Colon Mild FOVs: {len(colon_mild_fovs)}")
print(f"Colon Severe FOVs: {len(colon_severe_fovs)}")
print(f"Duodenum Control FOVs: {len(duodenum_control_fovs)}")
print(f"Duodenum Mild FOVs: {len(duodenum_mild_fovs)}")
print(f"Duodenum Severe FOVs: {len(duodenum_severe_fovs)}")
print(f"Stage column used: {SCORE_COLUMN}")
# Out:
# Total Cells: 713372
# Colon Control FOVs: 25
# Colon Mild FOVs: 40
# Colon Severe FOVs: 32
# Duodenum Control FOVs: 52
# Duodenum Mild FOVs: 103
# Duodenum Severe FOVs: 36
# Stage column used: Pathological score

# %% [markdown]
# ## Step 2: Evaluation Framework
#
# Define a reusable function that iterates over a given list of FOVs, computes both binary and weighted metrics *per FOV*, and verifies how many FOVs pass the algorithm thresholds. Finally, it visualizes the FOV with the highest target cell density.

# %%
def evaluate_cohort(cohort_name, fov_list, df_cells_all):
    print(f"==============================================")
    print(f"Evaluating Cohort: {cohort_name}")
    print(f"==============================================\n")

    binary_pass_count = 0
    weighted_pass_count = 0
    valid_fovs = 0

    global_binary_transactions = []
    global_weighted_transactions = []
    passing_binary_transactions = []
    passing_weighted_transactions = []

    max_target_count = -1
    max_target_fov = None
    fov_metrics = []
    organ = None
    stage = cohort_name
    if " - " in cohort_name:
        organ, stage = [part.strip() for part in cohort_name.split(" - ", 1)]

    def _parse_token(token, suffix):
        token = str(token)
        tail = f"_{suffix}"
        if not token.endswith(tail):
            return None, set()
        core = token[:-len(tail)]
        base = _extract_base_lineage(core)
        markers = {part for part in core.split('_') if part.endswith('+')}
        return base, markers

    def _matches_rule_item(token, base, suffix, required_markers=()):
        token_base, token_markers = _parse_token(token, suffix)
        if token_base != base:
            return False
        return set(required_markers).issubset(token_markers)

    def _has_item(binary_trans, base, suffix, required_markers=()):
        return any(_matches_rule_item(item, base, suffix, required_markers) for item in binary_trans)

    def _weight_for_item(weighted_trans, base, suffix, required_markers=()):
        return min(
            sum(float(v) for k, v in weighted_trans.items() if _matches_rule_item(k, base, suffix, required_markers)),
            1.0,
        )

    def _conviction(confidence, support_con):
        if confidence >= 1:
            return float("inf")
        denom = 1 - confidence
        if denom <= 0:
            return float("inf")
        return (1 - support_con) / denom

    def _rule_item_label(base, required_markers):
        if not required_markers:
            return base
        return f"{base}_{'_'.join(required_markers)}"

    for fov in fov_list:
        fov_data = df_cells_all[df_cells_all['fov'] == fov]
        if fov_data.empty:
            continue
        valid_fovs += 1

        coords = fov_data[['x_um', 'y_um']].values
        types = fov_data['cell type'].values
        subtypes = fov_data['functional_subtypes'].values

        target_count = sum(
            1
            for t, st in zip(types, subtypes)
            if _matches_rule_item(
                build_cell_item_token(t, st, suffix='CENTER'),
                ANTECEDENT_BASE,
                'CENTER',
                ANTECEDENT_REQUIRED_MARKERS,
            )
        )
        if target_count > max_target_count:
            max_target_count = target_count
            max_target_fov = fov

        nn = NearestNeighbors(radius=RADIUS).fit(coords)
        distances, neighbors_idx = nn.radius_neighbors(coords, return_distance=True)

        fov_binary_trans = []
        fov_weighted_trans = []

        for i, (idxs, dists) in enumerate(zip(neighbors_idx, distances)):
            if len(idxs) < CONFIG.get("MIN_CELLS_PER_PATCH", 2):
                continue

            center_token = build_cell_item_token(types[i], subtypes[i], suffix='CENTER')

            b_trans = {center_token}
            w_trans = {center_token: 1.0}

            for n_idx, d in zip(idxs, dists):
                if n_idx == i:
                    continue

                neighbor_token = build_cell_item_token(types[n_idx], subtypes[n_idx], suffix='NEIGHBOR')
                b_trans.add(neighbor_token)

                w = np.exp(-0.5 * (d / BANDWIDTH) ** 2)
                w_trans[neighbor_token] = w_trans.get(neighbor_token, 0.0) + w

            w_trans = {k: min(v, 1.0) for k, v in w_trans.items()}

            fov_binary_trans.append(b_trans)
            fov_weighted_trans.append(w_trans)
            global_binary_transactions.append(b_trans)
            global_weighted_transactions.append(w_trans)

        n_trans = len(fov_binary_trans)
        if n_trans == 0:
            print(f"FOV: {fov} | 0 Transactions")
            continue

        b_sup_ant = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_con = sum(
            1 for t in fov_binary_trans
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_joint = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_conf = b_sup_joint / b_sup_ant if b_sup_ant > 0 else 0
        b_lift = b_conf / b_sup_con if b_sup_con > 0 else 0

        b_pass = False
        if b_sup_joint >= MIN_SUPPORT and b_conf >= MIN_CONFIDENCE and b_lift >= MIN_LIFT:
            binary_pass_count += 1
            b_pass = True

        w_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in fov_weighted_trans
        ) / n_trans
        w_conf = w_sup_joint / w_sup_ant if w_sup_ant > 0 else 0
        w_lift = w_conf / w_sup_con if w_sup_con > 0 else 0

        b_leverage = b_sup_joint - (b_sup_ant * b_sup_con)
        w_leverage = w_sup_joint - (w_sup_ant * w_sup_con)
        b_conviction = _conviction(b_conf, b_sup_con)
        w_conviction = _conviction(w_conf, w_sup_con)

        fov_metrics.append({
            "Cohort": cohort_name,
            "Organ": organ,
            "Stage": stage,
            "FOV": fov,
            "Binary_support": b_sup_joint,
            "Binary_confidence": b_conf,
            "Binary_lift": b_lift,
            "Binary_conviction": b_conviction,
            "Binary_leverage": b_leverage,
            "Weighted_support": w_sup_joint,
            "Weighted_confidence": w_conf,
            "Weighted_lift": w_lift,
            "Weighted_conviction": w_conviction,
            "Weighted_leverage": w_leverage,
        })

        w_pass = False
        if (
            passes_rule_support_policy(CONFIG, w_sup_joint, w_conf, w_lift, num_transactions=n_trans)
            and w_conf >= MIN_CONFIDENCE
            and w_lift >= MIN_LIFT
        ):
            weighted_pass_count += 1
            w_pass = True

        if b_pass:
            passing_binary_transactions.extend(fov_binary_trans)
        if w_pass:
            passing_weighted_transactions.extend(fov_weighted_trans)

        print(f"FOV: {fov} | Transactions: {n_trans}")
        print(f"  [Binary]   Sup: {b_sup_joint:.4f} | Conf: {b_conf:.4f} | Lift: {b_lift:.4f} | PASS: {b_pass}")
        print(f"  [Weighted] Sup: {w_sup_joint:.4f} | Conf: {w_conf:.4f} | Lift: {w_lift:.4f} | PASS: {w_pass}\n")

    ant_label = _rule_item_label(ANTECEDENT_BASE, ANTECEDENT_REQUIRED_MARKERS)
    con_label = _rule_item_label(CONSEQUENT_BASE, CONSEQUENT_REQUIRED_MARKERS)
    print(f"\n[Algorithm Comparison: {ant_label}_CENTER -> {con_label}_NEIGHBOR (rule-aware)]")
    print(f"FOVs passing standard FP-Growth (Binary): {binary_pass_count} / {valid_fovs}")
    print(f"FOVs passing Weighted FP-Growth (Distance-decay): {weighted_pass_count} / {valid_fovs}")

    if not global_binary_transactions:
        return

    g_n_trans = len(global_binary_transactions)
    gb_sup_ant = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_con = sum(
        1 for t in global_binary_transactions
        if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_joint = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_conf = gb_sup_joint / gb_sup_ant if gb_sup_ant > 0 else 0
    gb_lift = gb_conf / gb_sup_con if gb_sup_con > 0 else 0

    gw_sup_ant = sum(
        _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_con = sum(
        _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_joint = sum(
        min(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
        )
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_conf = gw_sup_joint / gw_sup_ant if gw_sup_ant > 0 else 0
    gw_lift = gw_conf / gw_sup_con if gw_sup_con > 0 else 0

    if passing_binary_transactions:
        p_n_trans = len(passing_binary_transactions)
        pb_sup_ant = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_con = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_joint = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_conf = pb_sup_joint / pb_sup_ant if pb_sup_ant > 0 else 0
        pb_lift = pb_conf / pb_sup_con if pb_sup_con > 0 else 0

        pw_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_conf = pw_sup_joint / pw_sup_ant if pw_sup_ant > 0 else 0
        pw_lift = pw_conf / pw_sup_con if pw_sup_con > 0 else 0
    else:
        pb_sup_joint = pb_conf = pb_lift = 0
        pw_sup_joint = pw_conf = pw_lift = 0

    print(f"\n[Aggregate Metrics: ALL FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Approved: {binary_pass_count:>12} | {weighted_pass_count:>12}  (out of {valid_fovs} valid FOVs)")
    print(f"Support : {gb_sup_joint:>12.4f} | {gw_sup_joint:>12.4f}")
    print(f"Conf    : {gb_conf:>12.4f} | {gw_conf:>12.4f}")
    print(f"Lift    : {gb_lift:>12.4f} | {gw_lift:>12.4f}")

    print(f"\n[Aggregate Metrics: ONLY PASSING FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Support : {pb_sup_joint:>12.4f} | {pw_sup_joint:>12.4f}")
    print(f"Conf    : {pb_conf:>12.4f} | {pw_conf:>12.4f}")
    print(f"Lift    : {pb_lift:>12.4f} | {pw_lift:>12.4f}")

    if max_target_fov:
        print(f"\nVisualizing Representative FOV: {max_target_fov} ({max_target_count} matching antecedent cells)")
        _plot_fov(max_target_fov, df_cells_all)

    return pd.DataFrame(fov_metrics)

def _plot_fov(fov, df_cells_all):
    fov_df = df_cells_all[df_cells_all['fov'] == fov].copy()
    
    def get_plot_class(row):
        if row['cell type'] == 'Paneth': return 'Paneth'
        elif 'Epithelial_Ki67+' in row['functional_subtypes']: return 'Epithelial_Ki67+'
        elif row['cell type'] == 'Epithelial': return 'Epithelial_Other'
        return 'Other'
        
    fov_df['PlotClass'] = fov_df.apply(get_plot_class, axis=1)
    
    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.figure(figsize=(10, 10))
    others = fov_df[fov_df['PlotClass'] == 'Other']
    sns.scatterplot(data=others, x='x_um', y='y_um', color='lightgrey', alpha=0.3, s=20)
    
    epi_other = fov_df[fov_df['PlotClass'] == 'Epithelial_Other']
    sns.scatterplot(data=epi_other, x='x_um', y='y_um', color='blue', alpha=0.5, s=20, label='Epithelial (Other)')
    
    epi_ki67 = fov_df[fov_df['PlotClass'] == 'Epithelial_Ki67+']
    sns.scatterplot(data=epi_ki67, x='x_um', y='y_um', color='green', s=60, edgecolor='black', zorder=8, label='Epithelial_Ki67+')
    
    target = fov_df[fov_df['PlotClass'] == 'Paneth']
    sns.scatterplot(data=target, x='x_um', y='y_um', color='red', s=70, edgecolor='black', zorder=10, label='Paneth')
    
    plt.title(f"Spatial Distribution in FOV {fov}")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.show()

# %% [markdown]
# ## Stage-level Metric Distributions
#
# Run after all cohorts to compare metric distributions across stages.

# %%
def plot_stage_metric_distributions(stage_fov_metrics, organ=None, stage_column="Pathological score"):
    if not stage_fov_metrics:
        print('No per-FOV metrics collected yet. Run the cohort evaluations first.')
        return
    if isinstance(stage_fov_metrics, list):
        plot_df = pd.concat(stage_fov_metrics, ignore_index=True)
    else:
        plot_df = stage_fov_metrics.copy()

    if organ:
        plot_df = plot_df[plot_df['Organ'] == organ].copy()
    if plot_df.empty:
        print(f"No per-FOV metrics found for {organ or 'all organs'}.")
        return

    plot_df = plot_df.replace([np.inf, -np.inf], np.nan)
    stage_order = ['Control', 'Mild', 'Severe']
    available_stages = [s for s in stage_order if s in plot_df['Stage'].dropna().unique()]
    if available_stages:
        plot_df['Stage'] = pd.Categorical(plot_df['Stage'], categories=available_stages, ordered=True)
        stage_levels = list(plot_df['Stage'].cat.categories)
    else:
        stage_levels = sorted(plot_df['Stage'].dropna().unique())

    stage_counts = plot_df.groupby('Stage', observed=True).size().to_dict()
    stage_labels = [f"{stage} (n={stage_counts.get(stage, 0)})" for stage in stage_levels]

    metric_defs = [
        ('support', 'Support'),
        ('confidence', 'Confidence'),
        ('lift', 'Lift'),
        ('conviction', 'Conviction'),
        ('leverage', 'Leverage'),
    ]

    palette = sns.color_palette("Set2", n_colors=len(stage_levels))
    title_organ = organ or "All organs"
    for mode in ['Binary', 'Weighted']:
        fig, axes = plt.subplots(1, len(metric_defs), figsize=(4 * len(metric_defs), 4), sharey=False)
        for ax, (key, label) in zip(axes, metric_defs):
            col = f"{mode}_{key}"
            if col not in plot_df.columns:
                ax.axis('off')
                continue
            sns.violinplot(
                data=plot_df,
                x='Stage',
                y=col,
                order=stage_levels,
                palette=palette,
                ax=ax,
                inner='quartile',
                cut=0,
            )
            sns.stripplot(
                data=plot_df,
                x='Stage',
                y=col,
                order=stage_levels,
                color='black',
                alpha=0.5,
                size=3,
                jitter=0.25,
                ax=ax,
            )
            ax.set_title(f"{mode} {label}")
            ax.set_xlabel(stage_column)
            ax.set_ylabel(label)
            ax.set_xticklabels(stage_labels, rotation=0)
            ax.grid(True, axis='y', linestyle='--', alpha=0.4)
        fig.suptitle(f"{mode} metrics by stage ({title_organ} | {stage_column})", y=1.08, fontsize=12)
        plt.tight_layout()
        plt.subplots_adjust(top=0.82)
        plt.show()

# %% [markdown]
# ## Step 3: Run Evaluation on Control Cohort

# %%
metrics = evaluate_cohort("Colon - Control", colon_control_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
# Out:
# ==============================================
# Evaluating Cohort: Colon - Control
# ==============================================
#
# FOV: Control_Colon_01_FOV_1 | Transactions: 1401
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_2 | Transactions: 1778
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_3 | Transactions: 1624
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_4 | Transactions: 2046
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_5 | Transactions: 1877
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_6 | Transactions: 5270
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_7 | Transactions: 5502
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_1 | Transactions: 1743
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_2 | Transactions: 1901
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_3 | Transactions: 1706
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_4 | Transactions: 1882
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_5 | Transactions: 5686
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_6 | Transactions: 5706
#   [Binary]   Sup: 0.0004 | Conf: 0.4000 | Lift: 1.5026 | PASS: False
#   [Weighted] Sup: 0.0001 | Conf: 0.1436 | Lift: 0.6504 | PASS: False
#
# FOV: Control_Colon_03_FOV_1 | Transactions: 1672
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_2 | Transactions: 1846
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_3 | Transactions: 1850
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_4 | Transactions: 1834
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_5 | Transactions: 5717
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_6 | Transactions: 6034
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_1 | Transactions: 2273
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_2 | Transactions: 2379
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_3 | Transactions: 2357
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_4 | Transactions: 2294
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_5 | Transactions: 7392
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_6 | Transactions: 7983
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 0 / 25
# FOVs passing Weighted FP-Growth (Distance-decay): 0 / 25
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            0 |            0  (out of 25 valid FOVs)
# Support :       0.0000 |       0.0000
# Conf    :       0.2500 |       0.0898
# Lift    :       1.0470 |       0.4825
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0000 |       0.0000
# Conf    :       0.0000 |       0.0000
# Lift    :       0.0000 |       0.0000
#
# Visualizing Representative FOV: Control_Colon_02_FOV_6 (5 matching antecedent cells)

# %%
metrics = evaluate_cohort("Colon - Mild", colon_mild_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
# Out:
# ==============================================
# Evaluating Cohort: Colon - Mild
# ==============================================
#
# FOV: GVHD_13_FOV_1 | Transactions: 1462
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_13_FOV_2 | Transactions: 1661
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_13_FOV_3 | Transactions: 1294
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_1 | Transactions: 1503
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_2 | Transactions: 1188
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_3 | Transactions: 1492
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_22_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_22_FOV_2 | Transactions: 1698
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_22_FOV_3 | Transactions: 1900
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_1 | Transactions: 2347
#   [Binary]   Sup: 0.0030 | Conf: 1.0000 | Lift: 1.2504 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 0.9935 | Lift: 1.3020 | PASS: False
#
# FOV: GVHD_23_FOV_2 | Transactions: 1039
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_3 | Transactions: 1348
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_4 | Transactions: 1161
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_33_FOV_1 | Transactions: 1834
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_33_FOV_2 | Transactions: 1535
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_33_FOV_3 | Transactions: 1990
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4014 | PASS: False
#   [Weighted] Sup: 0.0002 | Conf: 0.3205 | Lift: 0.4835 | PASS: False
#
# FOV: GVHD_39_FOV_1 | Transactions: 1942
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.6916 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.8194 | PASS: False
#
# FOV: GVHD_39_FOV_2 | Transactions: 1508
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_39_FOV_3 | Transactions: 1957
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_1 | Transactions: 1386
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_2 | Transactions: 1447
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_3 | Transactions: 1147
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_4 | Transactions: 1437
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_1 | Transactions: 1768
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_2 | Transactions: 1913
#   [Binary]   Sup: 0.0010 | Conf: 1.0000 | Lift: 3.0955 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.8611 | Lift: 3.4528 | PASS: False
#
# FOV: GVHD_42_FOV_3 | Transactions: 1989
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_4 | Transactions: 2275
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_45_FOV_1 | Transactions: 2357
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_45_FOV_2 | Transactions: 2096
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 2.0409 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 2.1819 | PASS: False
#
# FOV: GVHD_50_FOV_1 | Transactions: 2444
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_2 | Transactions: 2514
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_3 | Transactions: 2088
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_4 | Transactions: 2225
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_1 | Transactions: 2420
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_2 | Transactions: 2375
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 2.4637 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 3.1884 | PASS: False
#
# FOV: GVHD_53_FOV_3 | Transactions: 2707
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_4 | Transactions: 2668
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_59_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_59_FOV_2 | Transactions: 1953
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_59_FOV_3 | Transactions: 1993
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 0 / 40
# FOVs passing Weighted FP-Growth (Distance-decay): 0 / 40
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            0 |            0  (out of 40 valid FOVs)
# Support :       0.0002 |       0.0002
# Conf    :       0.8667 |       0.7998
# Lift    :       2.0227 |       2.1845
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0000 |       0.0000
# Conf    :       0.0000 |       0.0000
# Lift    :       0.0000 |       0.0000
#
# Visualizing Representative FOV: GVHD_23_FOV_1 (7 matching antecedent cells)

# %%
metrics = evaluate_cohort("Colon - Severe", colon_severe_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
plot_stage_metric_distributions(STAGE_FOV_METRICS, organ="Colon", stage_column=STAGE_COLUMN)
# Out:
# ==============================================
# Evaluating Cohort: Colon - Severe
# ==============================================
#
# FOV: GVHD_01_FOV_1 | Transactions: 1801
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_2_R | Transactions: 2040
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_3_R | Transactions: 1852
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_4 | Transactions: 1937
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_5 | Transactions: 2103
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_6_R | Transactions: 2010
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_7 | Transactions: 2066
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_1 | Transactions: 1340
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_2 | Transactions: 1840
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_3 | Transactions: 2570
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_4 | Transactions: 1956
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_25_FOV_1 | Transactions: 2667
#   [Binary]   Sup: 0.0007 | Conf: 1.0000 | Lift: 1.9242 | PASS: False
#   [Weighted] Sup: 0.0007 | Conf: 1.0000 | Lift: 2.0578 | PASS: False
#
# FOV: GVHD_25_FOV_2 | Transactions: 2589
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_25_FOV_3 | Transactions: 2320
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.6066 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.7664 | PASS: False
#
# FOV: GVHD_25_FOV_4 | Transactions: 2276
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_1 | Transactions: 2579
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_2 | Transactions: 1867
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_3 | Transactions: 2197
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_4 | Transactions: 1765
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_1 | Transactions: 1821
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_2 | Transactions: 2118
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_3 | Transactions: 1431
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_4 | Transactions: 1596
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_1 | Transactions: 1896
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_2 | Transactions: 2102
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_3 | Transactions: 2569
#   [Binary]   Sup: 0.0008 | Conf: 0.6667 | Lift: 1.7387 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 0.6667 | Lift: 1.9301 | PASS: False
#
# FOV: GVHD_41_FOV_4 | Transactions: 2023
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_48_FOV_1 | Transactions: 2528
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 2.1552 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 2.3107 | PASS: False
#
# FOV: GVHD_48_FOV_2 | Transactions: 2151
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.4151 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.5133 | PASS: False
#
# FOV: GVHD_48_FOV_3 | Transactions: 2388
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 1.9736 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 2.1017 | PASS: False
#
# FOV: GVHD_48_FOV_4 | Transactions: 2989
#   [Binary]   Sup: 0.0003 | Conf: 1.0000 | Lift: 6.5262 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 1.0000 | Lift: 8.1161 | PASS: False
#
# FOV: GVHD_48_FOV_5 | Transactions: 2740
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.6137 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 1.6985 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 0 / 32
# FOVs passing Weighted FP-Growth (Distance-decay): 0 / 32
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            0 |            0  (out of 32 valid FOVs)
# Support :       0.0002 |       0.0002
# Conf    :       0.9286 |       0.9286
# Lift    :       2.0007 |       2.2137
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0000 |       0.0000
# Conf    :       0.0000 |       0.0000
# Lift    :       0.0000 |       0.0000
#
# Visualizing Representative FOV: GVHD_41_FOV_3 (3 matching antecedent cells)

# %%
metrics = evaluate_cohort("Duodenum - Control", duodenum_control_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
# Out:
# ==============================================
# Evaluating Cohort: Duodenum - Control
# ==============================================
#
# FOV: Control_01_FOV_1 | Transactions: 2618
#   [Binary]   Sup: 0.0111 | Conf: 0.9667 | Lift: 2.9808 | PASS: True
#   [Weighted] Sup: 0.0097 | Conf: 0.8471 | Lift: 2.9693 | PASS: False
#
# FOV: Control_01_FOV_2 | Transactions: 2354
#   [Binary]   Sup: 0.0047 | Conf: 0.9167 | Lift: 1.6261 | PASS: False
#   [Weighted] Sup: 0.0043 | Conf: 0.8351 | Lift: 1.6834 | PASS: False
#
# FOV: Control_01_FOV_3 | Transactions: 2157
#   [Binary]   Sup: 0.0116 | Conf: 0.8929 | Lift: 1.4298 | PASS: True
#   [Weighted] Sup: 0.0105 | Conf: 0.8058 | Lift: 1.4512 | PASS: True
#
# FOV: Control_01_FOV_4 | Transactions: 2140
#   [Binary]   Sup: 0.0182 | Conf: 0.8667 | Lift: 1.0852 | PASS: False
#   [Weighted] Sup: 0.0175 | Conf: 0.8326 | Lift: 1.1539 | PASS: False
#
# FOV: Control_02_FOV_1 | Transactions: 2305
#   [Binary]   Sup: 0.0048 | Conf: 0.7857 | Lift: 1.4160 | PASS: False
#   [Weighted] Sup: 0.0037 | Conf: 0.6170 | Lift: 1.2374 | PASS: False
#
# FOV: Control_02_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0044 | Conf: 0.9000 | Lift: 2.0013 | PASS: False
#   [Weighted] Sup: 0.0044 | Conf: 0.9000 | Lift: 2.2410 | PASS: False
#
# FOV: Control_02_FOV_3 | Transactions: 2040
#   [Binary]   Sup: 0.0029 | Conf: 0.7500 | Lift: 0.9178 | PASS: False
#   [Weighted] Sup: 0.0026 | Conf: 0.6678 | Lift: 0.8968 | PASS: False
#
# FOV: Control_02_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0079 | Conf: 0.9000 | Lift: 1.5481 | PASS: False
#   [Weighted] Sup: 0.0076 | Conf: 0.8680 | Lift: 1.6527 | PASS: False
#
# FOV: Control_03_FOV_1 | Transactions: 2074
#   [Binary]   Sup: 0.0101 | Conf: 0.7778 | Lift: 1.2772 | PASS: True
#   [Weighted] Sup: 0.0096 | Conf: 0.7340 | Lift: 1.3108 | PASS: False
#
# FOV: Control_03_FOV_2 | Transactions: 1916
#   [Binary]   Sup: 0.0031 | Conf: 0.3000 | Lift: 1.4442 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.1947 | Lift: 1.1820 | PASS: False
#
# FOV: Control_03_FOV_3 | Transactions: 1884
#   [Binary]   Sup: 0.0042 | Conf: 0.6667 | Lift: 1.2290 | PASS: False
#   [Weighted] Sup: 0.0033 | Conf: 0.5150 | Lift: 1.1032 | PASS: False
#
# FOV: Control_04_FOV_1 | Transactions: 2290
#   [Binary]   Sup: 0.0052 | Conf: 0.8000 | Lift: 1.3275 | PASS: False
#   [Weighted] Sup: 0.0048 | Conf: 0.7388 | Lift: 1.3881 | PASS: False
#
# FOV: Control_04_FOV_2 | Transactions: 1911
#   [Binary]   Sup: 0.0157 | Conf: 0.9677 | Lift: 1.2412 | PASS: True
#   [Weighted] Sup: 0.0157 | Conf: 0.9677 | Lift: 1.3044 | PASS: True
#
# FOV: Control_05_FOV_1 | Transactions: 1924
#   [Binary]   Sup: 0.0078 | Conf: 0.7500 | Lift: 1.6069 | PASS: False
#   [Weighted] Sup: 0.0062 | Conf: 0.6004 | Lift: 1.4610 | PASS: False
#
# FOV: Control_05_FOV_2 | Transactions: 1753
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_06_FOV_1 | Transactions: 1723
#   [Binary]   Sup: 0.0168 | Conf: 0.8788 | Lift: 1.6749 | PASS: True
#   [Weighted] Sup: 0.0148 | Conf: 0.7704 | Lift: 1.6718 | PASS: True
#
# FOV: Control_06_FOV_2 | Transactions: 1651
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_06_FOV_3 | Transactions: 1308
#   [Binary]   Sup: 0.0161 | Conf: 0.8077 | Lift: 1.9896 | PASS: True
#   [Weighted] Sup: 0.0142 | Conf: 0.7142 | Lift: 1.9325 | PASS: True
#
# FOV: Control_07_FOV_1 | Transactions: 2317
#   [Binary]   Sup: 0.0125 | Conf: 0.9355 | Lift: 1.9114 | PASS: True
#   [Weighted] Sup: 0.0120 | Conf: 0.8948 | Lift: 1.9415 | PASS: True
#
# FOV: Control_07_FOV_2 | Transactions: 1811
#   [Binary]   Sup: 0.0072 | Conf: 0.7647 | Lift: 1.9728 | PASS: False
#   [Weighted] Sup: 0.0068 | Conf: 0.7240 | Lift: 2.1178 | PASS: False
#
# FOV: Control_07_FOV_3 | Transactions: 1913
#   [Binary]   Sup: 0.0152 | Conf: 0.8056 | Lift: 1.3015 | PASS: True
#   [Weighted] Sup: 0.0142 | Conf: 0.7546 | Lift: 1.3235 | PASS: True
#
# FOV: Control_08_FOV_1 | Transactions: 1954
#   [Binary]   Sup: 0.0271 | Conf: 0.6543 | Lift: 1.0488 | PASS: False
#   [Weighted] Sup: 0.0230 | Conf: 0.5552 | Lift: 0.9498 | PASS: False
#
# FOV: Control_08_FOV_2 | Transactions: 1657
#   [Binary]   Sup: 0.0006 | Conf: 1.0000 | Lift: 2.8520 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 1.0000 | Lift: 3.3826 | PASS: False
#
# FOV: Control_08_FOV_3 | Transactions: 2070
#   [Binary]   Sup: 0.0068 | Conf: 0.7778 | Lift: 1.5784 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 0.7302 | Lift: 1.5585 | PASS: False
#
# FOV: Control_09_FOV_1 | Transactions: 2375
#   [Binary]   Sup: 0.0051 | Conf: 1.0000 | Lift: 3.3357 | PASS: False
#   [Weighted] Sup: 0.0051 | Conf: 1.0000 | Lift: 3.9874 | PASS: True
#
# FOV: Control_09_FOV_2 | Transactions: 2644
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_09_FOV_3 | Transactions: 2064
#   [Binary]   Sup: 0.0053 | Conf: 0.7857 | Lift: 1.4518 | PASS: False
#   [Weighted] Sup: 0.0044 | Conf: 0.6420 | Lift: 1.3169 | PASS: False
#
# FOV: Control_09_FOV_4 | Transactions: 1977
#   [Binary]   Sup: 0.0035 | Conf: 0.7000 | Lift: 1.1698 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 0.4760 | Lift: 0.9044 | PASS: False
#
# FOV: Control_10_FOV_2 | Transactions: 1966
#   [Binary]   Sup: 0.0025 | Conf: 0.7143 | Lift: 0.8183 | PASS: False
#   [Weighted] Sup: 0.0022 | Conf: 0.6126 | Lift: 0.7704 | PASS: False
#
# FOV: Control_10_FOV_3 | Transactions: 1797
#   [Binary]   Sup: 0.0045 | Conf: 0.6154 | Lift: 0.8680 | PASS: False
#   [Weighted] Sup: 0.0038 | Conf: 0.5190 | Lift: 0.8639 | PASS: False
#
# FOV: Control_10_FOV_4 | Transactions: 2073
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.2087 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.3199 | PASS: False
#
# FOV: S_01_FOV_1 | Transactions: 5113
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 9.1795 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 0.6705 | Lift: 8.3005 | PASS: False
#
# FOV: S_01_FOV_2 | Transactions: 6563
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 6.7940 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 0.8505 | Lift: 6.7514 | PASS: False
#
# FOV: S_01_FOV_3 | Transactions: 6849
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 5.4924 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 0.8874 | Lift: 5.6208 | PASS: False
#
# FOV: S_01_FOV_4 | Transactions: 6070
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_02_FOV_1 | Transactions: 6163
#   [Binary]   Sup: 0.0003 | Conf: 0.5000 | Lift: 3.4050 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 0.5000 | Lift: 4.5029 | PASS: False
#
# FOV: S_02_FOV_2 | Transactions: 5802
#   [Binary]   Sup: 0.0031 | Conf: 0.9000 | Lift: 4.2385 | PASS: False
#   [Weighted] Sup: 0.0027 | Conf: 0.7814 | Lift: 4.2819 | PASS: False
#
# FOV: S_02_FOV_3 | Transactions: 6259
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 5.8386 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 0.7669 | Lift: 5.4129 | PASS: False
#
# FOV: S_02_FOV_4 | Transactions: 5914
#   [Binary]   Sup: 0.0007 | Conf: 1.0000 | Lift: 7.1859 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 0.8377 | Lift: 7.0656 | PASS: False
#
# FOV: S_02_FOV_5 | Transactions: 5174
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_03_FOV_1 | Transactions: 5245
#   [Binary]   Sup: 0.0053 | Conf: 0.7179 | Lift: 3.5795 | PASS: False
#   [Weighted] Sup: 0.0042 | Conf: 0.5670 | Lift: 3.4478 | PASS: False
#
# FOV: S_03_FOV_10 | Transactions: 5116
#   [Binary]   Sup: 0.0057 | Conf: 0.8529 | Lift: 3.7521 | PASS: False
#   [Weighted] Sup: 0.0049 | Conf: 0.7438 | Lift: 3.8165 | PASS: False
#
# FOV: S_03_FOV_2 | Transactions: 5494
#   [Binary]   Sup: 0.0020 | Conf: 0.8462 | Lift: 6.4656 | PASS: False
#   [Weighted] Sup: 0.0015 | Conf: 0.6381 | Lift: 6.1975 | PASS: False
#
# FOV: S_03_FOV_3 | Transactions: 6689
#   [Binary]   Sup: 0.0028 | Conf: 0.6129 | Lift: 4.1162 | PASS: False
#   [Weighted] Sup: 0.0023 | Conf: 0.5032 | Lift: 4.0027 | PASS: False
#
# FOV: S_03_FOV_4 | Transactions: 5343
#   [Binary]   Sup: 0.0037 | Conf: 0.9091 | Lift: 5.4699 | PASS: False
#   [Weighted] Sup: 0.0033 | Conf: 0.8093 | Lift: 6.0959 | PASS: False
#
# FOV: S_03_FOV_5 | Transactions: 5158
#   [Binary]   Sup: 0.0035 | Conf: 0.6667 | Lift: 2.6472 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.4725 | Lift: 2.1702 | PASS: False
#
# FOV: S_03_FOV_6 | Transactions: 4794
#   [Binary]   Sup: 0.0013 | Conf: 0.8571 | Lift: 4.9389 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.6837 | Lift: 4.6994 | PASS: False
#
# FOV: S_03_FOV_7 | Transactions: 5981
#   [Binary]   Sup: 0.0025 | Conf: 0.7143 | Lift: 5.4353 | PASS: False
#   [Weighted] Sup: 0.0022 | Conf: 0.6390 | Lift: 5.7842 | PASS: False
#
# FOV: S_03_FOV_8 | Transactions: 5875
#   [Binary]   Sup: 0.0026 | Conf: 0.8333 | Lift: 5.0317 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.6477 | Lift: 5.0180 | PASS: False
#
# FOV: S_03_FOV_9 | Transactions: 4546
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_04_FOV_1 | Transactions: 3501
#   [Binary]   Sup: 0.0020 | Conf: 0.5833 | Lift: 3.0391 | PASS: False
#   [Weighted] Sup: 0.0016 | Conf: 0.4647 | Lift: 3.0112 | PASS: False
#
# FOV: S_04_FOV_2 | Transactions: 3544
#   [Binary]   Sup: 0.0003 | Conf: 0.3333 | Lift: 4.0319 | PASS: False
#   [Weighted] Sup: 0.0001 | Conf: 0.0873 | Lift: 1.5898 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 8 / 52
# FOVs passing Weighted FP-Growth (Distance-decay): 7 / 52
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            8 |            7  (out of 52 valid FOVs)
# Support :       0.0038 |       0.0034
# Conf    :       0.7878 |       0.6915
# Lift    :       2.7905 |       2.8156
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0133 |       0.0102
# Conf    :       0.8802 |       0.8297
# Lift    :       1.6204 |       1.9999
#
# Visualizing Representative FOV: Control_08_FOV_1 (81 matching antecedent cells)

# %%
metrics = evaluate_cohort("Duodenum - Mild", duodenum_mild_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
# Out:
# ==============================================
# Evaluating Cohort: Duodenum - Mild
# ==============================================
#
# FOV: GVHD_03_FOV_1_R | Transactions: 2879
#   [Binary]   Sup: 0.0017 | Conf: 0.8333 | Lift: 1.8455 | PASS: False
#   [Weighted] Sup: 0.0012 | Conf: 0.5835 | Lift: 1.5448 | PASS: False
#
# FOV: GVHD_03_FOV_2 | Transactions: 2524
#   [Binary]   Sup: 0.0012 | Conf: 0.0714 | Lift: 0.3487 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.0546 | Lift: 0.3357 | PASS: False
#
# FOV: GVHD_03_FOV_3_R | Transactions: 2615
#   [Binary]   Sup: 0.0042 | Conf: 0.1833 | Lift: 0.5897 | PASS: False
#   [Weighted] Sup: 0.0026 | Conf: 0.1121 | Lift: 0.4652 | PASS: False
#
# FOV: GVHD_03_FOV_4 | Transactions: 2443
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_04_FOV_1 | Transactions: 2177
#   [Binary]   Sup: 0.0018 | Conf: 1.0000 | Lift: 2.2282 | PASS: False
#   [Weighted] Sup: 0.0016 | Conf: 0.8962 | Lift: 2.2526 | PASS: False
#
# FOV: GVHD_04_FOV_2 | Transactions: 2031
#   [Binary]   Sup: 0.0005 | Conf: 0.2500 | Lift: 1.0405 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 0.1667 | Lift: 0.8531 | PASS: False
#
# FOV: GVHD_04_FOV_3 | Transactions: 2340
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_05_FOV_1_R | Transactions: 1815
#   [Binary]   Sup: 0.0176 | Conf: 0.5614 | Lift: 1.2411 | PASS: True
#   [Weighted] Sup: 0.0147 | Conf: 0.4667 | Lift: 1.2685 | PASS: True
#
# FOV: GVHD_05_FOV_2_R | Transactions: 2398
#   [Binary]   Sup: 0.0254 | Conf: 0.1627 | Lift: 0.5153 | PASS: False
#   [Weighted] Sup: 0.0190 | Conf: 0.1212 | Lift: 0.4985 | PASS: False
#
# FOV: GVHD_05_FOV_3_R | Transactions: 2244
#   [Binary]   Sup: 0.0013 | Conf: 0.5000 | Lift: 0.9342 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 0.5000 | Lift: 1.0963 | PASS: False
#
# FOV: GVHD_07_FOV_1 | Transactions: 2137
#   [Binary]   Sup: 0.0056 | Conf: 0.5714 | Lift: 1.1742 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.4126 | Lift: 0.9489 | PASS: False
#
# FOV: GVHD_07_FOV_3 | Transactions: 2411
#   [Binary]   Sup: 0.0025 | Conf: 0.3529 | Lift: 0.7285 | PASS: False
#   [Weighted] Sup: 0.0021 | Conf: 0.3010 | Lift: 0.6988 | PASS: False
#
# FOV: GVHD_07_FOV_4 | Transactions: 2301
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_10_FOV_1 | Transactions: 1810
#   [Binary]   Sup: 0.0028 | Conf: 1.0000 | Lift: 2.5820 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 0.8642 | Lift: 2.4675 | PASS: False
#
# FOV: GVHD_10_FOV_2 | Transactions: 2395
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 2.7592 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 3.0713 | PASS: False
#
# FOV: GVHD_10_FOV_3 | Transactions: 1962
#   [Binary]   Sup: 0.0041 | Conf: 0.6667 | Lift: 1.2000 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 0.5754 | Lift: 1.1610 | PASS: False
#
# FOV: GVHD_10_FOV_4 | Transactions: 2438
#   [Binary]   Sup: 0.0016 | Conf: 0.2667 | Lift: 0.9941 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.1682 | Lift: 0.7400 | PASS: False
#
# FOV: GVHD_12_FOV_1 | Transactions: 1769
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_12_FOV_2 | Transactions: 1703
#   [Binary]   Sup: 0.0088 | Conf: 1.0000 | Lift: 1.6912 | PASS: False
#   [Weighted] Sup: 0.0078 | Conf: 0.8900 | Lift: 1.6810 | PASS: False
#
# FOV: GVHD_12_FOV_3 | Transactions: 1440
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_12_FOV_4 | Transactions: 2318
#   [Binary]   Sup: 0.0056 | Conf: 0.8125 | Lift: 1.4983 | PASS: False
#   [Weighted] Sup: 0.0046 | Conf: 0.6636 | Lift: 1.4642 | PASS: False
#
# FOV: GVHD_12_FOV_5 | Transactions: 2492
#   [Binary]   Sup: 0.0100 | Conf: 0.9259 | Lift: 1.4567 | PASS: True
#   [Weighted] Sup: 0.0087 | Conf: 0.8006 | Lift: 1.4295 | PASS: False
#
# FOV: GVHD_15_FOV_1 | Transactions: 1493
#   [Binary]   Sup: 0.0013 | Conf: 0.0426 | Lift: 0.1321 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 0.0426 | Lift: 0.1448 | PASS: False
#
# FOV: GVHD_15_FOV_1_B | Transactions: 1816
#   [Binary]   Sup: 0.0017 | Conf: 0.0811 | Lift: 0.2615 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.0502 | Lift: 0.1825 | PASS: False
#
# FOV: GVHD_15_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 1.3617 | PASS: False
#   [Weighted] Sup: 0.0014 | Conf: 0.9385 | Lift: 1.4043 | PASS: False
#
# FOV: GVHD_15_FOV_2_B | Transactions: 2040
#   [Binary]   Sup: 0.0034 | Conf: 0.8750 | Lift: 1.2814 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 0.7634 | Lift: 1.2517 | PASS: False
#
# FOV: GVHD_15_FOV_3 | Transactions: 2226
#   [Binary]   Sup: 0.0049 | Conf: 0.5238 | Lift: 1.0192 | PASS: False
#   [Weighted] Sup: 0.0045 | Conf: 0.4771 | Lift: 1.0315 | PASS: False
#
# FOV: GVHD_15_FOV_3_B | Transactions: 2470
#   [Binary]   Sup: 0.0077 | Conf: 0.5758 | Lift: 0.8752 | PASS: False
#   [Weighted] Sup: 0.0059 | Conf: 0.4413 | Lift: 0.7482 | PASS: False
#
# FOV: GVHD_16_FOV_1 | Transactions: 1912
#   [Binary]   Sup: 0.0141 | Conf: 0.8438 | Lift: 1.7631 | PASS: True
#   [Weighted] Sup: 0.0128 | Conf: 0.7656 | Lift: 1.7167 | PASS: True
#
# FOV: GVHD_16_FOV_2 | Transactions: 2166
#   [Binary]   Sup: 0.0115 | Conf: 0.4902 | Lift: 1.7209 | PASS: True
#   [Weighted] Sup: 0.0106 | Conf: 0.4521 | Lift: 1.8633 | PASS: True
#
# FOV: GVHD_16_FOV_3 | Transactions: 2272
#   [Binary]   Sup: 0.0070 | Conf: 0.6400 | Lift: 5.4460 | PASS: False
#   [Weighted] Sup: 0.0056 | Conf: 0.5064 | Lift: 4.9650 | PASS: False
#
# FOV: GVHD_18_FOV_1 | Transactions: 2169
#   [Binary]   Sup: 0.0069 | Conf: 0.3947 | Lift: 0.6531 | PASS: False
#   [Weighted] Sup: 0.0056 | Conf: 0.3187 | Lift: 0.5881 | PASS: False
#
# FOV: GVHD_18_FOV_2 | Transactions: 2054
#   [Binary]   Sup: 0.0044 | Conf: 0.5294 | Lift: 1.0661 | PASS: False
#   [Weighted] Sup: 0.0039 | Conf: 0.4755 | Lift: 1.0515 | PASS: False
#
# FOV: GVHD_18_FOV_3 | Transactions: 2525
#   [Binary]   Sup: 0.0079 | Conf: 0.5263 | Lift: 1.2705 | PASS: False
#   [Weighted] Sup: 0.0069 | Conf: 0.4555 | Lift: 1.1746 | PASS: False
#
# FOV: GVHD_18_FOV_4 | Transactions: 2344
#   [Binary]   Sup: 0.0085 | Conf: 0.5882 | Lift: 1.0282 | PASS: False
#   [Weighted] Sup: 0.0072 | Conf: 0.4992 | Lift: 0.9499 | PASS: False
#
# FOV: GVHD_19_FOV_1 | Transactions: 2205
#   [Binary]   Sup: 0.0277 | Conf: 0.8243 | Lift: 2.0331 | PASS: True
#   [Weighted] Sup: 0.0208 | Conf: 0.6191 | Lift: 1.9635 | PASS: True
#
# FOV: GVHD_19_FOV_2 | Transactions: 2173
#   [Binary]   Sup: 0.0207 | Conf: 0.5769 | Lift: 0.8816 | PASS: False
#   [Weighted] Sup: 0.0156 | Conf: 0.4342 | Lift: 0.7335 | PASS: False
#
# FOV: GVHD_19_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0110 | Conf: 0.4655 | Lift: 1.1481 | PASS: False
#   [Weighted] Sup: 0.0103 | Conf: 0.4359 | Lift: 1.1868 | PASS: False
#
# FOV: GVHD_19_FOV_4 | Transactions: 2250
#   [Binary]   Sup: 0.0169 | Conf: 0.8085 | Lift: 1.9624 | PASS: True
#   [Weighted] Sup: 0.0152 | Conf: 0.7290 | Lift: 2.0111 | PASS: True
#
# FOV: GVHD_20_FOV_1 | Transactions: 1526
#   [Binary]   Sup: 0.0190 | Conf: 0.8788 | Lift: 2.3651 | PASS: True
#   [Weighted] Sup: 0.0158 | Conf: 0.7319 | Lift: 2.2468 | PASS: True
#
# FOV: GVHD_20_FOV_2 | Transactions: 2003
#   [Binary]   Sup: 0.0220 | Conf: 0.8148 | Lift: 2.4691 | PASS: True
#   [Weighted] Sup: 0.0181 | Conf: 0.6726 | Lift: 2.4483 | PASS: True
#
# FOV: GVHD_27_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0284 | Conf: 0.9403 | Lift: 1.9151 | PASS: True
#   [Weighted] Sup: 0.0267 | Conf: 0.8848 | Lift: 1.9239 | PASS: True
#
# FOV: GVHD_27_FOV_2 | Transactions: 2738
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 6.0442 | PASS: False
#   [Weighted] Sup: 0.0012 | Conf: 0.8517 | Lift: 5.9444 | PASS: False
#
# FOV: GVHD_27_FOV_3 | Transactions: 3061
#   [Binary]   Sup: 0.0029 | Conf: 0.9000 | Lift: 6.2897 | PASS: False
#   [Weighted] Sup: 0.0029 | Conf: 0.8749 | Lift: 7.2593 | PASS: False
#
# FOV: GVHD_27_FOV_4 | Transactions: 2161
#   [Binary]   Sup: 0.0074 | Conf: 0.8000 | Lift: 2.3362 | PASS: False
#   [Weighted] Sup: 0.0066 | Conf: 0.7157 | Lift: 2.3737 | PASS: False
#
# FOV: GVHD_27_FOV_5 | Transactions: 2416
#   [Binary]   Sup: 0.0364 | Conf: 0.7333 | Lift: 1.5474 | PASS: True
#   [Weighted] Sup: 0.0323 | Conf: 0.6495 | Lift: 1.5819 | PASS: True
#
# FOV: GVHD_28_FOV_1 | Transactions: 2142
#   [Binary]   Sup: 0.0131 | Conf: 0.6512 | Lift: 1.5959 | PASS: True
#   [Weighted] Sup: 0.0114 | Conf: 0.5702 | Lift: 1.5988 | PASS: True
#
# FOV: GVHD_28_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0113 | Conf: 0.6500 | Lift: 1.5581 | PASS: True
#   [Weighted] Sup: 0.0090 | Conf: 0.5155 | Lift: 1.3924 | PASS: False
#
# FOV: GVHD_28_FOV_3 | Transactions: 2110
#   [Binary]   Sup: 0.0190 | Conf: 0.7273 | Lift: 1.5194 | PASS: True
#   [Weighted] Sup: 0.0167 | Conf: 0.6401 | Lift: 1.4958 | PASS: True
#
# FOV: GVHD_29_FOV_1 | Transactions: 2334
#   [Binary]   Sup: 0.0270 | Conf: 0.6238 | Lift: 1.2872 | PASS: True
#   [Weighted] Sup: 0.0226 | Conf: 0.5233 | Lift: 1.2218 | PASS: True
#
# FOV: GVHD_29_FOV_2 | Transactions: 2393
#   [Binary]   Sup: 0.0301 | Conf: 0.5950 | Lift: 1.0259 | PASS: False
#   [Weighted] Sup: 0.0247 | Conf: 0.4891 | Lift: 0.9943 | PASS: False
#
# FOV: GVHD_29_FOV_3 | Transactions: 2233
#   [Binary]   Sup: 0.0175 | Conf: 0.6724 | Lift: 2.1542 | PASS: True
#   [Weighted] Sup: 0.0155 | Conf: 0.5978 | Lift: 2.2486 | PASS: True
#
# FOV: GVHD_29_FOV_4 | Transactions: 2107
#   [Binary]   Sup: 0.0195 | Conf: 0.6406 | Lift: 1.8773 | PASS: True
#   [Weighted] Sup: 0.0158 | Conf: 0.5191 | Lift: 1.8362 | PASS: True
#
# FOV: GVHD_30_FOV_1 | Transactions: 2235
#   [Binary]   Sup: 0.0121 | Conf: 0.7941 | Lift: 1.8111 | PASS: True
#   [Weighted] Sup: 0.0116 | Conf: 0.7598 | Lift: 1.9024 | PASS: True
#
# FOV: GVHD_30_FOV_2 | Transactions: 2267
#   [Binary]   Sup: 0.0106 | Conf: 0.9231 | Lift: 1.6931 | PASS: True
#   [Weighted] Sup: 0.0094 | Conf: 0.8228 | Lift: 1.6386 | PASS: False
#
# FOV: GVHD_30_FOV_3 | Transactions: 2206
#   [Binary]   Sup: 0.0036 | Conf: 1.0000 | Lift: 2.4511 | PASS: False
#   [Weighted] Sup: 0.0028 | Conf: 0.7728 | Lift: 2.0649 | PASS: False
#
# FOV: GVHD_31_FOV_1 | Transactions: 2168
#   [Binary]   Sup: 0.0198 | Conf: 0.7414 | Lift: 1.2460 | PASS: True
#   [Weighted] Sup: 0.0163 | Conf: 0.6089 | Lift: 1.1190 | PASS: False
#
# FOV: GVHD_31_FOV_2 | Transactions: 2315
#   [Binary]   Sup: 0.0380 | Conf: 0.8224 | Lift: 1.2830 | PASS: True
#   [Weighted] Sup: 0.0327 | Conf: 0.7080 | Lift: 1.2150 | PASS: True
#
# FOV: GVHD_31_FOV_3 | Transactions: 2372
#   [Binary]   Sup: 0.0148 | Conf: 0.3333 | Lift: 1.0743 | PASS: False
#   [Weighted] Sup: 0.0124 | Conf: 0.2808 | Lift: 0.9999 | PASS: False
#
# FOV: GVHD_34_FOV_1 | Transactions: 2224
#   [Binary]   Sup: 0.0144 | Conf: 0.9143 | Lift: 1.2878 | PASS: True
#   [Weighted] Sup: 0.0129 | Conf: 0.8174 | Lift: 1.2378 | PASS: True
#
# FOV: GVHD_34_FOV_2 | Transactions: 2254
#   [Binary]   Sup: 0.0111 | Conf: 0.6944 | Lift: 2.2985 | PASS: True
#   [Weighted] Sup: 0.0086 | Conf: 0.5396 | Lift: 2.1812 | PASS: False
#
# FOV: GVHD_35_FOV_1 | Transactions: 2240
#   [Binary]   Sup: 0.0013 | Conf: 0.4286 | Lift: 2.5600 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.3595 | Lift: 2.9976 | PASS: False
#
# FOV: GVHD_35_FOV_2 | Transactions: 2120
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_36_FOV_1 | Transactions: 2179
#   [Binary]   Sup: 0.0064 | Conf: 0.8750 | Lift: 1.7008 | PASS: False
#   [Weighted] Sup: 0.0056 | Conf: 0.7681 | Lift: 1.6313 | PASS: False
#
# FOV: GVHD_36_FOV_2 | Transactions: 2409
#   [Binary]   Sup: 0.0087 | Conf: 0.7241 | Lift: 1.5302 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.6219 | Lift: 1.3831 | PASS: False
#
# FOV: GVHD_36_FOV_3 | Transactions: 2318
#   [Binary]   Sup: 0.0022 | Conf: 0.6250 | Lift: 1.2164 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 0.5240 | Lift: 1.0838 | PASS: False
#
# FOV: GVHD_38_FOV_1 | Transactions: 1760
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_38_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0118 | Conf: 0.6136 | Lift: 1.5728 | PASS: True
#   [Weighted] Sup: 0.0109 | Conf: 0.5696 | Lift: 1.6894 | PASS: True
#
# FOV: GVHD_43_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0018 | Conf: 0.5000 | Lift: 2.2470 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 0.4699 | Lift: 2.9911 | PASS: False
#
# FOV: GVHD_43_FOV_2 | Transactions: 2110
#   [Binary]   Sup: 0.0071 | Conf: 1.0000 | Lift: 2.4853 | PASS: False
#   [Weighted] Sup: 0.0062 | Conf: 0.8685 | Lift: 2.6588 | PASS: False
#
# FOV: GVHD_44_FOV_1 | Transactions: 1837
#   [Binary]   Sup: 0.0250 | Conf: 0.7419 | Lift: 2.8335 | PASS: True
#   [Weighted] Sup: 0.0224 | Conf: 0.6622 | Lift: 2.9217 | PASS: True
#
# FOV: GVHD_44_FOV_2 | Transactions: 1932
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_47_FOV_1 | Transactions: 2145
#   [Binary]   Sup: 0.0056 | Conf: 1.0000 | Lift: 1.6589 | PASS: False
#   [Weighted] Sup: 0.0050 | Conf: 0.8888 | Lift: 1.7377 | PASS: False
#
# FOV: GVHD_47_FOV_2 | Transactions: 2091
#   [Binary]   Sup: 0.0043 | Conf: 1.0000 | Lift: 1.4081 | PASS: False
#   [Weighted] Sup: 0.0042 | Conf: 0.9642 | Lift: 1.5627 | PASS: False
#
# FOV: GVHD_49_FOV_1 | Transactions: 2531
#   [Binary]   Sup: 0.0174 | Conf: 0.7213 | Lift: 1.4421 | PASS: True
#   [Weighted] Sup: 0.0152 | Conf: 0.6326 | Lift: 1.3971 | PASS: True
#
# FOV: GVHD_49_FOV_2 | Transactions: 2426
#   [Binary]   Sup: 0.0070 | Conf: 0.8500 | Lift: 2.0850 | PASS: False
#   [Weighted] Sup: 0.0053 | Conf: 0.6444 | Lift: 1.8642 | PASS: False
#
# FOV: GVHD_49_FOV_3 | Transactions: 1967
#   [Binary]   Sup: 0.0076 | Conf: 0.7895 | Lift: 1.7870 | PASS: False
#   [Weighted] Sup: 0.0060 | Conf: 0.6169 | Lift: 1.5216 | PASS: False
#
# FOV: GVHD_51_FOV_1 | Transactions: 2527
#   [Binary]   Sup: 0.0265 | Conf: 0.4351 | Lift: 0.6867 | PASS: False
#   [Weighted] Sup: 0.0222 | Conf: 0.3639 | Lift: 0.6468 | PASS: False
#
# FOV: GVHD_51_FOV_2 | Transactions: 2273
#   [Binary]   Sup: 0.0114 | Conf: 0.9630 | Lift: 0.9976 | PASS: False
#   [Weighted] Sup: 0.0109 | Conf: 0.9208 | Lift: 0.9844 | PASS: False
#
# FOV: GVHD_51_FOV_3 | Transactions: 2210
#   [Binary]   Sup: 0.0027 | Conf: 0.7500 | Lift: 0.7829 | PASS: False
#   [Weighted] Sup: 0.0027 | Conf: 0.7500 | Lift: 0.7993 | PASS: False
#
# FOV: GVHD_51_FOV_4 | Transactions: 1873
#   [Binary]   Sup: 0.0064 | Conf: 0.2857 | Lift: 0.6706 | PASS: False
#   [Weighted] Sup: 0.0045 | Conf: 0.1999 | Lift: 0.5440 | PASS: False
#
# FOV: GVHD_52_FOV_1 | Transactions: 2407
#   [Binary]   Sup: 0.0120 | Conf: 0.7436 | Lift: 0.8856 | PASS: False
#   [Weighted] Sup: 0.0108 | Conf: 0.6695 | Lift: 0.8305 | PASS: False
#
# FOV: GVHD_52_FOV_2 | Transactions: 2624
#   [Binary]   Sup: 0.0347 | Conf: 0.7054 | Lift: 0.9732 | PASS: False
#   [Weighted] Sup: 0.0281 | Conf: 0.5725 | Lift: 0.8692 | PASS: False
#
# FOV: GVHD_52_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0253 | Conf: 0.6966 | Lift: 0.8262 | PASS: False
#   [Weighted] Sup: 0.0195 | Conf: 0.5379 | Lift: 0.6903 | PASS: False
#
# FOV: GVHD_52_FOV_4 | Transactions: 2201
#   [Binary]   Sup: 0.0118 | Conf: 0.6667 | Lift: 1.1757 | PASS: False
#   [Weighted] Sup: 0.0107 | Conf: 0.6045 | Lift: 1.1426 | PASS: False
#
# FOV: GVHD_54_FOV_1 | Transactions: 2263
#   [Binary]   Sup: 0.0106 | Conf: 0.5581 | Lift: 2.2475 | PASS: True
#   [Weighted] Sup: 0.0093 | Conf: 0.4910 | Lift: 2.4297 | PASS: False
#
# FOV: GVHD_54_FOV_2 | Transactions: 2289
#   [Binary]   Sup: 0.0083 | Conf: 0.5758 | Lift: 1.1959 | PASS: False
#   [Weighted] Sup: 0.0072 | Conf: 0.5028 | Lift: 1.1777 | PASS: False
#
# FOV: GVHD_54_FOV_3 | Transactions: 2688
#   [Binary]   Sup: 0.0048 | Conf: 0.7222 | Lift: 2.8591 | PASS: False
#   [Weighted] Sup: 0.0048 | Conf: 0.7132 | Lift: 3.1331 | PASS: False
#
# FOV: GVHD_54_FOV_4 | Transactions: 2739
#   [Binary]   Sup: 0.0142 | Conf: 0.9286 | Lift: 3.1245 | PASS: True
#   [Weighted] Sup: 0.0118 | Conf: 0.7723 | Lift: 2.9698 | PASS: True
#
# FOV: GVHD_55_FOV_1 | Transactions: 2553
#   [Binary]   Sup: 0.0024 | Conf: 1.0000 | Lift: 3.5069 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 0.8581 | Lift: 3.5023 | PASS: False
#
# FOV: GVHD_55_FOV_2 | Transactions: 2216
#   [Binary]   Sup: 0.0181 | Conf: 1.0000 | Lift: 2.0054 | PASS: True
#   [Weighted] Sup: 0.0173 | Conf: 0.9565 | Lift: 2.1366 | PASS: True
#
# FOV: GVHD_55_FOV_3 | Transactions: 1786
#   [Binary]   Sup: 0.0062 | Conf: 0.9167 | Lift: 2.1858 | PASS: False
#   [Weighted] Sup: 0.0045 | Conf: 0.6656 | Lift: 1.8332 | PASS: False
#
# FOV: GVHD_56_FOV_1 | Transactions: 2237
#   [Binary]   Sup: 0.0022 | Conf: 0.8333 | Lift: 1.1988 | PASS: False
#   [Weighted] Sup: 0.0022 | Conf: 0.8333 | Lift: 1.3091 | PASS: False
#
# FOV: GVHD_56_FOV_2 | Transactions: 2424
#   [Binary]   Sup: 0.0025 | Conf: 1.0000 | Lift: 1.3032 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 1.0000 | Lift: 1.4253 | PASS: False
#
# FOV: GVHD_56_FOV_3 | Transactions: 2278
#   [Binary]   Sup: 0.0057 | Conf: 0.6842 | Lift: 1.6599 | PASS: False
#   [Weighted] Sup: 0.0048 | Conf: 0.5709 | Lift: 1.5423 | PASS: False
#
# FOV: GVHD_56_FOV_4 | Transactions: 2406
#   [Binary]   Sup: 0.0029 | Conf: 0.6364 | Lift: 1.5466 | PASS: False
#   [Weighted] Sup: 0.0027 | Conf: 0.5826 | Lift: 1.5693 | PASS: False
#
# FOV: GVHD_58_FOV_1 | Transactions: 2377
#   [Binary]   Sup: 0.0088 | Conf: 0.8077 | Lift: 1.1401 | PASS: False
#   [Weighted] Sup: 0.0084 | Conf: 0.7695 | Lift: 1.1705 | PASS: False
#
# FOV: GVHD_58_FOV_2 | Transactions: 2628
#   [Binary]   Sup: 0.0080 | Conf: 0.7778 | Lift: 1.9864 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.7300 | Lift: 2.0513 | PASS: False
#
# FOV: GVHD_58_FOV_3 | Transactions: 2730
#   [Binary]   Sup: 0.0081 | Conf: 0.7586 | Lift: 1.9018 | PASS: False
#   [Weighted] Sup: 0.0062 | Conf: 0.5881 | Lift: 1.6756 | PASS: False
#
# FOV: GVHD_58_FOV_4 | Transactions: 2447
#   [Binary]   Sup: 0.0094 | Conf: 0.3710 | Lift: 0.8952 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.2966 | Lift: 0.7865 | PASS: False
#
# FOV: GVHD_60_FOV_1 | Transactions: 1962
#   [Binary]   Sup: 0.0153 | Conf: 0.7143 | Lift: 1.3024 | PASS: True
#   [Weighted] Sup: 0.0137 | Conf: 0.6383 | Lift: 1.2683 | PASS: True
#
# FOV: GVHD_60_FOV_2 | Transactions: 1949
#   [Binary]   Sup: 0.0205 | Conf: 0.6780 | Lift: 1.4897 | PASS: True
#   [Weighted] Sup: 0.0177 | Conf: 0.5843 | Lift: 1.4155 | PASS: True
#
# FOV: GVHD_60_FOV_3 | Transactions: 2138
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 30 / 103
# FOVs passing Weighted FP-Growth (Distance-decay): 24 / 103
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:           30 |           24  (out of 103 valid FOVs)
# Support :       0.0100 |       0.0085
# Conf    :       0.5870 |       0.5000
# Lift    :       1.3179 |       1.2642
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0183 |       0.0137
# Conf    :       0.7432 |       0.6507
# Lift    :       1.6812 |       2.1288
#
# Visualizing Representative FOV: GVHD_05_FOV_2_R (375 matching antecedent cells)

# %%
metrics = evaluate_cohort("Duodenum - Severe", duodenum_severe_fovs, df_cells)
if not metrics.empty:
    STAGE_FOV_METRICS.append(metrics)
plot_stage_metric_distributions(STAGE_FOV_METRICS, organ="Duodenum", stage_column=STAGE_COLUMN)
# Out:
# ==============================================
# Evaluating Cohort: Duodenum - Severe
# ==============================================
#
# FOV: GVHD_02_FOV_1_R | Transactions: 1977
#   [Binary]   Sup: 0.0182 | Conf: 0.1075 | Lift: 0.6002 | PASS: False
#   [Weighted] Sup: 0.0104 | Conf: 0.0614 | Lift: 0.4680 | PASS: False
#
# FOV: GVHD_02_FOV_2_R | Transactions: 1722
#   [Binary]   Sup: 0.0099 | Conf: 0.0929 | Lift: 0.7110 | PASS: False
#   [Weighted] Sup: 0.0074 | Conf: 0.0695 | Lift: 0.7218 | PASS: False
#
# FOV: GVHD_06_FOV_1 | Transactions: 2174
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_2 | Transactions: 2265
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_3 | Transactions: 1998
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_4 | Transactions: 2040
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_5 | Transactions: 2233
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_1 | Transactions: 2672
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_2 | Transactions: 2496
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_3 | Transactions: 2107
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_09_FOV_1 | Transactions: 2477
#   [Binary]   Sup: 0.0024 | Conf: 0.8571 | Lift: 1.6784 | PASS: False
#   [Weighted] Sup: 0.0021 | Conf: 0.7568 | Lift: 1.6102 | PASS: False
#
# FOV: GVHD_09_FOV_2 | Transactions: 2121
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.1647 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.2117 | PASS: False
#
# FOV: GVHD_09_FOV_3 | Transactions: 2765
#   [Binary]   Sup: 0.0014 | Conf: 0.5714 | Lift: 1.2373 | PASS: False
#   [Weighted] Sup: 0.0011 | Conf: 0.4271 | Lift: 0.9950 | PASS: False
#
# FOV: GVHD_09_FOV_4 | Transactions: 2233
#   [Binary]   Sup: 0.0063 | Conf: 1.0000 | Lift: 1.6853 | PASS: False
#   [Weighted] Sup: 0.0058 | Conf: 0.9316 | Lift: 1.6635 | PASS: True
#
# FOV: GVHD_11_FOV_1 | Transactions: 2608
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_11_FOV_2 | Transactions: 2600
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_11_FOV_3 | Transactions: 2441
#   [Binary]   Sup: 0.0004 | Conf: 0.2000 | Lift: 1.3375 | PASS: False
#   [Weighted] Sup: 0.0002 | Conf: 0.1049 | Lift: 1.0116 | PASS: False
#
# FOV: GVHD_11_FOV_4 | Transactions: 1796
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_14_FOV_1 | Transactions: 2206
#   [Binary]   Sup: 0.0014 | Conf: 0.6000 | Lift: 1.4006 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 0.3900 | Lift: 1.0223 | PASS: False
#
# FOV: GVHD_14_FOV_2 | Transactions: 2210
#   [Binary]   Sup: 0.0059 | Conf: 0.9286 | Lift: 1.8065 | PASS: False
#   [Weighted] Sup: 0.0046 | Conf: 0.7212 | Lift: 1.5299 | PASS: False
#
# FOV: GVHD_14_FOV_3 | Transactions: 2000
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4296 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.5858 | PASS: False
#
# FOV: GVHD_14_FOV_4 | Transactions: 2703
#   [Binary]   Sup: 0.0015 | Conf: 0.8000 | Lift: 1.9256 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 0.7087 | Lift: 1.8442 | PASS: False
#
# FOV: GVHD_14_FOV_5 | Transactions: 2412
#   [Binary]   Sup: 0.0087 | Conf: 0.8400 | Lift: 2.4618 | PASS: False
#   [Weighted] Sup: 0.0075 | Conf: 0.7250 | Lift: 2.4268 | PASS: False
#
# FOV: GVHD_24_FOV_1 | Transactions: 2262
#   [Binary]   Sup: 0.0013 | Conf: 0.2143 | Lift: 12.7556 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 0.1675 | Lift: 12.5633 | PASS: False
#
# FOV: GVHD_24_FOV_2 | Transactions: 2001
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_24_FOV_3 | Transactions: 1589
#   [Binary]   Sup: 0.0031 | Conf: 0.7143 | Lift: 4.7890 | PASS: False
#   [Weighted] Sup: 0.0031 | Conf: 0.7143 | Lift: 6.3234 | PASS: False
#
# FOV: GVHD_24_FOV_4 | Transactions: 1483
#   [Binary]   Sup: 0.0081 | Conf: 1.0000 | Lift: 9.0427 | PASS: False
#   [Weighted] Sup: 0.0081 | Conf: 1.0000 | Lift: 12.6562 | PASS: True
#
# FOV: GVHD_26_FOV_1 | Transactions: 2686
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_2 | Transactions: 2425
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_3 | Transactions: 2362
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_4 | Transactions: 2534
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_57_FOV_1 | Transactions: 2427
#   [Binary]   Sup: 0.0272 | Conf: 0.9851 | Lift: 2.6564 | PASS: True
#   [Weighted] Sup: 0.0257 | Conf: 0.9321 | Lift: 3.0369 | PASS: True
#
# FOV: GVHD_57_FOV_2 | Transactions: 2178
#   [Binary]   Sup: 0.0179 | Conf: 0.9512 | Lift: 1.0559 | PASS: False
#   [Weighted] Sup: 0.0170 | Conf: 0.9019 | Lift: 1.0546 | PASS: False
#
# FOV: GVHD_57_FOV_3 | Transactions: 2036
#   [Binary]   Sup: 0.0049 | Conf: 0.8333 | Lift: 1.4092 | PASS: False
#   [Weighted] Sup: 0.0049 | Conf: 0.8333 | Lift: 1.5724 | PASS: False
#
# FOV: GVHD_57_FOV_4 | Transactions: 2196
#   [Binary]   Sup: 0.0128 | Conf: 1.0000 | Lift: 1.7526 | PASS: True
#   [Weighted] Sup: 0.0128 | Conf: 1.0000 | Lift: 1.8115 | PASS: True
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_Ki67+_NEIGHBOR (rule-aware)]
# FOVs passing standard FP-Growth (Binary): 2 / 36
# FOVs passing Weighted FP-Growth (Distance-decay): 4 / 36
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            2 |            4  (out of 36 valid FOVs)
# Support :       0.0035 |       0.0031
# Conf    :       0.3586 |       0.3127
# Lift    :       1.5506 |       1.5039
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0203 |       0.0250
# Conf    :       0.9895 |       0.9545
# Lift    :       2.1246 |       1.3272
#
# Visualizing Representative FOV: GVHD_02_FOV_1_R (335 matching antecedent cells)
