# %% [markdown]
# # Investigation: Paneth -> Epithelial rule (Multi-Stage Evaluation)
#
# This notebook investigates the association rule **Paneth -> Epithelial** across different disease stages (Control, Mild, Severe). It calculates per-FOV metrics to directly compare standard FP-Growth (binary) vs Weighted FP-Growth (distance-decay) pass rates.

# %%
import pandas as pd
import numpy as np
import os
import sys
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
import warnings
warnings.filterwarnings('ignore')

# Add root to path for constants and utils
sys.path.append(os.path.abspath('../../'))
import constants
from utils.rules import build_cell_item_token, passes_rule_support_policy, _extract_base_lineage

RADIUS = constants.CONFIG['RADIUS']
BANDWIDTH = constants.CONFIG.get('BANDWIDTH', RADIUS)
MIN_SUPPORT = constants.CONFIG['MIN_SUPPORT']
MIN_ABS_SUPPORT = constants.CONFIG.get('MIN_ABS_SUPPORT', 5)
MIN_CONFIDENCE = constants.CONFIG['MIN_CONFIDENCE']
MIN_LIFT = constants.CONFIG['MIN_LIFT']

ANTECEDENT_REQUIRED_MARKERS = ()
CONSEQUENT_REQUIRED_MARKERS = ()

ANTECEDENT_BASE = 'Paneth'
CONSEQUENT_BASE = 'Epithelial'

# %% [markdown]
# ## Step 1: Data Loading & Functional Subtypes
#
# Load the cell and metadata tables, identify disease stages, and append the `functional_subtypes` array to every cell.

# %%
def _add_functional_subtypes(df):
    if not constants.USE_FUNCTIONAL_MARKERS:
        df["functional_subtypes"] = [[] for _ in range(len(df))]
        return df
    functional_subtypes_list = [[] for _ in range(len(df))]
    idx_to_pos = {idx: i for i, idx in enumerate(df.index)}
    for base_type, markers in constants.CELLTYPE_MARKER_THRESHOLDS.items():
        type_mask = df["cell type"] == base_type
        for marker, threshold in markers.items():
            if marker in df.columns:
                mask = type_mask & (df[marker] > threshold)
                subtype_label = f"{base_type}_{marker}+"
                matching_indices = df.index[mask]
                for idx in matching_indices:
                    functional_subtypes_list[idx_to_pos[idx]].append(subtype_label)
    df["functional_subtypes"] = functional_subtypes_list
    return df

cell_table_path = '../../data/MIBIGutCsv/cell_table.csv'
fov_meta_path = '../../data/MIBIGutCsv/fovs_metadata.csv'
biopsy_meta_path = '../../data/MIBIGutCsv/biopsy_metadata.csv'

df_cells = pd.read_csv(cell_table_path)
df_fovs = pd.read_csv(fov_meta_path)
df_biopsy = pd.read_csv(biopsy_meta_path)

# Merge FOV with Biopsy to get Pathological score
df_fovs = pd.merge(df_fovs, df_biopsy[['Biopsy_ID', 'Pathological score']], left_on='Patient', right_on='Biopsy_ID', how='left')

# Define FOV lists for each cohort
control_cohorts = ['Duodenum_Cohort_Control_1', 'Duodenum_Cohort_Control_2', 'Colon_Cohort_Control']
control_fovs = df_fovs[df_fovs['Cohort'].isin(control_cohorts)]['FOV'].tolist()
mild_fovs = df_fovs[df_fovs['Pathological score'] == 'Mild']['FOV'].tolist()
severe_fovs = df_fovs[df_fovs['Pathological score'] == 'Severe']['FOV'].tolist()

# Normalize Coordinates
fov_to_size = df_fovs.set_index('FOV')['Size [um]'].to_dict()
def normalize_coords(row):
    size = fov_to_size.get(row['fov'], 800)
    res = 1024 if size == 400 else 2048
    return row['centroid_x'] * (size / res), row['centroid_y'] * (size / res)

df_cells[['x_um', 'y_um']] = df_cells.apply(lambda row: pd.Series(normalize_coords(row)), axis=1)

# Add Functional Subtypes
df_cells = _add_functional_subtypes(df_cells)

print(f"Total Cells: {len(df_cells)}")
print(f"Control FOVs: {len(control_fovs)}")
print(f"Mild FOVs: {len(mild_fovs)}")
print(f"Severe FOVs: {len(severe_fovs)}")
# Out:
# Total Cells: 713372
# Control FOVs: 77
# Mild FOVs: 143
# Severe FOVs: 68

# %% [markdown]
# ## Step 2: Evaluation Framework
#
# Define a reusable function that iterates over a given list of FOVs, computes both binary and weighted metrics *per FOV*, and verifies how many FOVs pass the algorithm thresholds. Finally, it visualizes the FOV with the highest target cell density.

# %%
def evaluate_cohort(cohort_name, fov_list, df_cells_all):
    print(f"==============================================")
    print(f"Evaluating Cohort: {cohort_name}")
    print(f"==============================================\n")

    binary_pass_count = 0
    weighted_pass_count = 0
    valid_fovs = 0

    global_binary_transactions = []
    global_weighted_transactions = []
    passing_binary_transactions = []
    passing_weighted_transactions = []

    max_target_count = -1
    max_target_fov = None

    def _parse_token(token, suffix):
        token = str(token)
        tail = f"_{suffix}"
        if not token.endswith(tail):
            return None, set()
        core = token[:-len(tail)]
        base = _extract_base_lineage(core)
        markers = {part for part in core.split('_') if part.endswith('+')}
        return base, markers

    def _matches_rule_item(token, base, suffix, required_markers=()):
        token_base, token_markers = _parse_token(token, suffix)
        if token_base != base:
            return False
        return set(required_markers).issubset(token_markers)

    def _has_item(binary_trans, base, suffix, required_markers=()):
        return any(_matches_rule_item(item, base, suffix, required_markers) for item in binary_trans)

    def _weight_for_item(weighted_trans, base, suffix, required_markers=()):
        return min(
            sum(float(v) for k, v in weighted_trans.items() if _matches_rule_item(k, base, suffix, required_markers)),
            1.0,
        )

    def _rule_item_label(base, required_markers):
        if not required_markers:
            return base
        return f"{base}_{'_'.join(required_markers)}"

    for fov in fov_list:
        fov_data = df_cells_all[df_cells_all['fov'] == fov]
        if fov_data.empty:
            continue
        valid_fovs += 1

        coords = fov_data[['x_um', 'y_um']].values
        types = fov_data['cell type'].values
        subtypes = fov_data['functional_subtypes'].values

        target_count = sum(
            1
            for t, st in zip(types, subtypes)
            if _matches_rule_item(
                build_cell_item_token(t, st, suffix='CENTER'),
                ANTECEDENT_BASE,
                'CENTER',
                ANTECEDENT_REQUIRED_MARKERS,
            )
        )
        if target_count > max_target_count:
            max_target_count = target_count
            max_target_fov = fov

        nn = NearestNeighbors(radius=RADIUS).fit(coords)
        distances, neighbors_idx = nn.radius_neighbors(coords, return_distance=True)

        fov_binary_trans = []
        fov_weighted_trans = []

        for i, (idxs, dists) in enumerate(zip(neighbors_idx, distances)):
            if len(idxs) < constants.CONFIG.get("MIN_CELLS_PER_PATCH", 2):
                continue

            center_token = build_cell_item_token(types[i], subtypes[i], suffix='CENTER')

            b_trans = {center_token}
            w_trans = {center_token: 1.0}

            for n_idx, d in zip(idxs, dists):
                if n_idx == i:
                    continue

                neighbor_token = build_cell_item_token(types[n_idx], subtypes[n_idx], suffix='NEIGHBOR')
                b_trans.add(neighbor_token)

                w = np.exp(-0.5 * (d / BANDWIDTH) ** 2)
                w_trans[neighbor_token] = w_trans.get(neighbor_token, 0.0) + w

            w_trans = {k: min(v, 1.0) for k, v in w_trans.items()}

            fov_binary_trans.append(b_trans)
            fov_weighted_trans.append(w_trans)
            global_binary_transactions.append(b_trans)
            global_weighted_transactions.append(w_trans)

        n_trans = len(fov_binary_trans)
        if n_trans == 0:
            print(f"FOV: {fov} | 0 Transactions")
            continue

        b_sup_ant = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_con = sum(
            1 for t in fov_binary_trans
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_sup_joint = sum(
            1 for t in fov_binary_trans
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / n_trans
        b_conf = b_sup_joint / b_sup_ant if b_sup_ant > 0 else 0
        b_lift = b_conf / b_sup_con if b_sup_con > 0 else 0

        b_pass = False
        if b_sup_joint >= MIN_SUPPORT and b_conf >= MIN_CONFIDENCE and b_lift >= MIN_LIFT:
            binary_pass_count += 1
            b_pass = True

        w_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in fov_weighted_trans
        ) / n_trans
        w_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in fov_weighted_trans
        ) / n_trans
        w_conf = w_sup_joint / w_sup_ant if w_sup_ant > 0 else 0
        w_lift = w_conf / w_sup_con if w_sup_con > 0 else 0

        w_pass = False
        if (
            passes_rule_support_policy(constants.CONFIG, w_sup_joint, w_conf, w_lift, num_transactions=n_trans)
            and w_conf >= MIN_CONFIDENCE
            and w_lift >= MIN_LIFT
        ):
            weighted_pass_count += 1
            w_pass = True

        if b_pass:
            passing_binary_transactions.extend(fov_binary_trans)
        if w_pass:
            passing_weighted_transactions.extend(fov_weighted_trans)

        print(f"FOV: {fov} | Transactions: {n_trans}")
        print(f"  [Binary]   Sup: {b_sup_joint:.4f} | Conf: {b_conf:.4f} | Lift: {b_lift:.4f} | PASS: {b_pass}")
        print(f"  [Weighted] Sup: {w_sup_joint:.4f} | Conf: {w_conf:.4f} | Lift: {w_lift:.4f} | PASS: {w_pass}\n")

    ant_label = _rule_item_label(ANTECEDENT_BASE, ANTECEDENT_REQUIRED_MARKERS)
    con_label = _rule_item_label(CONSEQUENT_BASE, CONSEQUENT_REQUIRED_MARKERS)
    print(f"\n[Algorithm Comparison: {ant_label}_CENTER -> {con_label}_NEIGHBOR (rule-aware)]")
    print(f"FOVs passing standard FP-Growth (Binary): {binary_pass_count} / {valid_fovs}")
    print(f"FOVs passing Weighted FP-Growth (Distance-decay): {weighted_pass_count} / {valid_fovs}")

    if not global_binary_transactions:
        return

    g_n_trans = len(global_binary_transactions)
    gb_sup_ant = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_con = sum(
        1 for t in global_binary_transactions
        if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_sup_joint = sum(
        1 for t in global_binary_transactions
        if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
    ) / g_n_trans
    gb_conf = gb_sup_joint / gb_sup_ant if gb_sup_ant > 0 else 0
    gb_lift = gb_conf / gb_sup_con if gb_sup_con > 0 else 0

    gw_sup_ant = sum(
        _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_con = sum(
        _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_sup_joint = sum(
        min(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
        )
        for t in global_weighted_transactions
    ) / g_n_trans
    gw_conf = gw_sup_joint / gw_sup_ant if gw_sup_ant > 0 else 0
    gw_lift = gw_conf / gw_sup_con if gw_sup_con > 0 else 0

    if passing_binary_transactions:
        p_n_trans = len(passing_binary_transactions)
        pb_sup_ant = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_con = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_sup_joint = sum(
            1 for t in passing_binary_transactions
            if _has_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            and _has_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
        ) / p_n_trans
        pb_conf = pb_sup_joint / pb_sup_ant if pb_sup_ant > 0 else 0
        pb_lift = pb_conf / pb_sup_con if pb_sup_con > 0 else 0

        pw_sup_ant = sum(
            _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_con = sum(
            _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS)
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_sup_joint = sum(
            min(
                _weight_for_item(t, ANTECEDENT_BASE, 'CENTER', ANTECEDENT_REQUIRED_MARKERS),
                _weight_for_item(t, CONSEQUENT_BASE, 'NEIGHBOR', CONSEQUENT_REQUIRED_MARKERS),
            )
            for t in passing_weighted_transactions
        ) / p_n_trans
        pw_conf = pw_sup_joint / pw_sup_ant if pw_sup_ant > 0 else 0
        pw_lift = pw_conf / pw_sup_con if pw_sup_con > 0 else 0
    else:
        pb_sup_joint = pb_conf = pb_lift = 0
        pw_sup_joint = pw_conf = pw_lift = 0

    print(f"\n[Aggregate Metrics: ALL FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Approved: {binary_pass_count:>12} | {weighted_pass_count:>12}  (out of {valid_fovs} valid FOVs)")
    print(f"Support : {gb_sup_joint:>12.4f} | {gw_sup_joint:>12.4f}")
    print(f"Conf    : {gb_conf:>12.4f} | {gw_conf:>12.4f}")
    print(f"Lift    : {gb_lift:>12.4f} | {gw_lift:>12.4f}")

    print(f"\n[Aggregate Metrics: ONLY PASSING FOVs]")
    print(f"          {'Binary':>12} | {'Weighted':>12}")
    print(f"Support : {pb_sup_joint:>12.4f} | {pw_sup_joint:>12.4f}")
    print(f"Conf    : {pb_conf:>12.4f} | {pw_conf:>12.4f}")
    print(f"Lift    : {pb_lift:>12.4f} | {pw_lift:>12.4f}")

    if max_target_fov:
        print(f"\nVisualizing Representative FOV: {max_target_fov} ({max_target_count} matching antecedent cells)")
        _plot_fov(max_target_fov, df_cells_all)

def _plot_fov(fov, df_cells_all):
    fov_df = df_cells_all[df_cells_all['fov'] == fov].copy()

    def get_plot_class(row):
        if row['cell type'] == 'Paneth': return 'Paneth'
        elif row['cell type'] == 'Epithelial': return 'Epithelial'
        return 'Other'
        
    fov_df['PlotClass'] = fov_df.apply(get_plot_class, axis=1)
    
    import matplotlib.pyplot as plt
    import seaborn as sns
    plt.figure(figsize=(10, 10))
    others = fov_df[fov_df['PlotClass'] == 'Other']
    sns.scatterplot(data=others, x='x_um', y='y_um', color='lightgrey', alpha=0.3, s=20)
    epi = fov_df[fov_df['PlotClass'] == 'Epithelial']
    sns.scatterplot(data=epi, x='x_um', y='y_um', color='blue', alpha=0.5, s=30, label='Epithelial')
    target = fov_df[fov_df['PlotClass'] == 'Paneth']
    sns.scatterplot(data=target, x='x_um', y='y_um', color='red', s=70, edgecolor='black', zorder=10, label='Paneth')

    plt.title(f"Spatial Distribution in FOV {fov}")
    plt.legend(bbox_to_anchor=(1.05, 1), loc=2)
    plt.show()

# %% [markdown]
# ## Step 3: Run Evaluation on Control Cohort

# %%
evaluate_cohort("Control", control_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Control
# ==============================================
#
# FOV: Control_01_FOV_1 | Transactions: 2618
#   [Binary]   Sup: 0.0115 | Conf: 1.0000 | Lift: 2.1233 | PASS: True
#   [Weighted] Sup: 0.0115 | Conf: 1.0000 | Lift: 2.3447 | PASS: True
#
# FOV: Control_01_FOV_2 | Transactions: 2354
#   [Binary]   Sup: 0.0051 | Conf: 1.0000 | Lift: 1.3071 | PASS: False
#   [Weighted] Sup: 0.0051 | Conf: 1.0000 | Lift: 1.4045 | PASS: True
#
# FOV: Control_01_FOV_3 | Transactions: 2157
#   [Binary]   Sup: 0.0130 | Conf: 1.0000 | Lift: 1.3600 | PASS: True
#   [Weighted] Sup: 0.0130 | Conf: 1.0000 | Lift: 1.4030 | PASS: True
#
# FOV: Control_01_FOV_4 | Transactions: 2140
#   [Binary]   Sup: 0.0210 | Conf: 1.0000 | Lift: 1.0743 | PASS: False
#   [Weighted] Sup: 0.0210 | Conf: 1.0000 | Lift: 1.1066 | PASS: False
#
# FOV: Control_02_FOV_1 | Transactions: 2305
#   [Binary]   Sup: 0.0061 | Conf: 1.0000 | Lift: 1.3761 | PASS: False
#   [Weighted] Sup: 0.0057 | Conf: 0.9454 | Lift: 1.3762 | PASS: True
#
# FOV: Control_02_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0049 | Conf: 1.0000 | Lift: 1.5398 | PASS: False
#   [Weighted] Sup: 0.0049 | Conf: 1.0000 | Lift: 1.6193 | PASS: False
#
# FOV: Control_02_FOV_3 | Transactions: 2040
#   [Binary]   Sup: 0.0039 | Conf: 1.0000 | Lift: 1.0625 | PASS: False
#   [Weighted] Sup: 0.0039 | Conf: 1.0000 | Lift: 1.1006 | PASS: False
#
# FOV: Control_02_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0088 | Conf: 1.0000 | Lift: 1.3480 | PASS: False
#   [Weighted] Sup: 0.0085 | Conf: 0.9668 | Lift: 1.3904 | PASS: True
#
# FOV: Control_03_FOV_1 | Transactions: 2074
#   [Binary]   Sup: 0.0130 | Conf: 1.0000 | Lift: 1.2086 | PASS: True
#   [Weighted] Sup: 0.0130 | Conf: 1.0000 | Lift: 1.2573 | PASS: True
#
# FOV: Control_03_FOV_2 | Transactions: 1916
#   [Binary]   Sup: 0.0099 | Conf: 0.9500 | Lift: 1.2544 | PASS: False
#   [Weighted] Sup: 0.0092 | Conf: 0.8841 | Lift: 1.2229 | PASS: False
#
# FOV: Control_03_FOV_3 | Transactions: 1884
#   [Binary]   Sup: 0.0064 | Conf: 1.0000 | Lift: 1.2984 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 0.9943 | Lift: 1.3607 | PASS: True
#
# FOV: Control_04_FOV_1 | Transactions: 2290
#   [Binary]   Sup: 0.0066 | Conf: 1.0000 | Lift: 1.2938 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 0.9684 | Lift: 1.3340 | PASS: True
#
# FOV: Control_04_FOV_2 | Transactions: 1911
#   [Binary]   Sup: 0.0162 | Conf: 1.0000 | Lift: 1.2353 | PASS: True
#   [Weighted] Sup: 0.0158 | Conf: 0.9760 | Lift: 1.2489 | PASS: True
#
# FOV: Control_05_FOV_1 | Transactions: 1924
#   [Binary]   Sup: 0.0104 | Conf: 1.0000 | Lift: 1.2801 | PASS: True
#   [Weighted] Sup: 0.0104 | Conf: 1.0000 | Lift: 1.3642 | PASS: True
#
# FOV: Control_05_FOV_2 | Transactions: 1753
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_06_FOV_1 | Transactions: 1723
#   [Binary]   Sup: 0.0192 | Conf: 1.0000 | Lift: 1.1916 | PASS: False
#   [Weighted] Sup: 0.0181 | Conf: 0.9475 | Lift: 1.1912 | PASS: False
#
# FOV: Control_06_FOV_2 | Transactions: 1651
#   [Binary]   Sup: 0.0006 | Conf: 1.0000 | Lift: 1.0110 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 1.0000 | Lift: 1.0142 | PASS: False
#
# FOV: Control_06_FOV_3 | Transactions: 1308
#   [Binary]   Sup: 0.0199 | Conf: 1.0000 | Lift: 1.5893 | PASS: True
#   [Weighted] Sup: 0.0197 | Conf: 0.9902 | Lift: 1.8291 | PASS: True
#
# FOV: Control_07_FOV_1 | Transactions: 2317
#   [Binary]   Sup: 0.0129 | Conf: 0.9677 | Lift: 1.3739 | PASS: True
#   [Weighted] Sup: 0.0129 | Conf: 0.9671 | Lift: 1.4188 | PASS: True
#
# FOV: Control_07_FOV_2 | Transactions: 1811
#   [Binary]   Sup: 0.0083 | Conf: 0.8824 | Lift: 1.2866 | PASS: False
#   [Weighted] Sup: 0.0081 | Conf: 0.8611 | Lift: 1.4054 | PASS: False
#
# FOV: Control_07_FOV_3 | Transactions: 1913
#   [Binary]   Sup: 0.0188 | Conf: 1.0000 | Lift: 1.2917 | PASS: True
#   [Weighted] Sup: 0.0188 | Conf: 0.9975 | Lift: 1.3334 | PASS: True
#
# FOV: Control_08_FOV_1 | Transactions: 1954
#   [Binary]   Sup: 0.0399 | Conf: 0.9630 | Lift: 1.3040 | PASS: True
#   [Weighted] Sup: 0.0399 | Conf: 0.9624 | Lift: 1.3378 | PASS: True
#
# FOV: Control_08_FOV_2 | Transactions: 1657
#   [Binary]   Sup: 0.0006 | Conf: 1.0000 | Lift: 1.0061 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 1.0000 | Lift: 1.0156 | PASS: False
#
# FOV: Control_08_FOV_3 | Transactions: 2070
#   [Binary]   Sup: 0.0087 | Conf: 1.0000 | Lift: 1.4385 | PASS: False
#   [Weighted] Sup: 0.0087 | Conf: 1.0000 | Lift: 1.4949 | PASS: True
#
# FOV: Control_09_FOV_1 | Transactions: 2375
#   [Binary]   Sup: 0.0051 | Conf: 1.0000 | Lift: 1.9030 | PASS: False
#   [Weighted] Sup: 0.0051 | Conf: 1.0000 | Lift: 2.1408 | PASS: True
#
# FOV: Control_09_FOV_2 | Transactions: 2644
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_09_FOV_3 | Transactions: 2064
#   [Binary]   Sup: 0.0068 | Conf: 1.0000 | Lift: 1.3769 | PASS: False
#   [Weighted] Sup: 0.0068 | Conf: 1.0000 | Lift: 1.4583 | PASS: True
#
# FOV: Control_09_FOV_4 | Transactions: 1977
#   [Binary]   Sup: 0.0051 | Conf: 1.0000 | Lift: 1.1629 | PASS: False
#   [Weighted] Sup: 0.0047 | Conf: 0.9353 | Lift: 1.1752 | PASS: False
#
# FOV: Control_10_FOV_2 | Transactions: 1966
#   [Binary]   Sup: 0.0036 | Conf: 1.0000 | Lift: 1.0277 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 1.0000 | Lift: 1.0439 | PASS: False
#
# FOV: Control_10_FOV_3 | Transactions: 1797
#   [Binary]   Sup: 0.0072 | Conf: 1.0000 | Lift: 1.0322 | PASS: False
#   [Weighted] Sup: 0.0072 | Conf: 1.0000 | Lift: 1.0601 | PASS: False
#
# FOV: Control_10_FOV_4 | Transactions: 2073
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0534 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0753 | PASS: False
#
# FOV: S_01_FOV_1 | Transactions: 5113
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.1297 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 1.1692 | PASS: False
#
# FOV: S_01_FOV_2 | Transactions: 6563
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.4520 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.5578 | PASS: False
#
# FOV: S_01_FOV_3 | Transactions: 6849
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.1004 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.1351 | PASS: False
#
# FOV: S_01_FOV_4 | Transactions: 6070
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_02_FOV_1 | Transactions: 6163
#   [Binary]   Sup: 0.0006 | Conf: 1.0000 | Lift: 1.2054 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 1.0000 | Lift: 1.2716 | PASS: False
#
# FOV: S_02_FOV_2 | Transactions: 5802
#   [Binary]   Sup: 0.0034 | Conf: 1.0000 | Lift: 1.2184 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 0.8819 | Lift: 1.1383 | PASS: False
#
# FOV: S_02_FOV_3 | Transactions: 6259
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4209 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.5142 | PASS: False
#
# FOV: S_02_FOV_4 | Transactions: 5914
#   [Binary]   Sup: 0.0007 | Conf: 1.0000 | Lift: 1.2901 | PASS: False
#   [Weighted] Sup: 0.0007 | Conf: 1.0000 | Lift: 1.3553 | PASS: False
#
# FOV: S_02_FOV_5 | Transactions: 5174
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_03_FOV_1 | Transactions: 5245
#   [Binary]   Sup: 0.0074 | Conf: 1.0000 | Lift: 1.2130 | PASS: False
#   [Weighted] Sup: 0.0073 | Conf: 0.9879 | Lift: 1.2650 | PASS: True
#
# FOV: S_03_FOV_10 | Transactions: 5116
#   [Binary]   Sup: 0.0066 | Conf: 1.0000 | Lift: 1.3679 | PASS: False
#   [Weighted] Sup: 0.0066 | Conf: 0.9938 | Lift: 1.4695 | PASS: True
#
# FOV: S_03_FOV_2 | Transactions: 5494
#   [Binary]   Sup: 0.0024 | Conf: 1.0000 | Lift: 1.1797 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 1.0000 | Lift: 1.2607 | PASS: False
#
# FOV: S_03_FOV_3 | Transactions: 6689
#   [Binary]   Sup: 0.0046 | Conf: 1.0000 | Lift: 1.4529 | PASS: False
#   [Weighted] Sup: 0.0046 | Conf: 0.9914 | Lift: 1.5471 | PASS: False
#
# FOV: S_03_FOV_4 | Transactions: 5343
#   [Binary]   Sup: 0.0041 | Conf: 1.0000 | Lift: 1.4259 | PASS: False
#   [Weighted] Sup: 0.0041 | Conf: 0.9980 | Lift: 1.5352 | PASS: False
#
# FOV: S_03_FOV_5 | Transactions: 5158
#   [Binary]   Sup: 0.0052 | Conf: 1.0000 | Lift: 1.2275 | PASS: False
#   [Weighted] Sup: 0.0052 | Conf: 1.0000 | Lift: 1.2955 | PASS: True
#
# FOV: S_03_FOV_6 | Transactions: 4794
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 1.2045 | PASS: False
#   [Weighted] Sup: 0.0015 | Conf: 1.0000 | Lift: 1.2724 | PASS: False
#
# FOV: S_03_FOV_7 | Transactions: 5981
#   [Binary]   Sup: 0.0035 | Conf: 1.0000 | Lift: 1.5773 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 0.9832 | Lift: 1.6971 | PASS: False
#
# FOV: S_03_FOV_8 | Transactions: 5875
#   [Binary]   Sup: 0.0031 | Conf: 1.0000 | Lift: 1.1463 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 0.9785 | Lift: 1.1682 | PASS: False
#
# FOV: S_03_FOV_9 | Transactions: 4546
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: S_04_FOV_1 | Transactions: 3501
#   [Binary]   Sup: 0.0031 | Conf: 0.9167 | Lift: 1.4045 | PASS: False
#   [Weighted] Sup: 0.0031 | Conf: 0.9156 | Lift: 1.5201 | PASS: False
#
# FOV: S_04_FOV_2 | Transactions: 3544
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 1.2612 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 1.3470 | PASS: False
#
# FOV: Control_Colon_01_FOV_1 | Transactions: 1401
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_2 | Transactions: 1778
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_3 | Transactions: 1624
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_4 | Transactions: 2046
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_5 | Transactions: 1877
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_6 | Transactions: 5270
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_01_FOV_7 | Transactions: 5502
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_1 | Transactions: 1743
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_2 | Transactions: 1901
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_3 | Transactions: 1706
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_02_FOV_4 | Transactions: 1882
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.3667 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4961 | PASS: False
#
# FOV: Control_Colon_02_FOV_5 | Transactions: 5686
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.8735 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 2.1406 | PASS: False
#
# FOV: Control_Colon_02_FOV_6 | Transactions: 5706
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.8520 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 2.0779 | PASS: False
#
# FOV: Control_Colon_03_FOV_1 | Transactions: 1672
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_2 | Transactions: 1846
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_3 | Transactions: 1850
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_4 | Transactions: 1834
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_5 | Transactions: 5717
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_03_FOV_6 | Transactions: 6034
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_1 | Transactions: 2273
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_2 | Transactions: 2379
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_3 | Transactions: 2357
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_4 | Transactions: 2294
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_5 | Transactions: 7392
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: Control_Colon_04_FOV_6 | Transactions: 7983
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_NEIGHBOR (lineage-aware)]
# FOVs passing standard FP-Growth (Binary): 9 / 77
# FOVs passing Weighted FP-Growth (Distance-decay): 20 / 77
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            9 |           20  (out of 77 valid FOVs)
# Support :       0.0033 |       0.0033
# Conf    :       0.9886 |       0.9757
# Lift    :       1.3967 |       1.4779
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0168 |       0.0286
# Conf    :       0.9871 |       0.9852
# Lift    :       1.3839 |       0.5022
#
# Visualizing Representative FOV: Control_08_FOV_1 (81 target cells)

# %% [markdown]
# ## Step 4: Run Evaluation on Mild Cohort (Stage 1)

# %%
evaluate_cohort("Mild", mild_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Mild
# ==============================================
#
# FOV: GVHD_03_FOV_1_R | Transactions: 2879
#   [Binary]   Sup: 0.0021 | Conf: 1.0000 | Lift: 1.5871 | PASS: False
#   [Weighted] Sup: 0.0021 | Conf: 1.0000 | Lift: 1.6908 | PASS: False
#
# FOV: GVHD_03_FOV_2 | Transactions: 2524
#   [Binary]   Sup: 0.0166 | Conf: 1.0000 | Lift: 1.7066 | PASS: True
#   [Weighted] Sup: 0.0166 | Conf: 1.0000 | Lift: 1.8103 | PASS: True
#
# FOV: GVHD_03_FOV_3_R | Transactions: 2615
#   [Binary]   Sup: 0.0229 | Conf: 1.0000 | Lift: 1.3362 | PASS: True
#   [Weighted] Sup: 0.0229 | Conf: 1.0000 | Lift: 1.4329 | PASS: True
#
# FOV: GVHD_03_FOV_4 | Transactions: 2443
#   [Binary]   Sup: 0.0147 | Conf: 1.0000 | Lift: 1.3364 | PASS: True
#   [Weighted] Sup: 0.0147 | Conf: 1.0000 | Lift: 1.4031 | PASS: True
#
# FOV: GVHD_04_FOV_1 | Transactions: 2177
#   [Binary]   Sup: 0.0018 | Conf: 1.0000 | Lift: 1.5984 | PASS: False
#   [Weighted] Sup: 0.0018 | Conf: 1.0000 | Lift: 1.6505 | PASS: False
#
# FOV: GVHD_04_FOV_2 | Transactions: 2031
#   [Binary]   Sup: 0.0020 | Conf: 1.0000 | Lift: 1.6043 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 1.0000 | Lift: 1.7566 | PASS: False
#
# FOV: GVHD_04_FOV_3 | Transactions: 2340
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_05_FOV_1_R | Transactions: 1815
#   [Binary]   Sup: 0.0298 | Conf: 0.9474 | Lift: 1.1737 | PASS: False
#   [Weighted] Sup: 0.0297 | Conf: 0.9442 | Lift: 1.2488 | PASS: True
#
# FOV: GVHD_05_FOV_2_R | Transactions: 2398
#   [Binary]   Sup: 0.0859 | Conf: 0.5493 | Lift: 0.7610 | PASS: False
#   [Weighted] Sup: 0.0764 | Conf: 0.4883 | Lift: 0.7721 | PASS: False
#
# FOV: GVHD_05_FOV_3_R | Transactions: 2244
#   [Binary]   Sup: 0.0027 | Conf: 1.0000 | Lift: 1.1231 | PASS: False
#   [Weighted] Sup: 0.0022 | Conf: 0.8308 | Lift: 0.9673 | PASS: False
#
# FOV: GVHD_07_FOV_1 | Transactions: 2137
#   [Binary]   Sup: 0.0098 | Conf: 1.0000 | Lift: 1.4469 | PASS: False
#   [Weighted] Sup: 0.0098 | Conf: 1.0000 | Lift: 1.4992 | PASS: True
#
# FOV: GVHD_07_FOV_3 | Transactions: 2411
#   [Binary]   Sup: 0.0071 | Conf: 1.0000 | Lift: 1.4067 | PASS: False
#   [Weighted] Sup: 0.0071 | Conf: 1.0000 | Lift: 1.4443 | PASS: True
#
# FOV: GVHD_07_FOV_4 | Transactions: 2301
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_10_FOV_1 | Transactions: 1810
#   [Binary]   Sup: 0.0028 | Conf: 1.0000 | Lift: 1.1207 | PASS: False
#   [Weighted] Sup: 0.0028 | Conf: 1.0000 | Lift: 1.1611 | PASS: False
#
# FOV: GVHD_10_FOV_2 | Transactions: 2395
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 1.6760 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 1.7566 | PASS: False
#
# FOV: GVHD_10_FOV_3 | Transactions: 1962
#   [Binary]   Sup: 0.0061 | Conf: 1.0000 | Lift: 1.1407 | PASS: False
#   [Weighted] Sup: 0.0059 | Conf: 0.9614 | Lift: 1.1553 | PASS: False
#
# FOV: GVHD_10_FOV_4 | Transactions: 2438
#   [Binary]   Sup: 0.0049 | Conf: 0.8000 | Lift: 1.3872 | PASS: False
#   [Weighted] Sup: 0.0042 | Conf: 0.6890 | Lift: 1.3723 | PASS: False
#
# FOV: GVHD_12_FOV_1 | Transactions: 1769
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_12_FOV_2 | Transactions: 1703
#   [Binary]   Sup: 0.0088 | Conf: 1.0000 | Lift: 1.0670 | PASS: False
#   [Weighted] Sup: 0.0088 | Conf: 1.0000 | Lift: 1.1013 | PASS: False
#
# FOV: GVHD_12_FOV_3 | Transactions: 1440
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_12_FOV_4 | Transactions: 2318
#   [Binary]   Sup: 0.0069 | Conf: 1.0000 | Lift: 1.2194 | PASS: False
#   [Weighted] Sup: 0.0069 | Conf: 1.0000 | Lift: 1.3146 | PASS: True
#
# FOV: GVHD_12_FOV_5 | Transactions: 2492
#   [Binary]   Sup: 0.0108 | Conf: 1.0000 | Lift: 1.2127 | PASS: True
#   [Weighted] Sup: 0.0108 | Conf: 1.0000 | Lift: 1.2644 | PASS: True
#
# FOV: GVHD_13_FOV_1 | Transactions: 1462
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_13_FOV_2 | Transactions: 1661
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_13_FOV_3 | Transactions: 1294
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_15_FOV_1 | Transactions: 1493
#   [Binary]   Sup: 0.0114 | Conf: 0.3617 | Lift: 0.7804 | PASS: False
#   [Weighted] Sup: 0.0078 | Conf: 0.2470 | Lift: 0.5756 | PASS: False
#
# FOV: GVHD_15_FOV_1_B | Transactions: 1816
#   [Binary]   Sup: 0.0127 | Conf: 0.6216 | Lift: 1.2613 | PASS: True
#   [Weighted] Sup: 0.0092 | Conf: 0.4497 | Lift: 1.0336 | PASS: False
#
# FOV: GVHD_15_FOV_2 | Transactions: 2048
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 1.1650 | PASS: False
#   [Weighted] Sup: 0.0015 | Conf: 1.0000 | Lift: 1.2113 | PASS: False
#
# FOV: GVHD_15_FOV_2_B | Transactions: 2040
#   [Binary]   Sup: 0.0039 | Conf: 1.0000 | Lift: 1.1075 | PASS: False
#   [Weighted] Sup: 0.0039 | Conf: 1.0000 | Lift: 1.1429 | PASS: False
#
# FOV: GVHD_15_FOV_3 | Transactions: 2226
#   [Binary]   Sup: 0.0081 | Conf: 0.8571 | Lift: 1.3408 | PASS: False
#   [Weighted] Sup: 0.0081 | Conf: 0.8571 | Lift: 1.4073 | PASS: False
#
# FOV: GVHD_15_FOV_3_B | Transactions: 2470
#   [Binary]   Sup: 0.0134 | Conf: 1.0000 | Lift: 1.1602 | PASS: False
#   [Weighted] Sup: 0.0134 | Conf: 1.0000 | Lift: 1.2041 | PASS: True
#
# FOV: GVHD_16_FOV_1 | Transactions: 1912
#   [Binary]   Sup: 0.0167 | Conf: 1.0000 | Lift: 1.1274 | PASS: False
#   [Weighted] Sup: 0.0167 | Conf: 1.0000 | Lift: 1.1584 | PASS: False
#
# FOV: GVHD_16_FOV_2 | Transactions: 2166
#   [Binary]   Sup: 0.0217 | Conf: 0.9216 | Lift: 1.5867 | PASS: True
#   [Weighted] Sup: 0.0200 | Conf: 0.8511 | Lift: 1.5670 | PASS: True
#
# FOV: GVHD_16_FOV_3 | Transactions: 2272
#   [Binary]   Sup: 0.0110 | Conf: 1.0000 | Lift: 4.7932 | PASS: True
#   [Weighted] Sup: 0.0110 | Conf: 1.0000 | Lift: 5.0883 | PASS: True
#
# FOV: GVHD_17_FOV_1 | Transactions: 1503
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_2 | Transactions: 1188
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_17_FOV_3 | Transactions: 1492
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_18_FOV_1 | Transactions: 2169
#   [Binary]   Sup: 0.0175 | Conf: 1.0000 | Lift: 1.3405 | PASS: True
#   [Weighted] Sup: 0.0175 | Conf: 1.0000 | Lift: 1.3911 | PASS: True
#
# FOV: GVHD_18_FOV_2 | Transactions: 2054
#   [Binary]   Sup: 0.0083 | Conf: 1.0000 | Lift: 1.5561 | PASS: False
#   [Weighted] Sup: 0.0083 | Conf: 1.0000 | Lift: 1.6222 | PASS: True
#
# FOV: GVHD_18_FOV_3 | Transactions: 2525
#   [Binary]   Sup: 0.0123 | Conf: 0.8158 | Lift: 1.4041 | PASS: True
#   [Weighted] Sup: 0.0123 | Conf: 0.8158 | Lift: 1.4704 | PASS: True
#
# FOV: GVHD_18_FOV_4 | Transactions: 2344
#   [Binary]   Sup: 0.0145 | Conf: 1.0000 | Lift: 1.1329 | PASS: False
#   [Weighted] Sup: 0.0145 | Conf: 1.0000 | Lift: 1.1860 | PASS: False
#
# FOV: GVHD_19_FOV_1 | Transactions: 2205
#   [Binary]   Sup: 0.0336 | Conf: 1.0000 | Lift: 1.4497 | PASS: True
#   [Weighted] Sup: 0.0331 | Conf: 0.9872 | Lift: 1.5833 | PASS: True
#
# FOV: GVHD_19_FOV_2 | Transactions: 2173
#   [Binary]   Sup: 0.0354 | Conf: 0.9872 | Lift: 1.1865 | PASS: False
#   [Weighted] Sup: 0.0354 | Conf: 0.9872 | Lift: 1.2511 | PASS: True
#
# FOV: GVHD_19_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0229 | Conf: 0.9655 | Lift: 1.5597 | PASS: True
#   [Weighted] Sup: 0.0203 | Conf: 0.8566 | Lift: 1.5192 | PASS: True
#
# FOV: GVHD_19_FOV_4 | Transactions: 2250
#   [Binary]   Sup: 0.0200 | Conf: 0.9574 | Lift: 1.3583 | PASS: True
#   [Weighted] Sup: 0.0200 | Conf: 0.9553 | Lift: 1.4494 | PASS: True
#
# FOV: GVHD_20_FOV_1 | Transactions: 1526
#   [Binary]   Sup: 0.0216 | Conf: 1.0000 | Lift: 1.6714 | PASS: True
#   [Weighted] Sup: 0.0211 | Conf: 0.9754 | Lift: 1.7712 | PASS: True
#
# FOV: GVHD_20_FOV_2 | Transactions: 2003
#   [Binary]   Sup: 0.0270 | Conf: 1.0000 | Lift: 1.7297 | PASS: True
#   [Weighted] Sup: 0.0270 | Conf: 1.0000 | Lift: 1.8729 | PASS: True
#
# FOV: GVHD_22_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_22_FOV_2 | Transactions: 1698
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_22_FOV_3 | Transactions: 1900
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_1 | Transactions: 2347
#   [Binary]   Sup: 0.0030 | Conf: 1.0000 | Lift: 1.1999 | PASS: False
#   [Weighted] Sup: 0.0030 | Conf: 1.0000 | Lift: 1.2400 | PASS: False
#
# FOV: GVHD_23_FOV_2 | Transactions: 1039
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_3 | Transactions: 1348
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_23_FOV_4 | Transactions: 1161
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_27_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0302 | Conf: 1.0000 | Lift: 1.8393 | PASS: True
#   [Weighted] Sup: 0.0302 | Conf: 1.0000 | Lift: 1.8884 | PASS: True
#
# FOV: GVHD_27_FOV_2 | Transactions: 2738
#   [Binary]   Sup: 0.0015 | Conf: 1.0000 | Lift: 4.2915 | PASS: False
#   [Weighted] Sup: 0.0015 | Conf: 1.0000 | Lift: 5.1138 | PASS: False
#
# FOV: GVHD_27_FOV_3 | Transactions: 3061
#   [Binary]   Sup: 0.0033 | Conf: 1.0000 | Lift: 5.1532 | PASS: False
#   [Weighted] Sup: 0.0033 | Conf: 1.0000 | Lift: 5.9014 | PASS: False
#
# FOV: GVHD_27_FOV_4 | Transactions: 2161
#   [Binary]   Sup: 0.0093 | Conf: 1.0000 | Lift: 1.1979 | PASS: False
#   [Weighted] Sup: 0.0093 | Conf: 1.0000 | Lift: 1.2599 | PASS: True
#
# FOV: GVHD_27_FOV_5 | Transactions: 2416
#   [Binary]   Sup: 0.0497 | Conf: 1.0000 | Lift: 1.5025 | PASS: True
#   [Weighted] Sup: 0.0497 | Conf: 1.0000 | Lift: 1.5945 | PASS: True
#
# FOV: GVHD_28_FOV_1 | Transactions: 2142
#   [Binary]   Sup: 0.0201 | Conf: 1.0000 | Lift: 1.4958 | PASS: True
#   [Weighted] Sup: 0.0196 | Conf: 0.9765 | Lift: 1.5637 | PASS: True
#
# FOV: GVHD_28_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0174 | Conf: 1.0000 | Lift: 1.8834 | PASS: True
#   [Weighted] Sup: 0.0170 | Conf: 0.9732 | Lift: 1.9036 | PASS: True
#
# FOV: GVHD_28_FOV_3 | Transactions: 2110
#   [Binary]   Sup: 0.0251 | Conf: 0.9636 | Lift: 1.4441 | PASS: True
#   [Weighted] Sup: 0.0249 | Conf: 0.9548 | Lift: 1.4894 | PASS: True
#
# FOV: GVHD_29_FOV_1 | Transactions: 2334
#   [Binary]   Sup: 0.0416 | Conf: 0.9604 | Lift: 1.4527 | PASS: True
#   [Weighted] Sup: 0.0412 | Conf: 0.9525 | Lift: 1.5389 | PASS: True
#
# FOV: GVHD_29_FOV_2 | Transactions: 2393
#   [Binary]   Sup: 0.0506 | Conf: 1.0000 | Lift: 1.1293 | PASS: False
#   [Weighted] Sup: 0.0504 | Conf: 0.9975 | Lift: 1.1844 | PASS: False
#
# FOV: GVHD_29_FOV_3 | Transactions: 2233
#   [Binary]   Sup: 0.0260 | Conf: 1.0000 | Lift: 1.4662 | PASS: True
#   [Weighted] Sup: 0.0260 | Conf: 1.0000 | Lift: 1.5201 | PASS: True
#
# FOV: GVHD_29_FOV_4 | Transactions: 2107
#   [Binary]   Sup: 0.0304 | Conf: 1.0000 | Lift: 1.9102 | PASS: True
#   [Weighted] Sup: 0.0304 | Conf: 1.0000 | Lift: 2.0543 | PASS: True
#
# FOV: GVHD_30_FOV_1 | Transactions: 2235
#   [Binary]   Sup: 0.0125 | Conf: 0.8235 | Lift: 1.3261 | PASS: True
#   [Weighted] Sup: 0.0125 | Conf: 0.8235 | Lift: 1.4024 | PASS: True
#
# FOV: GVHD_30_FOV_2 | Transactions: 2267
#   [Binary]   Sup: 0.0115 | Conf: 1.0000 | Lift: 1.6463 | PASS: True
#   [Weighted] Sup: 0.0115 | Conf: 1.0000 | Lift: 1.7022 | PASS: True
#
# FOV: GVHD_30_FOV_3 | Transactions: 2206
#   [Binary]   Sup: 0.0036 | Conf: 1.0000 | Lift: 1.6044 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 1.0000 | Lift: 1.6779 | PASS: False
#
# FOV: GVHD_31_FOV_1 | Transactions: 2168
#   [Binary]   Sup: 0.0268 | Conf: 1.0000 | Lift: 1.2283 | PASS: True
#   [Weighted] Sup: 0.0267 | Conf: 0.9990 | Lift: 1.2520 | PASS: True
#
# FOV: GVHD_31_FOV_2 | Transactions: 2315
#   [Binary]   Sup: 0.0462 | Conf: 1.0000 | Lift: 1.1598 | PASS: False
#   [Weighted] Sup: 0.0461 | Conf: 0.9976 | Lift: 1.1903 | PASS: False
#
# FOV: GVHD_31_FOV_3 | Transactions: 2372
#   [Binary]   Sup: 0.0430 | Conf: 0.9714 | Lift: 2.0482 | PASS: True
#   [Weighted] Sup: 0.0424 | Conf: 0.9571 | Lift: 2.1028 | PASS: True
#
# FOV: GVHD_33_FOV_1 | Transactions: 1834
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_33_FOV_2 | Transactions: 1535
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_33_FOV_3 | Transactions: 1990
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0768 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0996 | PASS: False
#
# FOV: GVHD_34_FOV_1 | Transactions: 2224
#   [Binary]   Sup: 0.0157 | Conf: 1.0000 | Lift: 1.1656 | PASS: False
#   [Weighted] Sup: 0.0155 | Conf: 0.9834 | Lift: 1.1919 | PASS: False
#
# FOV: GVHD_34_FOV_2 | Transactions: 2254
#   [Binary]   Sup: 0.0155 | Conf: 0.9722 | Lift: 1.0674 | PASS: False
#   [Weighted] Sup: 0.0151 | Conf: 0.9456 | Lift: 1.0665 | PASS: False
#
# FOV: GVHD_35_FOV_1 | Transactions: 2240
#   [Binary]   Sup: 0.0031 | Conf: 1.0000 | Lift: 1.9718 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 0.7854 | Lift: 1.8152 | PASS: False
#
# FOV: GVHD_35_FOV_2 | Transactions: 2120
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_36_FOV_1 | Transactions: 2179
#   [Binary]   Sup: 0.0073 | Conf: 1.0000 | Lift: 1.4104 | PASS: False
#   [Weighted] Sup: 0.0073 | Conf: 1.0000 | Lift: 1.4882 | PASS: True
#
# FOV: GVHD_36_FOV_2 | Transactions: 2409
#   [Binary]   Sup: 0.0120 | Conf: 1.0000 | Lift: 1.9149 | PASS: True
#   [Weighted] Sup: 0.0120 | Conf: 1.0000 | Lift: 1.9671 | PASS: True
#
# FOV: GVHD_36_FOV_3 | Transactions: 2318
#   [Binary]   Sup: 0.0035 | Conf: 1.0000 | Lift: 1.4309 | PASS: False
#   [Weighted] Sup: 0.0035 | Conf: 1.0000 | Lift: 1.5127 | PASS: False
#
# FOV: GVHD_38_FOV_1 | Transactions: 1760
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_38_FOV_2 | Transactions: 2294
#   [Binary]   Sup: 0.0139 | Conf: 0.7273 | Lift: 1.2029 | PASS: True
#   [Weighted] Sup: 0.0139 | Conf: 0.7273 | Lift: 1.3172 | PASS: True
#
# FOV: GVHD_39_FOV_1 | Transactions: 1942
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.1091 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.1880 | PASS: False
#
# FOV: GVHD_39_FOV_2 | Transactions: 1508
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_39_FOV_3 | Transactions: 1957
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_1 | Transactions: 1386
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_2 | Transactions: 1447
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_3 | Transactions: 1147
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_40_FOV_4 | Transactions: 1437
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_1 | Transactions: 1768
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_2 | Transactions: 1913
#   [Binary]   Sup: 0.0010 | Conf: 1.0000 | Lift: 1.5680 | PASS: False
#   [Weighted] Sup: 0.0010 | Conf: 1.0000 | Lift: 1.6681 | PASS: False
#
# FOV: GVHD_42_FOV_3 | Transactions: 1989
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_42_FOV_4 | Transactions: 2275
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.6367 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.7243 | PASS: False
#
# FOV: GVHD_43_FOV_1 | Transactions: 2220
#   [Binary]   Sup: 0.0036 | Conf: 1.0000 | Lift: 1.8423 | PASS: False
#   [Weighted] Sup: 0.0034 | Conf: 0.9421 | Lift: 2.2107 | PASS: False
#
# FOV: GVHD_43_FOV_2 | Transactions: 2110
#   [Binary]   Sup: 0.0071 | Conf: 1.0000 | Lift: 1.2993 | PASS: False
#   [Weighted] Sup: 0.0071 | Conf: 1.0000 | Lift: 1.5260 | PASS: True
#
# FOV: GVHD_44_FOV_1 | Transactions: 1837
#   [Binary]   Sup: 0.0327 | Conf: 0.9677 | Lift: 1.3488 | PASS: True
#   [Weighted] Sup: 0.0321 | Conf: 0.9510 | Lift: 1.3758 | PASS: True
#
# FOV: GVHD_44_FOV_2 | Transactions: 1932
#   [Binary]   Sup: 0.0031 | Conf: 0.2308 | Lift: 2.8041 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 0.1294 | Lift: 2.6638 | PASS: False
#
# FOV: GVHD_45_FOV_1 | Transactions: 2357
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_45_FOV_2 | Transactions: 2096
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.4435 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.5932 | PASS: False
#
# FOV: GVHD_47_FOV_1 | Transactions: 2145
#   [Binary]   Sup: 0.0056 | Conf: 1.0000 | Lift: 1.1313 | PASS: False
#   [Weighted] Sup: 0.0056 | Conf: 1.0000 | Lift: 1.1802 | PASS: False
#
# FOV: GVHD_47_FOV_2 | Transactions: 2091
#   [Binary]   Sup: 0.0043 | Conf: 1.0000 | Lift: 1.0382 | PASS: False
#   [Weighted] Sup: 0.0043 | Conf: 1.0000 | Lift: 1.0591 | PASS: False
#
# FOV: GVHD_49_FOV_1 | Transactions: 2531
#   [Binary]   Sup: 0.0241 | Conf: 1.0000 | Lift: 1.4348 | PASS: True
#   [Weighted] Sup: 0.0241 | Conf: 1.0000 | Lift: 1.4850 | PASS: True
#
# FOV: GVHD_49_FOV_2 | Transactions: 2426
#   [Binary]   Sup: 0.0082 | Conf: 1.0000 | Lift: 1.2850 | PASS: False
#   [Weighted] Sup: 0.0082 | Conf: 1.0000 | Lift: 1.3725 | PASS: True
#
# FOV: GVHD_49_FOV_3 | Transactions: 1967
#   [Binary]   Sup: 0.0097 | Conf: 1.0000 | Lift: 1.2112 | PASS: False
#   [Weighted] Sup: 0.0097 | Conf: 1.0000 | Lift: 1.2360 | PASS: True
#
# FOV: GVHD_50_FOV_1 | Transactions: 2444
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_2 | Transactions: 2514
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_3 | Transactions: 2088
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_50_FOV_4 | Transactions: 2225
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_51_FOV_1 | Transactions: 2527
#   [Binary]   Sup: 0.0609 | Conf: 1.0000 | Lift: 1.1030 | PASS: False
#   [Weighted] Sup: 0.0593 | Conf: 0.9730 | Lift: 1.1134 | PASS: False
#
# FOV: GVHD_51_FOV_2 | Transactions: 2273
#   [Binary]   Sup: 0.0119 | Conf: 1.0000 | Lift: 1.0049 | PASS: False
#   [Weighted] Sup: 0.0119 | Conf: 0.9981 | Lift: 1.0094 | PASS: False
#
# FOV: GVHD_51_FOV_3 | Transactions: 2210
#   [Binary]   Sup: 0.0036 | Conf: 1.0000 | Lift: 1.0005 | PASS: False
#   [Weighted] Sup: 0.0036 | Conf: 1.0000 | Lift: 1.0018 | PASS: False
#
# FOV: GVHD_51_FOV_4 | Transactions: 1873
#   [Binary]   Sup: 0.0208 | Conf: 0.9286 | Lift: 0.9916 | PASS: False
#   [Weighted] Sup: 0.0192 | Conf: 0.8582 | Lift: 0.9542 | PASS: False
#
# FOV: GVHD_52_FOV_1 | Transactions: 2407
#   [Binary]   Sup: 0.0162 | Conf: 1.0000 | Lift: 1.0251 | PASS: False
#   [Weighted] Sup: 0.0159 | Conf: 0.9833 | Lift: 1.0249 | PASS: False
#
# FOV: GVHD_52_FOV_2 | Transactions: 2624
#   [Binary]   Sup: 0.0484 | Conf: 0.9845 | Lift: 1.1345 | PASS: False
#   [Weighted] Sup: 0.0484 | Conf: 0.9845 | Lift: 1.1630 | PASS: False
#
# FOV: GVHD_52_FOV_3 | Transactions: 2449
#   [Binary]   Sup: 0.0363 | Conf: 1.0000 | Lift: 1.0457 | PASS: False
#   [Weighted] Sup: 0.0360 | Conf: 0.9893 | Lift: 1.0531 | PASS: False
#
# FOV: GVHD_52_FOV_4 | Transactions: 2201
#   [Binary]   Sup: 0.0177 | Conf: 1.0000 | Lift: 1.0848 | PASS: False
#   [Weighted] Sup: 0.0177 | Conf: 1.0000 | Lift: 1.1106 | PASS: False
#
# FOV: GVHD_53_FOV_1 | Transactions: 2420
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_2 | Transactions: 2375
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.3784 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 1.5265 | PASS: False
#
# FOV: GVHD_53_FOV_3 | Transactions: 2707
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_53_FOV_4 | Transactions: 2668
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_54_FOV_1 | Transactions: 2263
#   [Binary]   Sup: 0.0177 | Conf: 0.9302 | Lift: 1.9601 | PASS: True
#   [Weighted] Sup: 0.0174 | Conf: 0.9175 | Lift: 2.1479 | PASS: True
#
# FOV: GVHD_54_FOV_2 | Transactions: 2289
#   [Binary]   Sup: 0.0144 | Conf: 1.0000 | Lift: 1.1293 | PASS: False
#   [Weighted] Sup: 0.0144 | Conf: 1.0000 | Lift: 1.1677 | PASS: False
#
# FOV: GVHD_54_FOV_3 | Transactions: 2688
#   [Binary]   Sup: 0.0067 | Conf: 1.0000 | Lift: 1.8065 | PASS: False
#   [Weighted] Sup: 0.0067 | Conf: 1.0000 | Lift: 2.0469 | PASS: True
#
# FOV: GVHD_54_FOV_4 | Transactions: 2739
#   [Binary]   Sup: 0.0153 | Conf: 1.0000 | Lift: 2.0609 | PASS: True
#   [Weighted] Sup: 0.0153 | Conf: 1.0000 | Lift: 2.3377 | PASS: True
#
# FOV: GVHD_55_FOV_1 | Transactions: 2553
#   [Binary]   Sup: 0.0024 | Conf: 1.0000 | Lift: 1.5287 | PASS: False
#   [Weighted] Sup: 0.0024 | Conf: 1.0000 | Lift: 1.6577 | PASS: False
#
# FOV: GVHD_55_FOV_2 | Transactions: 2216
#   [Binary]   Sup: 0.0181 | Conf: 1.0000 | Lift: 1.1608 | PASS: False
#   [Weighted] Sup: 0.0181 | Conf: 1.0000 | Lift: 1.1938 | PASS: False
#
# FOV: GVHD_55_FOV_3 | Transactions: 1786
#   [Binary]   Sup: 0.0067 | Conf: 1.0000 | Lift: 1.3348 | PASS: False
#   [Weighted] Sup: 0.0067 | Conf: 1.0000 | Lift: 1.3858 | PASS: True
#
# FOV: GVHD_56_FOV_1 | Transactions: 2237
#   [Binary]   Sup: 0.0027 | Conf: 1.0000 | Lift: 1.0854 | PASS: False
#   [Weighted] Sup: 0.0027 | Conf: 1.0000 | Lift: 1.1154 | PASS: False
#
# FOV: GVHD_56_FOV_2 | Transactions: 2424
#   [Binary]   Sup: 0.0025 | Conf: 1.0000 | Lift: 1.1947 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 1.0000 | Lift: 1.2775 | PASS: False
#
# FOV: GVHD_56_FOV_3 | Transactions: 2278
#   [Binary]   Sup: 0.0083 | Conf: 1.0000 | Lift: 1.3039 | PASS: False
#   [Weighted] Sup: 0.0083 | Conf: 1.0000 | Lift: 1.3438 | PASS: True
#
# FOV: GVHD_56_FOV_4 | Transactions: 2406
#   [Binary]   Sup: 0.0046 | Conf: 1.0000 | Lift: 1.4304 | PASS: False
#   [Weighted] Sup: 0.0046 | Conf: 1.0000 | Lift: 1.4957 | PASS: False
#
# FOV: GVHD_58_FOV_1 | Transactions: 2377
#   [Binary]   Sup: 0.0109 | Conf: 1.0000 | Lift: 1.0698 | PASS: False
#   [Weighted] Sup: 0.0109 | Conf: 1.0000 | Lift: 1.0947 | PASS: False
#
# FOV: GVHD_58_FOV_2 | Transactions: 2628
#   [Binary]   Sup: 0.0103 | Conf: 1.0000 | Lift: 1.4814 | PASS: True
#   [Weighted] Sup: 0.0103 | Conf: 1.0000 | Lift: 1.5405 | PASS: True
#
# FOV: GVHD_58_FOV_3 | Transactions: 2730
#   [Binary]   Sup: 0.0106 | Conf: 1.0000 | Lift: 1.7322 | PASS: True
#   [Weighted] Sup: 0.0106 | Conf: 1.0000 | Lift: 1.8002 | PASS: True
#
# FOV: GVHD_58_FOV_4 | Transactions: 2447
#   [Binary]   Sup: 0.0253 | Conf: 1.0000 | Lift: 1.2975 | PASS: True
#   [Weighted] Sup: 0.0248 | Conf: 0.9786 | Lift: 1.3322 | PASS: True
#
# FOV: GVHD_59_FOV_1 | Transactions: 2055
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_59_FOV_2 | Transactions: 1953
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_59_FOV_3 | Transactions: 1993
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_60_FOV_1 | Transactions: 1962
#   [Binary]   Sup: 0.0214 | Conf: 1.0000 | Lift: 1.0442 | PASS: False
#   [Weighted] Sup: 0.0213 | Conf: 0.9934 | Lift: 1.0472 | PASS: False
#
# FOV: GVHD_60_FOV_2 | Transactions: 1949
#   [Binary]   Sup: 0.0292 | Conf: 0.9661 | Lift: 1.2275 | PASS: True
#   [Weighted] Sup: 0.0283 | Conf: 0.9361 | Lift: 1.2388 | PASS: True
#
# FOV: GVHD_60_FOV_3 | Transactions: 2138
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_NEIGHBOR (lineage-aware)]
# FOVs passing standard FP-Growth (Binary): 36 / 143
# FOVs passing Weighted FP-Growth (Distance-decay): 50 / 143
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:           36 |           50  (out of 143 valid FOVs)
# Support :       0.0119 |       0.0116
# Conf    :       0.9235 |       0.9043
# Lift    :       1.3002 |       1.3489
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0217 |       0.0257
# Conf    :       0.9659 |       0.9660
# Lift    :       1.5467 |       1.1151
#
# Visualizing Representative FOV: GVHD_05_FOV_2_R (375 target cells)

# %% [markdown]
# ## Step 5: Run Evaluation on Severe Cohort (Stage 3)

# %%
evaluate_cohort("Severe", severe_fovs, df_cells)
# Out:
# ==============================================
# Evaluating Cohort: Severe
# ==============================================
#
# FOV: GVHD_01_FOV_1 | Transactions: 1801
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_2_R | Transactions: 2040
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_3_R | Transactions: 1852
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_4 | Transactions: 1937
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_5 | Transactions: 2103
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_6_R | Transactions: 2010
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_01_FOV_7 | Transactions: 2066
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_02_FOV_1_R | Transactions: 1977
#   [Binary]   Sup: 0.1027 | Conf: 0.6060 | Lift: 1.1217 | PASS: False
#   [Weighted] Sup: 0.0864 | Conf: 0.5097 | Lift: 1.0872 | PASS: False
#
# FOV: GVHD_02_FOV_2_R | Transactions: 1722
#   [Binary]   Sup: 0.0459 | Conf: 0.4317 | Lift: 1.0789 | PASS: False
#   [Weighted] Sup: 0.0377 | Conf: 0.3549 | Lift: 1.1034 | PASS: False
#
# FOV: GVHD_06_FOV_1 | Transactions: 2174
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_2 | Transactions: 2265
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_3 | Transactions: 1998
#   [Binary]   Sup: 0.0005 | Conf: 0.5000 | Lift: 2.7147 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 0.3310 | Lift: 2.4467 | PASS: False
#
# FOV: GVHD_06_FOV_4 | Transactions: 2040
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_06_FOV_5 | Transactions: 2233
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_1 | Transactions: 2672
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_2 | Transactions: 2496
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_3 | Transactions: 2107
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_08_FOV_4 | Transactions: 2274
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_09_FOV_1 | Transactions: 2477
#   [Binary]   Sup: 0.0028 | Conf: 1.0000 | Lift: 1.6012 | PASS: False
#   [Weighted] Sup: 0.0028 | Conf: 1.0000 | Lift: 1.6740 | PASS: False
#
# FOV: GVHD_09_FOV_2 | Transactions: 2121
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0271 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0400 | PASS: False
#
# FOV: GVHD_09_FOV_3 | Transactions: 2765
#   [Binary]   Sup: 0.0025 | Conf: 1.0000 | Lift: 1.8421 | PASS: False
#   [Weighted] Sup: 0.0025 | Conf: 1.0000 | Lift: 1.8869 | PASS: False
#
# FOV: GVHD_09_FOV_4 | Transactions: 2233
#   [Binary]   Sup: 0.0063 | Conf: 1.0000 | Lift: 1.3143 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 1.0000 | Lift: 1.3666 | PASS: True
#
# FOV: GVHD_11_FOV_1 | Transactions: 2608
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_11_FOV_2 | Transactions: 2600
#   [Binary]   Sup: 0.0004 | Conf: 0.5000 | Lift: 1.7544 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 0.5000 | Lift: 2.1091 | PASS: False
#
# FOV: GVHD_11_FOV_3 | Transactions: 2441
#   [Binary]   Sup: 0.0020 | Conf: 1.0000 | Lift: 2.0410 | PASS: False
#   [Weighted] Sup: 0.0020 | Conf: 1.0000 | Lift: 2.5191 | PASS: False
#
# FOV: GVHD_11_FOV_4 | Transactions: 1796
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_14_FOV_1 | Transactions: 2206
#   [Binary]   Sup: 0.0023 | Conf: 1.0000 | Lift: 1.8569 | PASS: False
#   [Weighted] Sup: 0.0023 | Conf: 1.0000 | Lift: 1.9725 | PASS: False
#
# FOV: GVHD_14_FOV_2 | Transactions: 2210
#   [Binary]   Sup: 0.0063 | Conf: 1.0000 | Lift: 1.6226 | PASS: False
#   [Weighted] Sup: 0.0063 | Conf: 1.0000 | Lift: 1.6864 | PASS: True
#
# FOV: GVHD_14_FOV_3 | Transactions: 2000
#   [Binary]   Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0672 | PASS: False
#   [Weighted] Sup: 0.0005 | Conf: 1.0000 | Lift: 1.0881 | PASS: False
#
# FOV: GVHD_14_FOV_4 | Transactions: 2703
#   [Binary]   Sup: 0.0018 | Conf: 1.0000 | Lift: 2.1117 | PASS: False
#   [Weighted] Sup: 0.0017 | Conf: 0.9225 | Lift: 2.0415 | PASS: False
#
# FOV: GVHD_14_FOV_5 | Transactions: 2412
#   [Binary]   Sup: 0.0104 | Conf: 1.0000 | Lift: 1.7303 | PASS: True
#   [Weighted] Sup: 0.0104 | Conf: 1.0000 | Lift: 1.8483 | PASS: True
#
# FOV: GVHD_21_FOV_1 | Transactions: 1340
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_2 | Transactions: 1840
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_3 | Transactions: 2570
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_21_FOV_4 | Transactions: 1956
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_24_FOV_1 | Transactions: 2262
#   [Binary]   Sup: 0.0022 | Conf: 0.3571 | Lift: 2.5011 | PASS: False
#   [Weighted] Sup: 0.0013 | Conf: 0.2078 | Lift: 2.4003 | PASS: False
#
# FOV: GVHD_24_FOV_2 | Transactions: 2001
#   [Binary]   Sup: 0.0010 | Conf: 0.6667 | Lift: 17.1026 | PASS: False
#   [Weighted] Sup: 0.0006 | Conf: 0.4231 | Lift: 16.7314 | PASS: False
#
# FOV: GVHD_24_FOV_3 | Transactions: 1589
#   [Binary]   Sup: 0.0038 | Conf: 0.8571 | Lift: 2.0826 | PASS: False
#   [Weighted] Sup: 0.0038 | Conf: 0.8571 | Lift: 2.8642 | PASS: False
#
# FOV: GVHD_24_FOV_4 | Transactions: 1483
#   [Binary]   Sup: 0.0081 | Conf: 1.0000 | Lift: 3.6527 | PASS: False
#   [Weighted] Sup: 0.0081 | Conf: 1.0000 | Lift: 4.6527 | PASS: True
#
# FOV: GVHD_25_FOV_1 | Transactions: 2667
#   [Binary]   Sup: 0.0007 | Conf: 1.0000 | Lift: 1.7307 | PASS: False
#   [Weighted] Sup: 0.0007 | Conf: 1.0000 | Lift: 1.8548 | PASS: False
#
# FOV: GVHD_25_FOV_2 | Transactions: 2589
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_25_FOV_3 | Transactions: 2320
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.4881 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.5933 | PASS: False
#
# FOV: GVHD_25_FOV_4 | Transactions: 2276
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_1 | Transactions: 2686
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_2 | Transactions: 2425
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_3 | Transactions: 2362
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_26_FOV_4 | Transactions: 2534
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_1 | Transactions: 2579
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_2 | Transactions: 1867
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_3 | Transactions: 2197
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_32_FOV_4 | Transactions: 1765
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_1 | Transactions: 1821
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_2 | Transactions: 2118
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_3 | Transactions: 1431
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_37_FOV_4 | Transactions: 1596
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_1 | Transactions: 1896
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_2 | Transactions: 2102
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_41_FOV_3 | Transactions: 2569
#   [Binary]   Sup: 0.0012 | Conf: 1.0000 | Lift: 1.8549 | PASS: False
#   [Weighted] Sup: 0.0012 | Conf: 1.0000 | Lift: 2.1250 | PASS: False
#
# FOV: GVHD_41_FOV_4 | Transactions: 2023
#   [Binary]   Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#   [Weighted] Sup: 0.0000 | Conf: 0.0000 | Lift: 0.0000 | PASS: False
#
# FOV: GVHD_48_FOV_1 | Transactions: 2528
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 2.0503 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 2.1732 | PASS: False
#
# FOV: GVHD_48_FOV_2 | Transactions: 2151
#   [Binary]   Sup: 0.0009 | Conf: 1.0000 | Lift: 1.1937 | PASS: False
#   [Weighted] Sup: 0.0009 | Conf: 1.0000 | Lift: 1.2529 | PASS: False
#
# FOV: GVHD_48_FOV_3 | Transactions: 2388
#   [Binary]   Sup: 0.0008 | Conf: 1.0000 | Lift: 1.3989 | PASS: False
#   [Weighted] Sup: 0.0008 | Conf: 1.0000 | Lift: 1.5160 | PASS: False
#
# FOV: GVHD_48_FOV_4 | Transactions: 2989
#   [Binary]   Sup: 0.0003 | Conf: 1.0000 | Lift: 3.9123 | PASS: False
#   [Weighted] Sup: 0.0003 | Conf: 1.0000 | Lift: 4.9165 | PASS: False
#
# FOV: GVHD_48_FOV_5 | Transactions: 2740
#   [Binary]   Sup: 0.0004 | Conf: 1.0000 | Lift: 1.3666 | PASS: False
#   [Weighted] Sup: 0.0004 | Conf: 1.0000 | Lift: 1.4702 | PASS: False
#
# FOV: GVHD_57_FOV_1 | Transactions: 2427
#   [Binary]   Sup: 0.0272 | Conf: 0.9851 | Lift: 2.1365 | PASS: True
#   [Weighted] Sup: 0.0272 | Conf: 0.9851 | Lift: 2.3533 | PASS: True
#
# FOV: GVHD_57_FOV_2 | Transactions: 2178
#   [Binary]   Sup: 0.0188 | Conf: 1.0000 | Lift: 1.0366 | PASS: False
#   [Weighted] Sup: 0.0188 | Conf: 1.0000 | Lift: 1.0532 | PASS: False
#
# FOV: GVHD_57_FOV_3 | Transactions: 2036
#   [Binary]   Sup: 0.0059 | Conf: 1.0000 | Lift: 1.0807 | PASS: False
#   [Weighted] Sup: 0.0059 | Conf: 1.0000 | Lift: 1.1119 | PASS: False
#
# FOV: GVHD_57_FOV_4 | Transactions: 2196
#   [Binary]   Sup: 0.0128 | Conf: 1.0000 | Lift: 1.0186 | PASS: False
#   [Weighted] Sup: 0.0128 | Conf: 1.0000 | Lift: 1.0338 | PASS: False
#
#
# [Algorithm Comparison: Paneth_CENTER -> Epithelial_NEIGHBOR (lineage-aware)]
# FOVs passing standard FP-Growth (Binary): 2 / 68
# FOVs passing Weighted FP-Growth (Distance-decay): 5 / 68
#
# [Aggregate Metrics: ALL FOVs]
#                 Binary |     Weighted
# Approved:            2 |            5  (out of 68 valid FOVs)
# Support :       0.0037 |       0.0034
# Conf    :       0.6873 |       0.6255
# Lift    :       1.4086 |       1.3969
#
# [Aggregate Metrics: ONLY PASSING FOVs]
#                 Binary |     Weighted
# Support :       0.0188 |       0.0271
# Conf    :       0.9891 |       0.9924
# Lift    :       1.9047 |       0.8600
#
# Visualizing Representative FOV: GVHD_02_FOV_1_R (335 target cells)
